# %% [markdown]
# # Cloud Vendors and related Tweets
# (https://www.kaggle.com/datasets/bwandowando/cloud-vendors-and-related-tweets-dataset)

# %% [markdown]
# In this notebook we are performing an analysis per market region (EMEA, North America, LATAM, APAC) for the 3 major cloud vendors so that we find out the most popular cloud provider per number of tweets as well as per the overall reach of the tweeets in Twitter. Additionally, we are going to perform topic modelling so that we find out the major topics that users are tweeting about per cloud provider for the North Americas region.

# %% [markdown]
# ### Data Loading and Initial Exploration

# %%
#Load the dataset
import pandas as pd

df = pd.read_csv(r'Tweets_on_cloud_services_data\0423_to_0619_CloudProvidersTweets.csv')

# %%
df.shape[0] #Our initial data contain 1.6M rows
# Out:
# 1625820

# %%
df.head(10)
# Out:
#    Unnamed: 0         hashed_userid  masked_username  \
# 0           0  60387206788473740931         ****enni
# 1           1  11757760862330230620    *******angelo
# 2           2  67542035055337764482  ********nce_jbs
# 3           3  53508755950760688283       *****ggets
# 4           4  60615872602451730756   *******affairs
# 5           5  62142697060620806394     ******s_feed
# 6           6  86851226483299649418     ******ec_med
# 7           7  88834411414998048685      ******kup4U
# 8           8  42390035568972706408    *******EZJR01
# 9           9  41108708906982800530         ****oper
#
#                         location  following  followers  totaltweets  \
# 0                            NaN        370       1516        40930
# 1                       Michigan        633        302         3793
# 2                            NaN          1        222         8786
# 3            We go where you go.        340      32212        28262
# 4                         Africa        913       1193        69889
# 5                            NaN          1        170        10259
# 6                  Amsterdam, NL        688        907        23749
# 7               Toronto, Ontario        611        816        20539
# 8  Born in SP, lives in Brasilia        988       1641        62682
# 9                            NaN        253        125         8320
#
#                 usercreatedts              tweetid  \
# 0  2010-02-25 08:10:33.000000  1517992721239183362
# 1  2009-06-14 16:01:18.000000  1517993383700148227
# 2  2021-12-07 08:56:09.000000  1517994729950093313
# 3  2009-02-09 16:25:45.000000  1517995750000664577
# 4  2009-08-24 23:37:20.000000  1517995753372794880
# 5  2021-11-23 23:00:44.000000  1517997244858961920
# 6  2015-03-24 07:48:50.000000  1517998046700789760
# 7  2010-04-26 19:29:10.000000  1517998414717403137
# 8  2018-12-30 19:27:21.000000  1517998775322791936
# 9  2021-07-19 22:12:56.000000  1517998940737712132
#
#                tweetcreatedts  ...  \
# 0  2022-04-23 22:24:02.000000  ...
# 1  2022-04-23 22:26:40.000000  ...
# 2  2022-04-23 22:32:01.000000  ...
# 3  2022-04-23 22:36:04.000000  ...
# 4  2022-04-23 22:36:05.000000  ...
# 5  2022-04-23 22:42:00.000000  ...
# 6  2022-04-23 22:45:12.000000  ...
# 7  2022-04-23 22:46:39.000000  ...
# 8  2022-04-23 22:48:05.000000  ...
# 9  2022-04-23 22:48:45.000000  ...
#
#                                                 text  \
# 0  Migrate your Classic Storage Account to Azure ...
# 1  Does anyone in #Blazor land have any successfu...
# 2  Trane Technologies is looking for a Sr. Data S...
# 3  Azure was built for developers, so it's no sur...
# 4  Now playing on African Affairs Radio: Dangote ...
# 5  Guardian Life Insurance Company is looking for...
# 6  Deploying Azure Network Manager with Azure Bic...
# 7  Senior Architect - Permanent/Remote anywhere i...
# 8  Watch Out! #Cryptocurrency Miners Targeting Do...
# 9  @lakersucklolz Also, this ratio does too\n\nDa...
#
#                                             hashtags language favorite_count  \
# 0  [{'text': 'Azure', 'indices': [104, 110]}, {'t...       en              0
# 1  [{'text': 'Blazor', 'indices': [15, 22]}, {'te...       en              1
# 2  [{'text': 'careers', 'indices': [146, 154]}, {...       en              1
# 3  [{'text': 'ITexpert', 'indices': [165, 174]}, ...       en              2
# 4  [{'text': 'cloudcomputing', 'indices': [122, 1...       en              1
# 5  [{'text': 'programming', 'indices': [149, 161]...       en              1
# 6  [{'text': 'azure', 'indices': [68, 74]}, {'tex...       en              0
# 7  [{'text': 'softwaredesign', 'indices': [182, 1...       en              1
# 8  [{'text': 'Cryptocurrency', 'indices': [11, 26...       en              1
# 9  [{'text': '100DaysOfCode', 'indices': [52, 66]...       en              9
#
#    is_retweet  original_tweet_id  in_reply_to_status_id  is_quote_status  \
# 0       False                  0                      0            False
# 1       False                  0                      0            False
# 2       False                  0                      0            False
# 3       False                  0                      0            False
# 4       False                  0                      0             True
# 5       False                  0                      0            False
# 6       False                  0                      0            False
# 7       False                  0                      0            False
# 8       False                  0                      0            False
# 9       False                  0    1517998519575060480            False
#
#       quoted_status_id                 extractedts
# 0                    0  2022-04-26 12:03:25.181694
# 1                    0  2022-04-26 12:03:25.168930
# 2                    0  2022-04-26 12:03:25.156006
# 3                    0  2022-04-26 12:03:25.143810
# 4  1361781471242039296  2022-04-26 12:03:25.131613
# 5                    0  2022-04-26 12:03:25.119380
# 6                    0  2022-04-26 12:03:25.106191
# 7                    0  2022-04-26 12:03:25.093500
# 8                    0  2022-04-26 12:03:25.081036
# 9                    0  2022-04-26 12:03:25.067920
#
# [10 rows x 21 columns]

# %% [markdown]
# We see that there are some redundant columns that can be safely dropped without losing any important information

# %%
df['language'].value_counts() #Language column is everywhere en, so it does not add any useful information
# Out:
# en    1625820
# Name: language, dtype: int64

# %% [markdown]
# On the one hand, all of the retweets have an original tweet id that is different to 0

# %%
df.loc[df['is_retweet']==True].shape
# Out:
# (745579, 21)

# %%
df.loc[(df['is_retweet']==True) & (df['original_tweet_id']!=0)].shape[0]
# Out:
# 745579

# %% [markdown]
# On the other hand, all of the original tweets have an original tweet id equal to 0

# %%
df.loc[df['is_retweet']==False].shape
# Out:
# (880241, 21)

# %%
df.loc[(df['is_retweet']==False) & (df['original_tweet_id']==0)].shape[0]
# Out:
# 880241

# %% [markdown]
# Hence is_retweet column is redundant given the original_tweet_id column and can be safely dropped. We are also going to drop the index, masked_username, extractedts columns since they do not offer any meaning to our analysis

# %%
df.drop(['Unnamed: 0', 'masked_username', 'extractedts', 'is_retweet', 'language'], inplace=True, axis=1)

# %% [markdown]
# Since it is not clear, to me at least, what the "is_quote_status" column indicates, I am going to keep only the rows that are not a quote_status and drop all the relevant columns from the dataset

# %%
df['is_quote_status'].value_counts()
# Out:
# False    1545947
# True       79873
# Name: is_quote_status, dtype: int64

# %%
df = df.loc[df['is_quote_status'] == False]

# %%
df.drop(['in_reply_to_status_id', 'is_quote_status', 'quoted_status_id'], inplace=True, axis=1)

# %%
df.drop_duplicates(inplace=True) #drop any duplicated records

# %%
df.shape[0] #After the above pre-processing we have 1.5M rows left
# Out:
# 1545947

# %% [markdown]
# We explore the hashtags column so to discover whether it can help us in our analysis.

# %%
import ast
list_of_hashtags = []
for i in range(df.shape[0]):    
    if i % 1000 == 0:
        print("Progress made: ", i/df.shape[0]*100, '%')
    hashtags = ast.literal_eval(df['hashtags'].iloc[i])
    for hash in hashtags:
        list_of_hashtags.append(hash['text'])
# Out:
# Progress made:  0.0 %
# Progress made:  0.0646852705817211 %
# Progress made:  0.1293705411634422 %
# Progress made:  0.19405581174516331 %
# Progress made:  0.2587410823268844 %
# Progress made:  0.3234263529086055 %
# Progress made:  0.38811162349032663 %
# Progress made:  0.45279689407204776 %
# Progress made:  0.5174821646537688 %
# Progress made:  0.58216743523549 %
# Progress made:  0.646852705817211 %
# Progress made:  0.7115379763989322 %
# Progress made:  0.7762232469806533 %
# Progress made:  0.8409085175623743 %
# Progress made:  0.9055937881440955 %
# Progress made:  0.9702790587258167 %
# Progress made:  1.0349643293075377 %
# Progress made:  1.0996495998892588 %
# Progress made:  1.16433487047098 %
# Progress made:  1.229020141052701 %
# Progress made:  1.293705411634422 %
# Progress made:  1.3583906822161433 %
# Progress made:  1.4230759527978645 %
# Progress made:  1.4877612233795854 %
# Progress made:  1.5524464939613065 %
# Progress made:  1.6171317645430276 %
# Progress made:  1.6818170351247486 %
# Progress made:  1.74650230570647 %
# Progress made:  1.811187576288191 %
# Progress made:  1.875872846869912 %
# Progress made:  1.9405581174516333 %
# Progress made:  2.0052433880333544 %
# Progress made:  2.0699286586150754 %
# Progress made:  2.1346139291967963 %
# Progress made:  2.1992991997785176 %
# Progress made:  2.2639844703602385 %
# Progress made:  2.32866974094196 %
# Progress made:  2.3933550115236812 %
# Progress made:  2.458040282105402 %
# Progress made:  2.522725552687123 %
# Progress made:  2.587410823268844 %
# Progress made:  2.6520960938505653 %
# Progress made:  2.7167813644322867 %
# Progress made:  2.7814666350140076 %
# Progress made:  2.846151905595729 %
# Progress made:  2.91083717617745 %
# Progress made:  2.9755224467591708 %
# Progress made:  3.0402077173408917 %
# Progress made:  3.104892987922613 %
# Progress made:  3.169578258504334 %
# Progress made:  3.2342635290860553 %
# Progress made:  3.2989487996677767 %
# Progress made:  3.363634070249497 %
# Progress made:  3.4283193408312185 %
# Progress made:  3.49300461141294 %
# Progress made:  3.5576898819946607 %
# Progress made:  3.622375152576382 %
# Progress made:  3.6870604231581035 %
# Progress made:  3.751745693739824 %
# Progress made:  3.8164309643215453 %
# Progress made:  3.8811162349032666 %
# Progress made:  3.9458015054849875 %
# Progress made:  4.010486776066709 %
# Progress made:  4.075172046648429 %
# Progress made:  4.139857317230151 %
# Progress made:  4.204542587811872 %
# Progress made:  4.2692278583935925 %
# Progress made:  4.333913128975314 %
# Progress made:  4.398598399557035 %
# Progress made:  97.73944384898059 %
# Progress made:  97.8041291195623 %
# Progress made:  97.86881439014404 %
# Progress made:  97.93349966072576 %
# Progress made:  97.99818493130748 %
# Progress made:  98.0628702018892 %
# Progress made:  98.12755547247092 %
# Progress made:  98.19224074305264 %
# Progress made:  98.25692601363436 %
# Progress made:  98.32161128421608 %
# Progress made:  98.38629655479781 %
# Progress made:  98.45098182537953 %
# Progress made:  98.51566709596125 %
# Progress made:  98.58035236654297 %
# Progress made:  98.64503763712469 %
# Progress made:  98.70972290770641 %
# Progress made:  98.77440817828813 %
# Progress made:  98.83909344886985 %
# Progress made:  98.90377871945158 %
# Progress made:  98.9684639900333 %
# Progress made:  99.03314926061502 %
# Progress made:  99.09783453119674 %
# Progress made:  99.16251980177846 %
# Progress made:  99.22720507236018 %
# Progress made:  99.2918903429419 %
# Progress made:  99.35657561352362 %
# Progress made:  99.42126088410535 %
# Progress made:  99.48594615468707 %
# Progress made:  99.55063142526879 %
# Progress made:  99.61531669585051 %
# Progress made:  99.68000196643223 %
# Progress made:  99.74468723701395 %
# Progress made:  99.80937250759567 %
# Progress made:  99.87405777817739 %
# Progress made:  99.93874304875912 %

# %%
list_of_hashtags_uniques = list(set(list_of_hashtags))

# %%
list_of_hashtags_uniques[:10] #Let's print some hashtags
# Out:
# ['highefficiencyai',
#  'MoCA',
#  'GoogleDoc',
#  'prolawgue',
#  'MicrosoftPartnerCommunity',
#  'Happy_Birthday',
#  'chartistjs',
#  'workstream',
#  'educationsector',
#  'twixorsolutions']

# %%
len(list_of_hashtags_uniques) #Overall, we have 215369 unique hashtags
# Out:
# 215369

# %%
list_of_hashtags_uniques.sort()

# %%
new_list_of_hashtags_uniques = []
for hash in list_of_hashtags_uniques:
    new_list_of_hashtags_uniques.append(hash.lower())

# %% [markdown]
# Overall, there exist 911 distinct hashtags about AWS, surpassing the corresponding number for Azure - 672 and for Google - 474.

# %%
len([x for x in new_list_of_hashtags_uniques if 'aws' in x])
# Out:
# 911

# %%
len([x for x in new_list_of_hashtags_uniques if 'azure' in x])
# Out:
# 672

# %%
len([x for x in new_list_of_hashtags_uniques if 'google' in x])
# Out:
# 474

# %% [markdown]
# We explore the tweetcreatedts_new column to discover whether it has to add anything meaningful in our analysis.

# %% [markdown]
# Given that the time window is just 3 months we cannot extract any meaningful trends from it.

# %%
df['tweetcreatedts_new'] = pd.to_datetime(df['tweetcreatedts'])

# %%
df['tweetcreatedts_date'] = df['tweetcreatedts_new'].dt.date

# %%
df['tweetcreatedts_date'].min()
# Out:
# datetime.date(2022, 4, 23)

# %%
df['tweetcreatedts_date'].max()
# Out:
# datetime.date(2022, 6, 19)

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Handling NAs

# %% [markdown]
# We are going to check for the existence of NAs and handle them appropriately

# %%
df.isnull().sum() #The location column contains some null values
# Out:
# hashed_userid               0
# location               504529
# following                   0
# followers                   0
# totaltweets                 0
# usercreatedts               0
# tweetid                     0
# tweetcreatedts              0
# retweetcount                0
# text                        0
# hashtags                    0
# favorite_count              0
# original_tweet_id           0
# tweetcreatedts_new          0
# tweetcreatedts_date         0
# dtype: int64

# %%
df['location'] = df['location'].fillna('') #We handle NAs by filling them with the empty string

# %% [markdown]
# #### Feature Creation

# %% [markdown]
# We are going to bring information about each tweet's country of origin. To do so, we first of all load a dataset that contains the names of most existing countries and then we search for the name of each country in the location column of our data

# %%
countries = pd.read_excel(r'Tweets_on_cloud_services_data\countries.xlsx')

# %%
countries
# Out:
#          Country
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# 3        Andorra
# 4         Angola
# ..           ...
# 190    Venezuela
# 191      Vietnam
# 192        Yemen
# 193       Zambia
# 194     Zimbabwe
#
# [195 rows x 1 columns]

# %% [markdown]
# We are going to traverse through the "location" column of our dataset and search whether it contains the name of an existing country, so that we can then know the country of origin for the particular tweet

# %%
list_of_countries = list(countries['Country'])
country = []
for i in range(df.shape[0]):    
    flag = 'not Resolved'
    if df['location'].iloc[i] == '':
        country.append('Cannot resolve country')
        continue
    if i % 1000 == 0 and i != 0:
        print('Completed ', i / df.shape[0] * 100, '% of the dataset')
        print('Amount of resolved countries: ', (len(country) - country.count('Cannot resolve country')) / len(country) * 100 ) 
    try:
        for cntr in list_of_countries:        
            if cntr in df['location'].iloc[i]:
                country.append(cntr)
                flag = 'Resolved'
                break
        if flag != 'Resolved':
            country.append('Cannot resolve country')
    except Exception as e:
        print(e)        
        country.append('Cannot resolve country')
# Out:
# Completed  0.09602292259208119 % of the dataset
# Amount of resolved countries:  22.5
# Completed  0.19204584518416237 % of the dataset
# Amount of resolved countries:  21.85
# Completed  0.2880687677762435 % of the dataset
# Amount of resolved countries:  23.333333333333332
# Completed  0.38409169036832475 % of the dataset
# Amount of resolved countries:  24.099999999999998
# Completed  0.4801146129604059 % of the dataset
# Amount of resolved countries:  24.4
# Completed  0.576137535552487 % of the dataset
# Amount of resolved countries:  24.8
# Completed  0.6721604581445683 % of the dataset
# Amount of resolved countries:  25.185714285714283
# Completed  0.8642063033287307 % of the dataset
# Amount of resolved countries:  25.211111111111112
# Completed  0.9602292259208118 % of the dataset
# Amount of resolved countries:  26.029999999999998
# Completed  1.056252148512893 % of the dataset
# Amount of resolved countries:  26.445454545454545
# Completed  1.152275071104974 % of the dataset
# Amount of resolved countries:  26.516666666666666
# Completed  1.2482979936970553 % of the dataset
# Amount of resolved countries:  25.92307692307692
# Completed  1.3443209162891365 % of the dataset
# Amount of resolved countries:  25.47142857142857
# Completed  1.536366761473299 % of the dataset
# Amount of resolved countries:  24.675
# Completed  1.6323896840653802 % of the dataset
# Amount of resolved countries:  24.54705882352941
# Completed  1.8244355292495424 % of the dataset
# Amount of resolved countries:  24.278947368421054
# Completed  1.9204584518416237 % of the dataset
# Amount of resolved countries:  24.255
# Completed  2.0164813744337047 % of the dataset
# Amount of resolved countries:  24.176190476190477
# Completed  2.112504297025786 % of the dataset
# Amount of resolved countries:  24.263636363636365
# Completed  2.208527219617867 % of the dataset
# Amount of resolved countries:  24.465217391304346
# Completed  2.304550142209948 % of the dataset
# Amount of resolved countries:  24.25
# Completed  2.4005730648020296 % of the dataset
# Amount of resolved countries:  24.372
# Completed  2.4965959873941106 % of the dataset
# Amount of resolved countries:  24.3
# Completed  2.592618909986192 % of the dataset
# Amount of resolved countries:  24.355555555555554
# Completed  2.688641832578273 % of the dataset
# Amount of resolved countries:  24.28214285714286
# Completed  2.784664755170354 % of the dataset
# Amount of resolved countries:  24.186206896551724
# Completed  2.8806876777624355 % of the dataset
# Amount of resolved countries:  23.973333333333333
# Completed  2.9767106003545165 % of the dataset
# Amount of resolved countries:  23.90967741935484
# Completed  3.072733522946598 % of the dataset
# Amount of resolved countries:  23.753125
# Completed  3.1687564455386794 % of the dataset
# Amount of resolved countries:  23.715151515151515
# Completed  3.360802290722841 % of the dataset
# Amount of resolved countries:  23.60857142857143
# Completed  3.456825213314923 % of the dataset
# Amount of resolved countries:  23.591666666666665
# Completed  3.552848135907004 % of the dataset
# Amount of resolved countries:  23.440540540540542
# Completed  3.648871058499085 % of the dataset
# Amount of resolved countries:  23.36578947368421
# Completed  3.744893981091166 % of the dataset
# Amount of resolved countries:  23.425641025641024
# Completed  3.8409169036832473 % of the dataset
# Amount of resolved countries:  23.4875
# Completed  4.032962748867409 % of the dataset
# Amount of resolved countries:  23.62857142857143
# Completed  4.225008594051572 % of the dataset
# Amount of resolved countries:  23.852272727272727
# Completed  4.321031516643653 % of the dataset
# Amount of resolved countries:  23.90888888888889
# Completed  4.801146129604059 % of the dataset
# Amount of resolved countries:  24.544
# Completed  4.897169052196141 % of the dataset
# Amount of resolved countries:  24.701960784313727
# Completed  5.185237819972384 % of the dataset
# Amount of resolved countries:  25.051851851851854
# Completed  5.281260742564465 % of the dataset
# Amount of resolved countries:  25.154545454545456
# Completed  5.377283665156546 % of the dataset
# Amount of resolved countries:  25.22142857142857
# Completed  5.4733065877486275 % of the dataset
# Amount of resolved countries:  25.308771929824562
# Completed  5.569329510340708 % of the dataset
# Amount of resolved countries:  25.331034482758618
# Completed  5.66535243293279 % of the dataset
# Amount of resolved countries:  25.438983050847458
# Completed  5.761375355524871 % of the dataset
# Amount of resolved countries:  25.435000000000002
# Completed  5.8573982781169525 % of the dataset
# Amount of resolved countries:  25.43770491803279
# Completed  6.337512891077359 % of the dataset
# Amount of resolved countries:  25.024242424242427
# Completed  6.4335358136694385 % of the dataset
# Amount of resolved countries:  25.028358208955225
# Completed  6.529558736261521 % of the dataset
# Amount of resolved countries:  24.985294117647058
# Completed  6.625581658853602 % of the dataset
# Amount of resolved countries:  24.946376811594202
# Completed  6.721604581445682 % of the dataset
# Amount of resolved countries:  24.9
# Completed  6.913650426629846 % of the dataset
# Amount of resolved countries:  24.630555555555556
# Completed  7.009673349221926 % of the dataset
# Amount of resolved countries:  24.594520547945205
# Completed  7.201719194406088 % of the dataset
# Amount of resolved countries:  24.490666666666666
# Completed  7.29774211699817 % of the dataset
# Amount of resolved countries:  24.426315789473684
# Completed  7.393765039590251 % of the dataset
# Amount of resolved countries:  24.337662337662337
# Completed  7.585810884774413 % of the dataset
# Completed  12.867071627338877 % of the dataset
# Amount of resolved countries:  23.573880597014927
# Completed  12.96309454993096 % of the dataset
# Amount of resolved countries:  23.533333333333335
# Completed  13.059117472523042 % of the dataset
# Amount of resolved countries:  23.50294117647059
# Completed  13.155140395115122 % of the dataset
# Amount of resolved countries:  23.475912408759125
# Completed  13.347186240299283 % of the dataset
# Amount of resolved countries:  23.438129496402876
# Completed  13.539232085483446 % of the dataset
# Amount of resolved countries:  23.370212765957447
# Completed  13.635255008075529 % of the dataset
# Amount of resolved countries:  23.345070422535212
# Completed  13.92332377585177 % of the dataset
# Amount of resolved countries:  23.384827586206896
# Completed  14.019346698443853 % of the dataset
# Amount of resolved countries:  23.404794520547945
# Completed  14.115369621035933 % of the dataset
# Amount of resolved countries:  23.43401360544218
# Completed  14.211392543628016 % of the dataset
# Amount of resolved countries:  23.470945945945946
# Completed  14.499461311404257 % of the dataset
# Amount of resolved countries:  23.572847682119207
# Completed  14.59548423399634 % of the dataset
# Amount of resolved countries:  23.58157894736842
# Completed  15.075598846956744 % of the dataset
# Amount of resolved countries:  23.81656050955414
# Completed  15.171621769548826 % of the dataset
# Amount of resolved countries:  23.819620253164555
# Completed  15.267644692140909 % of the dataset
# Amount of resolved countries:  23.830188679245285
# Completed  15.459690537325072 % of the dataset
# Amount of resolved countries:  23.84223602484472
# Completed  15.55571345991715 % of the dataset
# Amount of resolved countries:  23.811728395061728
# Completed  15.651736382509233 % of the dataset
# Amount of resolved countries:  23.792638036809816
# Completed  15.747759305101313 % of the dataset
# Amount of resolved countries:  23.78292682926829
# Completed  16.227873918061718 % of the dataset
# Amount of resolved countries:  23.73076923076923
# Completed  16.323896840653802 % of the dataset
# Amount of resolved countries:  23.708235294117646
# Completed  16.419919763245883 % of the dataset
# Amount of resolved countries:  23.70175438596491
# Completed  16.611965608430044 % of the dataset
# Amount of resolved countries:  23.635260115606936
# Completed  16.707988531022124 % of the dataset
# Amount of resolved countries:  23.628735632183908
# Completed  16.804011453614205 % of the dataset
# Amount of resolved countries:  23.613142857142858
# Completed  16.99605729879837 % of the dataset
# Amount of resolved countries:  23.533898305084747
# Completed  17.09208022139045 % of the dataset
# Amount of resolved countries:  23.538764044943818
# Completed  17.18810314398253 % of the dataset
# Amount of resolved countries:  23.51284916201117
# Completed  17.380148989166695 % of the dataset
# Amount of resolved countries:  23.486740331491713
# Completed  17.476171911758776 % of the dataset
# Amount of resolved countries:  23.47142857142857
# Completed  17.572194834350856 % of the dataset
# Amount of resolved countries:  23.446994535519124
# Completed  17.764240679535018 % of the dataset
# Amount of resolved countries:  23.404864864864866
# Completed  17.860263602127098 % of the dataset
# Amount of resolved countries:  23.38064516129032
# Completed  17.956286524719182 % of the dataset
# Amount of resolved countries:  23.36042780748663
# Completed  18.052309447311263 % of the dataset
# Amount of resolved countries:  23.32712765957447
# Completed  18.244355292495424 % of the dataset
# Amount of resolved countries:  23.25842105263158
# Completed  18.340378215087505 % of the dataset
# Amount of resolved countries:  23.225130890052355
# Completed  18.53242406027167 % of the dataset
# Amount of resolved countries:  23.17305699481865
# Completed  18.62844698286375 % of the dataset
# Amount of resolved countries:  23.147422680412372
# Completed  18.82049282804791 % of the dataset
# Amount of resolved countries:  23.13112244897959
# Completed  18.91651575063999 % of the dataset
# Amount of resolved countries:  23.153807106598983
# Completed  19.012538673232076 % of the dataset
# Amount of resolved countries:  23.143434343434343
# Completed  19.108561595824156 % of the dataset
# Amount of resolved countries:  23.145728643216078
# Completed  19.49265328619248 % of the dataset
# Amount of resolved countries:  23.269458128078817
# Completed  19.684699131376643 % of the dataset
# Amount of resolved countries:  23.29121951219512
# Completed  19.876744976560804 % of the dataset
# Amount of resolved countries:  23.25458937198068
# Completed  19.972767899152885 % of the dataset
# Amount of resolved countries:  23.25721153846154
# Completed  20.068790821744965 % of the dataset
# Amount of resolved countries:  23.25885167464115
# Completed  20.16481374433705 % of the dataset
# Amount of resolved countries:  23.27095238095238
# Completed  20.26083666692913 % of the dataset
# Amount of resolved countries:  23.27251184834123
# Completed  20.45288251211329 % of the dataset
# Amount of resolved countries:  23.215023474178402
# Completed  20.644928357297452 % of the dataset
# Amount of resolved countries:  23.183255813953487
# Completed  20.836974202481617 % of the dataset
# Amount of resolved countries:  23.23548387096774
# Completed  20.932997125073697 % of the dataset
# Amount of resolved countries:  23.25229357798165
# Completed  21.029020047665778 % of the dataset
# Amount of resolved countries:  23.239269406392694
# Completed  21.12504297025786 % of the dataset
# Amount of resolved countries:  23.237727272727273
# Completed  21.221065892849943 % of the dataset
# Amount of resolved countries:  23.214027149321268
# Completed  21.317088815442023 % of the dataset
# Amount of resolved countries:  23.194144144144143
# Completed  21.413111738034104 % of the dataset
# Amount of resolved countries:  23.19596412556054
# Completed  21.605157583218265 % of the dataset
# Amount of resolved countries:  23.207555555555555
# Completed  21.98924927358659 % of the dataset
# Amount of resolved countries:  23.141484716157205
# Completed  22.08527219617867 % of the dataset
# Amount of resolved countries:  23.130434782608695
# Completed  22.181295118770752 % of the dataset
# Amount of resolved countries:  23.10952380952381
# Completed  22.277318041362832 % of the dataset
# Amount of resolved countries:  23.069827586206895
# Completed  22.373340963954917 % of the dataset
# Amount of resolved countries:  23.04206008583691
# Completed  22.469363886546997 % of the dataset
# Amount of resolved countries:  23.02905982905983
# Completed  22.66140973173116 % of the dataset
# Amount of resolved countries:  23.010169491525424
# Completed  23.045501422099484 % of the dataset
# Amount of resolved countries:  22.972083333333334
# Completed  23.141524344691565 % of the dataset
# Amount of resolved countries:  22.963070539419085
# Completed  23.237547267283645 % of the dataset
# Amount of resolved countries:  22.947107438016527
# Completed  23.333570189875726 % of the dataset
# Amount of resolved countries:  22.93292181069959
# Completed  23.42959311246781 % of the dataset
# Amount of resolved countries:  22.92459016393443
# Completed  23.71766188024405 % of the dataset
# Amount of resolved countries:  22.900000000000002
# Completed  23.813684802836132 % of the dataset
# Amount of resolved countries:  22.901209677419352
# Completed  23.909707725428213 % of the dataset
# Amount of resolved countries:  22.910441767068274
# Completed  24.005730648020297 % of the dataset
# Completed  35.912573049438365 % of the dataset
# Amount of resolved countries:  21.544919786096255
# Completed  36.00859597203044 % of the dataset
# Amount of resolved countries:  21.548000000000002
# Completed  36.104618894622526 % of the dataset
# Amount of resolved countries:  21.550797872340425
# Completed  36.29666473980669 % of the dataset
# Amount of resolved countries:  21.547883597883597
# Completed  36.39268766239877 % of the dataset
# Amount of resolved countries:  21.537994722955144
# Completed  36.584733507582925 % of the dataset
# Amount of resolved countries:  21.518635170603677
# Completed  36.77677935276709 % of the dataset
# Amount of resolved countries:  21.503916449086162
# Completed  36.87280227535917 % of the dataset
# Amount of resolved countries:  21.497395833333332
# Completed  36.968825197951254 % of the dataset
# Amount of resolved countries:  21.488051948051947
# Completed  37.06484812054334 % of the dataset
# Amount of resolved countries:  21.509067357512954
# Completed  37.160871043135415 % of the dataset
# Amount of resolved countries:  21.518863049095607
# Completed  37.44893981091166 % of the dataset
# Amount of resolved countries:  21.567692307692308
# Completed  37.54496273350374 % of the dataset
# Amount of resolved countries:  21.58286445012788
# Completed  37.737008578687906 % of the dataset
# Amount of resolved countries:  21.617557251908398
# Completed  37.92905442387207 % of the dataset
# Amount of resolved countries:  21.648354430379747
# Completed  38.02507734646415 % of the dataset
# Amount of resolved countries:  21.635858585858585
# Completed  38.12110026905623 % of the dataset
# Amount of resolved countries:  21.634508816120906
# Completed  38.313146114240396 % of the dataset
# Amount of resolved countries:  21.62280701754386
# Completed  38.69723780460871 % of the dataset
# Amount of resolved countries:  21.59925558312655
# Completed  38.793260727200796 % of the dataset
# Amount of resolved countries:  21.59059405940594
# Completed  38.88928364979288 % of the dataset
# Amount of resolved countries:  21.582716049382718
# Completed  39.177352417569125 % of the dataset
# Amount of resolved countries:  21.569607843137256
# Completed  39.2733753401612 % of the dataset
# Amount of resolved countries:  21.576772616136918
# Completed  39.56144410793745 % of the dataset
# Amount of resolved countries:  21.584708737864077
# Completed  39.75348995312161 % of the dataset
# Amount of resolved countries:  21.583816425120773
# Completed  39.849512875713685 % of the dataset
# Amount of resolved countries:  21.591084337349397
# Completed  40.041558720897854 % of the dataset
# Amount of resolved countries:  21.60791366906475
# Completed  40.233604566082015 % of the dataset
# Amount of resolved countries:  21.63054892601432
# Completed  40.3296274886741 % of the dataset
# Amount of resolved countries:  21.65809523809524
# Completed  40.425650411266176 % of the dataset
# Amount of resolved countries:  21.670783847981
# Completed  40.8097421016345 % of the dataset
# Amount of resolved countries:  21.671058823529414
# Completed  40.90576502422658 % of the dataset
# Amount of resolved countries:  21.665258215962442
# Completed  41.001787946818666 % of the dataset
# Amount of resolved countries:  21.66651053864169
# Completed  41.19383379200283 % of the dataset
# Amount of resolved countries:  21.66083916083916
# Completed  41.289856714594904 % of the dataset
# Amount of resolved countries:  21.656511627906976
# Completed  41.38587963718699 % of the dataset
# Amount of resolved countries:  21.64802784222738
# Completed  41.48190255977907 % of the dataset
# Amount of resolved countries:  21.63912037037037
# Completed  41.57792548237115 % of the dataset
# Amount of resolved countries:  21.643879907621248
# Completed  41.865994250147395 % of the dataset
# Amount of resolved countries:  21.644954128440368
# Completed  41.96201717273947 % of the dataset
# Amount of resolved countries:  21.655606407322654
# Completed  42.058040095331556 % of the dataset
# Amount of resolved countries:  21.670547945205477
# Completed  42.15406301792364 % of the dataset
# Amount of resolved countries:  21.690432801822325
# Completed  42.25008594051572 % of the dataset
# Amount of resolved countries:  21.69840909090909
# Completed  42.3461088631078 % of the dataset
# Amount of resolved countries:  21.707256235827664
# Completed  42.442131785699885 % of the dataset
# Amount of resolved countries:  21.708371040723982
# Completed  42.53815470829196 % of the dataset
# Amount of resolved countries:  21.700902934537247
# Completed  42.63417763088405 % of the dataset
# Amount of resolved countries:  21.69436936936937
# Completed  42.73020055347613 % of the dataset
# Amount of resolved countries:  21.704269662921348
# Completed  42.92224639866029 % of the dataset
# Amount of resolved countries:  21.70201342281879
# Completed  43.01826932125237 % of the dataset
# Amount of resolved countries:  21.704910714285713
# Completed  43.306338089028614 % of the dataset
# Amount of resolved countries:  21.714634146341464
# Completed  43.59440685680486 % of the dataset
# Amount of resolved countries:  21.718942731277533
# Completed  43.78645270198902 % of the dataset
# Amount of resolved countries:  21.758552631578947
# Completed  43.882475624581105 % of the dataset
# Amount of resolved countries:  21.774398249452954
# Completed  44.07452146976526 % of the dataset
# Amount of resolved countries:  21.798039215686273
# Completed  44.17054439235734 % of the dataset
# Amount of resolved countries:  21.81434782608696
# Completed  44.26656731494943 % of the dataset
# Amount of resolved countries:  21.8236442516269
# Completed  44.45861316013359 % of the dataset
# Amount of resolved countries:  21.85313174946004
# Completed  44.65065900531775 % of the dataset
# Amount of resolved countries:  21.891827956989246
# Completed  44.74668192790983 % of the dataset
# Amount of resolved countries:  21.896995708154506
# Completed  45.03475069568608 % of the dataset
# Amount of resolved countries:  21.949040511727077
# Completed  45.130773618278155 % of the dataset
# Amount of resolved countries:  21.963404255319148
# Completed  45.22679654087023 % of the dataset
# Amount of resolved countries:  21.96772823779193
# Completed  45.32281946346232 % of the dataset
# Amount of resolved countries:  21.965254237288136
# Completed  45.4188423860544 % of the dataset
# Amount of resolved countries:  21.961310782241014
# Completed  45.51486530864648 % of the dataset
# Amount of resolved countries:  21.96729957805907
# Completed  45.61088823123856 % of the dataset
# Amount of resolved countries:  21.965052631578946
# Completed  45.706911153830646 % of the dataset
# Amount of resolved countries:  21.967436974789916
# Completed  45.80293407642272 % of the dataset
# Amount of resolved countries:  21.962893081761006
# Completed  46.09100284419897 % of the dataset
# Amount of resolved countries:  21.94
# Completed  46.18702576679105 % of the dataset
# Amount of resolved countries:  21.936590436590436
# Completed  46.28304868938313 % of the dataset
# Amount of resolved countries:  21.927178423236516
# Completed  46.379071611975206 % of the dataset
# Amount of resolved countries:  21.91697722567288
# Completed  46.47509453456729 % of the dataset
# Amount of resolved countries:  21.90909090909091
# Completed  46.763163302343536 % of the dataset
# Amount of resolved countries:  21.897330595482547
# Completed  47.05123207011978 % of the dataset
# Amount of resolved countries:  21.863673469387752
# Completed  47.147254992711865 % of the dataset
# Amount of resolved countries:  21.85010183299389
# Completed  47.627369605672264 % of the dataset
# Amount of resolved countries:  21.818548387096776
# Completed  47.91543837344851 % of the dataset
# Amount of resolved countries:  21.804609218436873
# Completed  48.01146129604059 % of the dataset
# Amount of resolved countries:  21.807399999999998
# Completed  48.10748421863267 % of the dataset
# Amount of resolved countries:  21.824750499001997
# Completed  48.203507141224755 % of the dataset
# Amount of resolved countries:  21.838645418326692
# Completed  48.29953006381684 % of the dataset
# Amount of resolved countries:  21.850298210735588
# Completed  48.395552986408916 % of the dataset
# Amount of resolved countries:  21.856349206349208
# Completed  48.971690521961406 % of the dataset
# Amount of resolved countries:  21.897254901960782
# Completed  49.06771344455348 % of the dataset
# Amount of resolved countries:  21.92074363992172
# Completed  49.16373636714557 % of the dataset
# Amount of resolved countries:  21.9248046875
# Completed  49.35578221232973 % of the dataset
# Amount of resolved countries:  21.931517509727627
# Completed  49.45180513492181 % of the dataset
# Amount of resolved countries:  21.936504854368934
# Completed  49.73987390269805 % of the dataset
# Amount of resolved countries:  21.94131274131274
# Completed  49.93191974788221 % of the dataset
# Amount of resolved countries:  21.93769230769231
# Completed  50.02794267047429 % of the dataset
# Amount of resolved countries:  21.938771593090213
# Completed  50.12396559306638 % of the dataset
# Amount of resolved countries:  21.9316091954023
# Completed  50.21998851565846 % of the dataset
# Amount of resolved countries:  21.92657743785851
# Completed  50.31601143825054 % of the dataset
# Amount of resolved countries:  21.9162213740458
# Completed  50.41203436084262 % of the dataset
# Amount of resolved countries:  21.908
# Completed  50.5080572834347 % of the dataset
# Amount of resolved countries:  21.898669201520914
# Completed  50.60408020602678 % of the dataset
# Amount of resolved countries:  21.894307400379507
# Completed  50.70010312861887 % of the dataset
# Amount of resolved countries:  21.88655303030303
# Completed  50.98817189639511 % of the dataset
# Amount of resolved countries:  21.862900188323916
# Completed  51.08419481898719 % of the dataset
# Amount of resolved countries:  21.849624060150376
# Completed  51.18021774157927 % of the dataset
# Amount of resolved countries:  21.85403377110694
# Completed  51.27624066417135 % of the dataset
# Amount of resolved countries:  21.86310861423221
# Completed  51.37226358676343 % of the dataset
# Amount of resolved countries:  21.873457943925235
# Completed  51.5643094319476 % of the dataset
# Amount of resolved countries:  21.907821229050278
# Completed  51.660332354539676 % of the dataset
# Amount of resolved countries:  21.91635687732342
# Completed  51.75635527713176 % of the dataset
# Amount of resolved countries:  21.931725417439704
# Completed  51.94840112231592 % of the dataset
# Amount of resolved countries:  21.956931608133086
# Completed  52.14044696750009 % of the dataset
# Amount of resolved countries:  21.977348066298344
# Completed  52.33249281268424 % of the dataset
# Amount of resolved countries:  21.984770642201834
# Completed  52.42851573527633 % of the dataset
# Amount of resolved countries:  21.989560439560442
# Completed  52.524538657868405 % of the dataset
# Amount of resolved countries:  21.989396709323582
# Completed  52.716584503052566 % of the dataset
# Amount of resolved countries:  21.977777777777778
# Completed  52.90863034823673 % of the dataset
# Amount of resolved countries:  21.969147005444643
# Completed  53.00465327082882 % of the dataset
# Amount of resolved countries:  21.964492753623187
# Completed  53.292722038605056 % of the dataset
# Amount of resolved countries:  21.946846846846846
# Completed  53.38874496119713 % of the dataset
# Amount of resolved countries:  21.93273381294964
# Completed  53.48476788378922 % of the dataset
# Amount of resolved countries:  21.928725314183122
# Completed  53.580790806381295 % of the dataset
# Amount of resolved countries:  21.92383512544803
# Completed  53.676813728973386 % of the dataset
# Amount of resolved countries:  21.911985688729875
# Completed  53.772836651565456 % of the dataset
# Amount of resolved countries:  21.90625
# Completed  53.86885957415755 % of the dataset
# Amount of resolved countries:  21.90071301247772
# Completed  54.06090541934171 % of the dataset
# Amount of resolved countries:  21.90266429840142
# Completed  54.156928341933785 % of the dataset
# Amount of resolved countries:  21.912056737588653
# Completed  54.252951264525876 % of the dataset
# Amount of resolved countries:  21.92867256637168
# Completed  54.44499710971002 % of the dataset
# Amount of resolved countries:  21.954673721340388
# Completed  54.541020032302114 % of the dataset
# Amount of resolved countries:  21.957922535211267
# Completed  54.63704295489419 % of the dataset
# Amount of resolved countries:  21.96115992970123
# Completed  55.021134645262514 % of the dataset
# Amount of resolved countries:  21.978534031413613
# Completed  55.117157567854605 % of the dataset
# Amount of resolved countries:  21.9794425087108
# Completed  55.213180490446675 % of the dataset
# Amount of resolved countries:  21.973565217391304
# Completed  55.309203413038766 % of the dataset
# Amount of resolved countries:  21.973090277777775
# Completed  55.50124925822292 % of the dataset
# Amount of resolved countries:  21.97491349480969
# Completed  55.597272180815004 % of the dataset
# Amount of resolved countries:  21.97392055267703
# Completed  55.69329510340708 % of the dataset
# Amount of resolved countries:  21.97189655172414
# Completed  55.789318025999165 % of the dataset
# Amount of resolved countries:  21.96282271944923
# Completed  55.88534094859124 % of the dataset
# Amount of resolved countries:  21.955841924398626
# Completed  55.98136387118333 % of the dataset
# Amount of resolved countries:  21.950943396226418
# Completed  56.173409716367495 % of the dataset
# Amount of resolved countries:  21.957264957264957
# Completed  56.26943263895957 % of the dataset
# Amount of resolved countries:  21.95170648464164
# Completed  56.365455561551656 % of the dataset
# Amount of resolved countries:  21.947018739352643
# Completed  56.55750140673581 % of the dataset
# Amount of resolved countries:  21.93735144312394
# Completed  56.84557017451206 % of the dataset
# Amount of resolved countries:  21.916216216216217
# Completed  56.94159309710414 % of the dataset
# Amount of resolved countries:  21.904721753794266
# Completed  57.03761601969622 % of the dataset
# Amount of resolved countries:  21.895286195286197
# Completed  57.1336389422883 % of the dataset
# Amount of resolved countries:  21.885882352941177
# Completed  57.42170771006455 % of the dataset
# Amount of resolved countries:  21.892976588628763
# Completed  57.51773063265663 % of the dataset
# Amount of resolved countries:  21.897328881469118
# Completed  57.61375355524871 % of the dataset
# Amount of resolved countries:  21.909166666666664
# Completed  57.70977647784079 % of the dataset
# Amount of resolved countries:  21.913643926788687
# Completed  57.80579940043287 % of the dataset
# Amount of resolved countries:  21.916445182724253
# Completed  57.90182232302495 % of the dataset
# Amount of resolved countries:  21.91177446102819
# Completed  57.99784524561703 % of the dataset
# Amount of resolved countries:  21.906291390728477
# Completed  58.09386816820912 % of the dataset
# Completed  63.183083065589415 % of the dataset
# Amount of resolved countries:  21.63996960486322
# Completed  63.27910598818149 % of the dataset
# Amount of resolved countries:  21.638088012139605
# Completed  63.37512891077358 % of the dataset
# Amount of resolved countries:  21.643636363636364
# Completed  63.47115183336566 % of the dataset
# Amount of resolved countries:  21.649621785173977
# Completed  63.567174755957744 % of the dataset
# Amount of resolved countries:  21.65966767371601
# Completed  63.66319767854982 % of the dataset
# Amount of resolved countries:  21.659426847662143
# Completed  63.95126644632607 % of the dataset
# Amount of resolved countries:  21.672222222222224
# Completed  64.04728936891814 % of the dataset
# Amount of resolved countries:  21.67016491754123
# Completed  64.14331229151023 % of the dataset
# Amount of resolved countries:  21.671706586826346
# Completed  64.43138105928648 % of the dataset
# Amount of resolved countries:  21.66199701937407
# Completed  64.52740398187855 % of the dataset
# Amount of resolved countries:  21.667113095238093
# Completed  64.62342690447063 % of the dataset
# Amount of resolved countries:  21.662704309063894
# Completed  64.71944982706272 % of the dataset
# Amount of resolved countries:  21.66127596439169
# Completed  64.8154727496548 % of the dataset
# Amount of resolved countries:  21.660592592592593
# Completed  64.91149567224687 % of the dataset
# Amount of resolved countries:  21.667455621301777
# Completed  65.00751859483897 % of the dataset
# Amount of resolved countries:  21.667799113737075
# Completed  65.10354151743104 % of the dataset
# Amount of resolved countries:  21.66401179941003
# Completed  65.19956444002312 % of the dataset
# Amount of resolved countries:  21.66642120765832
# Completed  65.29558736261521 % of the dataset
# Amount of resolved countries:  21.665588235294116
# Completed  65.48763320779936 % of the dataset
# Amount of resolved countries:  21.657624633431087
# Completed  65.58365613039145 % of the dataset
# Amount of resolved countries:  21.655051244509515
# Completed  65.7757019755756 % of the dataset
# Amount of resolved countries:  21.63941605839416
# Completed  65.8717248981677 % of the dataset
# Amount of resolved countries:  21.634839650145775
# Completed  65.96774782075977 % of the dataset
# Amount of resolved countries:  21.63595342066958
# Completed  66.15979366594394 % of the dataset
# Amount of resolved countries:  21.65065312046444
# Completed  66.35183951112809 % of the dataset
# Amount of resolved countries:  21.637047756874097
# Completed  66.63990827890433 % of the dataset
# Amount of resolved countries:  21.612391930835734
# Completed  66.73593120149643 % of the dataset
# Amount of resolved countries:  21.605179856115107
# Completed  66.8319541240885 % of the dataset
# Amount of resolved countries:  21.59655172413793
# Completed  66.92797704668058 % of the dataset
# Amount of resolved countries:  21.592252510760403
# Completed  67.02399996927267 % of the dataset
# Amount of resolved countries:  21.59627507163324
# Completed  67.12002289186475 % of the dataset
# Amount of resolved countries:  21.599713876967098
# Completed  67.21604581445682 % of the dataset
# Amount of resolved countries:  21.59842857142857
# Completed  67.31206873704892 % of the dataset
# Amount of resolved countries:  21.60713266761769
# Completed  67.50411458223307 % of the dataset
# Amount of resolved countries:  21.612233285917494
# Completed  67.60013750482516 % of the dataset
# Amount of resolved countries:  21.61747159090909
# Completed  67.8882062726014 % of the dataset
# Amount of resolved countries:  21.641301272984443
# Completed  67.98422919519348 % of the dataset
# Amount of resolved countries:  21.645621468926553
# Completed  68.17627504037765 % of the dataset
# Completed  127.80650997006005 % of the dataset
# Amount of resolved countries:  20.73726521412472
# Completed  128.0945787378363 % of the dataset
# Amount of resolved countries:  20.73553223388306
# Completed  128.28662458302045 % of the dataset
# Amount of resolved countries:  20.73375748502994
# Completed  128.38264750561254 % of the dataset
# Amount of resolved countries:  20.734480179506356
# Completed  128.47867042820462 % of the dataset
# Amount of resolved countries:  20.73609865470852
# Completed  128.5746933507967 % of the dataset
# Amount of resolved countries:  20.732486930545182
# Completed  128.67071627338876 % of the dataset
# Amount of resolved countries:  20.729701492537313
# Completed  128.86276211857296 % of the dataset
# Amount of resolved countries:  20.728315946348733
# Completed  129.1508308863492 % of the dataset
# Amount of resolved countries:  20.716133828996284
# Completed  129.34287673153335 % of the dataset
# Amount of resolved countries:  20.71314031180401
# Completed  129.43889965412544 % of the dataset
# Amount of resolved countries:  20.718620178041544
# Completed  129.7269684219017 % of the dataset
# Amount of resolved countries:  20.720725388601036
# Completed  129.82299134449374 % of the dataset
# Amount of resolved countries:  20.719008875739643
# Completed  130.01503718967794 % of the dataset
# Amount of resolved countries:  20.71277695716396
# Completed  130.11106011227 % of the dataset
# Amount of resolved countries:  20.711955719557196
# Completed  130.20708303486208 % of the dataset
# Amount of resolved countries:  20.7117994100295
# Completed  130.59117472523042 % of the dataset
# Amount of resolved countries:  20.71375
# Completed  130.68719764782247 % of the dataset
# Amount of resolved countries:  20.715797207935342
# Completed  130.78322057041456 % of the dataset
# Amount of resolved countries:  20.712701908957413
# Completed  130.97526641559872 % of the dataset
# Amount of resolved countries:  20.709824046920822
# Completed  131.5514039511512 % of the dataset
# Amount of resolved countries:  20.691751824817516
# Completed  131.64742687374329 % of the dataset
# Amount of resolved countries:  20.68869438366156
# Completed  131.7434497963354 % of the dataset
# Amount of resolved countries:  20.687244897959182
# Completed  131.83947271892745 % of the dataset
# Amount of resolved countries:  20.682665695557173
# Completed  132.03151856411162 % of the dataset
# Amount of resolved countries:  20.67570909090909
# Completed  132.2235644092958 % of the dataset
# Amount of resolved countries:  20.667175018155408
# Completed  132.31958733188787 % of the dataset
# Amount of resolved countries:  20.6633526850508
# Completed  132.41561025447993 % of the dataset
# Amount of resolved countries:  20.662871646120376
# Completed  132.60765609966413 % of the dataset
# Amount of resolved countries:  20.663939174511224
# Completed  132.79970194484827 % of the dataset
# Amount of resolved countries:  20.671655820679682
# Completed  133.1837936352166 % of the dataset
# Amount of resolved countries:  20.691708723864455
# Completed  133.27981655780866 % of the dataset
# Amount of resolved countries:  20.696325648414984
# Completed  133.37583948040077 % of the dataset
# Amount of resolved countries:  20.697048236141107
# Completed  133.5678853255849 % of the dataset
# Amount of resolved countries:  20.69964054636952
# Completed  133.85595409336116 % of the dataset
# Amount of resolved countries:  20.6954806312769
# Completed  133.95197701595325 % of the dataset
# Amount of resolved countries:  20.692616487455197
# Completed  134.04799993854533 % of the dataset
# Amount of resolved countries:  20.689111747851
# Completed  134.33606870632158 % of the dataset
# Amount of resolved countries:  20.682844889206574
# Completed  134.52811455150572 % of the dataset
# Amount of resolved countries:  20.677658815132048
# Completed  134.62413747409784 % of the dataset
# Amount of resolved countries:  20.676248216833095
# Completed  134.7201603966899 % of the dataset
# Amount of resolved countries:  20.671133285816108
# Completed  134.81618331928198 % of the dataset
# Amount of resolved countries:  20.666239316239317
# Completed  135.00822916446614 % of the dataset
# Amount of resolved countries:  20.65810810810811
# Completed  135.10425208705823 % of the dataset
# Amount of resolved countries:  20.65081734186212
# Completed  135.2962979322424 % of the dataset
# Amount of resolved countries:  20.644215755855218
# Completed  135.39232085483445 % of the dataset
# Amount of resolved countries:  20.643971631205673
# Completed  135.58436670001862 % of the dataset
# Amount of resolved countries:  20.652903682719547
# Completed  135.7764125452028 % of the dataset
# Amount of resolved countries:  20.66046676096181
# Completed  135.96845839038696 % of the dataset
# Amount of resolved countries:  20.669985875706214
# Completed  136.06448131297904 % of the dataset
# Amount of resolved countries:  20.67148906139732
# Completed  136.16050423557112 % of the dataset
# Amount of resolved countries:  20.672849083215798
# Completed  136.25652715816318 % of the dataset
# Amount of resolved countries:  20.673572938689215
# Completed  136.44857300334735 % of the dataset
# Amount of resolved countries:  20.675017593244192
# Completed  136.83266469371569 % of the dataset
# Amount of resolved countries:  20.671017543859648
# Completed  137.02471053889985 % of the dataset
# Amount of resolved countries:  20.670777855641205
# Completed  137.1207334614919 % of the dataset
# Amount of resolved countries:  20.670728291316525
# Completed  137.21675638408402 % of the dataset
# Amount of resolved countries:  20.669419174247725
# Completed  137.31277930667608 % of the dataset
# Amount of resolved countries:  20.667202797202798
# Completed  137.50482515186025 % of the dataset
# Amount of resolved countries:  20.661662011173185
# Completed  137.60084807445233 % of the dataset
# Amount of resolved countries:  20.664131193300765
# Completed  137.6968709970444 % of the dataset
# Amount of resolved countries:  20.660878661087867
# Completed  137.7928939196365 % of the dataset
# Amount of resolved countries:  20.65742160278746
# Completed  137.88891684222858 % of the dataset
# Amount of resolved countries:  20.651114206128135
# Completed  137.98493976482067 % of the dataset
# Amount of resolved countries:  20.654418928322897
# Completed  138.08096268741275 % of the dataset
# Amount of resolved countries:  20.650904033379692
# Completed  138.2730085325969 % of the dataset
# Amount of resolved countries:  20.641180555555554
# Completed  138.36903145518897 % of the dataset
# Amount of resolved countries:  20.636641221374045
# Completed  138.46505437778106 % of the dataset
# Amount of resolved countries:  20.635298196948682
# Completed  138.56107730037314 % of the dataset
# Amount of resolved countries:  20.63963963963964
# Completed  138.65710022296523 % of the dataset
# Amount of resolved countries:  20.642382271468144
# Completed  138.7531231455573 % of the dataset
# Amount of resolved countries:  20.643598615916954
# Completed  138.94516899074148 % of the dataset
# Amount of resolved countries:  20.63690393918452
# Completed  139.04119191333356 % of the dataset
# Amount of resolved countries:  20.634530386740334
# Completed  139.2332377585177 % of the dataset
# Amount of resolved countries:  20.632689655172413
# Completed  139.32926068110982 % of the dataset
# Amount of resolved countries:  20.63473466574776
# Completed  139.42528360370187 % of the dataset
# Amount of resolved countries:  20.635468319559227
# Completed  139.61732944888604 % of the dataset
# Amount of resolved countries:  20.636038514442916
# Completed  143.9383609655297 % of the dataset
# Amount of resolved countries:  20.49392928619079
# Completed  144.03438388812177 % of the dataset
# Amount of resolved countries:  20.492733333333334
# Completed  144.13040681071385 % of the dataset
# Amount of resolved countries:  20.489806795469686
# Completed  144.22642973330593 % of the dataset
# Amount of resolved countries:  20.484687083888147
# Completed  144.32245265589802 % of the dataset
# Amount of resolved countries:  20.479174983366597
# Completed  144.5144985010822 % of the dataset
# Amount of resolved countries:  20.47202657807309
# Completed  144.61052142367424 % of the dataset
# Amount of resolved countries:  20.468857901726427
# Completed  144.99461311404258 % of the dataset
# Amount of resolved countries:  20.450993377483442
# Completed  145.09063603663466 % of the dataset
# Amount of resolved countries:  20.448974189278623
# Completed  145.18665895922675 % of the dataset
# Amount of resolved countries:  20.450727513227513
# Completed  145.28268188181883 % of the dataset
# Amount of resolved countries:  20.452015862524785
# Completed  145.37870480441092 % of the dataset
# Amount of resolved countries:  20.449537648612946
# Completed  145.57075064959508 % of the dataset
# Amount of resolved countries:  20.45349604221636
# Completed  145.76279649477922 % of the dataset
# Amount of resolved countries:  20.457971014492752
# Completed  145.8588194173713 % of the dataset
# Amount of resolved countries:  20.455628703094142
# Completed  145.9548423399634 % of the dataset
# Amount of resolved countries:  20.45782894736842
# Completed  146.05086526255548 % of the dataset
# Amount of resolved countries:  20.45818540433925
# Completed  146.14688818514756 % of the dataset
# Amount of resolved countries:  20.45742444152431
# Completed  146.3389340303317 % of the dataset
# Amount of resolved countries:  20.453937007874014
# Completed  146.4349569529238 % of the dataset
# Amount of resolved countries:  20.452590163934424
# Completed  146.5309798755159 % of the dataset
# Amount of resolved countries:  20.45137614678899
# Completed  146.72302572070004 % of the dataset
# Amount of resolved countries:  20.45130890052356
# Completed  146.81904864329212 % of the dataset
# Amount of resolved countries:  20.449051667756706
# Completed  146.9150715658842 % of the dataset
# Amount of resolved countries:  20.447647058823527
# Completed  147.0110944884763 % of the dataset
# Amount of resolved countries:  20.44480731548008
# Completed  147.20314033366043 % of the dataset
# Amount of resolved countries:  20.441682974559686
# Completed  147.29916325625254 % of the dataset
# Amount of resolved countries:  20.4377444589309
# Completed  147.39518617884463 % of the dataset
# Amount of resolved countries:  20.437198697068403
# Completed  147.49120910143668 % of the dataset
# Amount of resolved countries:  20.43665364583333
# Completed  147.68325494662088 % of the dataset
# Amount of resolved countries:  20.432119635890768
# Completed  147.77927786921293 % of the dataset
# Amount of resolved countries:  20.431708901884342
# Completed  148.06734663698919 % of the dataset
# Amount of resolved countries:  20.421984435797665
# Completed  148.16336955958127 % of the dataset
# Amount of resolved countries:  20.41697990926766
# Completed  148.25939248217335 % of the dataset
# Amount of resolved countries:  20.4175518134715

# %%
len(country) #Verify the length of the country list so we can create a new column in our data
# Out:
# 1545947

# %%
df['country'] = country

# %%
df.loc[df['country']!='Cannot resolve country'].shape #Overall, we successfully identifies the country of origin for 315711 rows or 20% of our data
# Out:
# (315711, 16)

# %%
df_with_countries = df.loc[df['country']!='Cannot resolve country']

# %% [markdown]
# As we can see below, the country identification mechanism identified correctly all of the following records

# %%
df_with_countries[['location', 'country']][:20]
# Out:
#                      location      country
# 20        Islamabad, Pakistan     Pakistan
# 22        Islamabad, Pakistan     Pakistan
# 48                     Canada       Canada
# 52    US, Singapore and India        India
# 70   Waterloo, Ontario Canada       Canada
# 71          Brussels, Belgium      Belgium
# 72                New Zealand  New Zealand
# 73                  Thailand      Thailand
# 74                Philippines  Philippines
# 80        Manila, Philippines  Philippines
# 81         Navi Mumbai, India        India
# 82    US, Singapore and India        India
# 96           Bangalore, India        India
# 104                 Singapore    Singapore
# 105          Hyderabad, India        India
# 110                     India        India
# 118                 Singapore    Singapore
# 119                      Oman         Oman
# 124                 Indonesia    Indonesia
# 125             Ogun, Nigeria        Niger

# %% [markdown]
# We are going to manualy check the remaining records that we failed to identify their country of origin. We want to resolve the country for all locations that appear more than 1000 times in our data

# %%
df.loc[df['country']=='Cannot resolve country', 'location'].value_counts().to_clipboard()

# %% [markdown]
# Given our manual inspection of the data, we can safely assign the following locations to each of the following countries

# %%
usa_places_list = ['United States', 'Los Angeles, CA', 'New York, NY', 'Detroit, MI', 'San Francisco, CA', 'USA', 'Miami, FL', 'Chicago, IL', 'New York, USA', 'Washington, DC', "Town 'n' Country, FL", 'Austin, TX', 'Texas, USA', 'Seattle', 'California, USA', 'Tampa, FL', 'Las Vegas, NV', 'Seattle, WA', 'Boston, MA', 'Florida, USA', 'New York', 'Maryland, USA', 'Atlanta, GA', 'Pittsburgh, PA', 'Dallas, TX', 'Houston, TX', 'New Jersey, USA', 'San Francisco', 'San Jose, CA', 'Sacramento, CA', 'North Carolina, USA', 'Washington, USA', 'Troy, MI, US, 48083', 'Miami, usa', 'Florida', 'Texas', 'Palo Alto, CA', 'Titusville, FL', 'San Diego, CA', 'Alpharetta, GA', 'Lakeville, MN']

# %%
import swifter 

df['country_new'] = df.swifter.apply(lambda x: 'United States of America' if x['location'] in usa_places_list else x['country'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Brazil' if x['location'] in ['Rio de janeiro'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Argentina' if x['location'] in ['Buenos Aires'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'United Kingdom' if x['location'] in ['London', 'London, UK', 'UK', 'Bradford, Yorkshire', 'Carlisle, England', 'Hounslow, London', 'London, England'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'India' if x['location'] in ['Delhi', 'INDIA', 'Mumbai', 'Bangalore', 'New Delhi', 'Karachi'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Germany' if x['location'] in ['Mysore  and  BERLIN', 'Hamburg'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Canada' if x['location'] in ['Toronto, Ontario', 'Toronto'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Mexico' if x['location'] in ['Cancún', 'México'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Australia' if x['location'] in ['Melbourne, Victoria'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Bosnia and Herzegovina' if x['location'] in ['Sarajevo'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'India' if x['location'] in ['Chennai'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'France' if x['location'] in ['Paris'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Pakistan' if x['location'] in ['Islamabad'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Spain' if x['location'] in ['Madrid'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df['country_new'] = df.swifter.apply(lambda x: 'Colombia' if x['location'] in ['Envigado, antioquia'] else x['country_new'], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/1545947 [00:00<?, ?it/s]

# %%
df.loc[df['country_new']=='Cannot resolve country', 'location'].value_counts().to_clipboard()

# %% [markdown]
# After manual inspection we were able to identify the country for 561289 records. So by manually inspecting our data we resolved the country for 77% more records than we had initially detected

# %%
df.loc[df['country_new']!='Cannot resolve country'].shape
# Out:
# (561289, 17)

# %% [markdown]
# We are going to work only with the records that we were able to resolve their country

# %%
df_with_countries = df.loc[df['country_new']!='Cannot resolve country']

# %%
df_with_countries.shape
# Out:
# (561289, 17)

# %% [markdown]
# #### Natural Language Processing

# %% [markdown]
# We are going to clean the text column so that we can later perform topic modelling on it. To do so, we will first make all letters lower case, we are removing any special case characters, we are removing all url addresses, we remove extra spaces in between, we remove punctuation, we remove any non-ascii phrases, we use fasttext lang to detect foreign languages, sice we want to keep only tweets in English, we remove stopwords and we finally lemmatize our text

# %%
import re
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
import fasttext

model = fasttext.load_model(r'Tweets_on_cloud_services_data/lid.176.ftz')
st = SnowballStemmer('english')
lemmatizer = WordNetLemmatizer()

df_with_countries['clean_text'] = df_with_countries['text'].swifter.apply(lambda x: x.lower().strip())

df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: ' '.join(text for text in x.split() if text[0] not in ['!', '@', '#', '$', '%', '^', '&', '*']))

df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: ' '.join(text for text in x.split() if text[:4] != 'http'))

# remove extra spaces in between
df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: re.sub(' +', ' ', x))

# remove punctuation
df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: re.sub('[^a-zA-Z]', ' ', x))

df_with_countries.reset_index(inplace=True)
indices = []
for i in range(df_with_countries.shape[0]):    
    if df_with_countries['clean_text'].iloc[i].isascii():                
        indices.append(i)        
        
df_with_countries = df_with_countries.loc[df_with_countries.index[indices]]

df_with_countries.reset_index(inplace=True)
indices = []
for i in range(df_with_countries.shape[0]):
    lang_pred = model.predict(df_with_countries['clean_text'].iloc[i], k=1)    
    if lang_pred[1][0] > 0.7 and lang_pred[0][0][9:] == 'en':        
        indices.append(i)
        
df_with_countries = df_with_countries.loc[df_with_countries.index[indices]]

# remove stopwords
df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: ' '.join(text for text in x.split() if text not in stop_words))

# remove stopwords and get the stem
df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: ' '.join(lemmatizer.lemmatize(text) for text in x.split()))
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# Pandas Apply:   0%|          | 0/561289 [00:00<?, ?it/s]
# C:\Users\George\AppData\Local\Temp\ipykernel_5664\2770500003.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_countries['clean_text'] = df_with_countries['text'].swifter.apply(lambda x: x.lower().strip())
# Pandas Apply:   0%|          | 0/561289 [00:00<?, ?it/s]
# C:\Users\George\AppData\Local\Temp\ipykernel_5664\2770500003.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: ' '.join(text for text in x.split() if text[0] not in ['!', '@', '#', '$', '%', '^', '&', '*']))
# Pandas Apply:   0%|          | 0/561289 [00:00<?, ?it/s]
# C:\Users\George\AppData\Local\Temp\ipykernel_5664\2770500003.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: ' '.join(text for text in x.split() if text[:4] != 'http'))
# Pandas Apply:   0%|          | 0/561289 [00:00<?, ?it/s]
# C:\Users\George\AppData\Local\Temp\ipykernel_5664\2770500003.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: re.sub(' +', ' ', x))
# Pandas Apply:   0%|          | 0/561289 [00:00<?, ?it/s]
# C:\Users\George\AppData\Local\Temp\ipykernel_5664\2770500003.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_countries['clean_text'] = df_with_countries['clean_text'].swifter.apply(lambda x: re.sub('[^a-zA-Z]', ' ', x))
# Pandas Apply:   0%|          | 0/452977 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/452977 [00:00<?, ?it/s]

# %% [markdown]
# #### Divide in Market Regions

# %% [markdown]
# We want to bring information about the market region each country belongs into

# %%
regions = pd.read_excel(r'Tweets_on_cloud_services_data\countries_regions.xlsx')

# %%
regions
# Out:
#                   Country Region
# 0                 Andorra   EMEA
# 1    United Arab Emirates   EMEA
# 2             Afghanistan   EMEA
# 3     Antigua and Barbuda  LATAM
# 4                Anguilla  LATAM
# ..                    ...    ...
# 242                 Yemen   EMEA
# 243               Mayotte   EMEA
# 244          South Africa   EMEA
# 245                Zambia   EMEA
# 246              Zimbabwe   EMEA
#
# [247 rows x 2 columns]

# %%
df_with_countries = pd.merge(df_with_countries, regions, left_on = 'country_new', right_on='Country', how='left')

# %%
df_with_countries['Region'].value_counts() #Each region contains around the same number of tweets except LATAM
# Out:
# NOAM     145743
# EMEA     142573
# APAC     141482
# LATAM     23179
# Name: Region, dtype: int64

# %%
df_with_countries['Region'].isnull().sum() #There is no country in our data that has not be assigned to a region
# Out:
# 0

# %% [markdown]
# #### Feature Creation

# %% [markdown]
# We create 3 new columns, each one indicating whether a particular tweet is mentioning a cloud vendor

# %%
df_with_countries['processed_text'] = df_with_countries['text'].apply(lambda x: x.lower().strip())

df_with_countries['is_aws'] = df_with_countries.swifter.apply(lambda x: 1 if 'aws' in x['processed_text'] else 0, axis=1)
df_with_countries['is_azure'] = df_with_countries.swifter.apply(lambda x: 1 if 'azure' in x['processed_text'] else 0, axis=1)
df_with_countries['is_gcp'] = df_with_countries.swifter.apply(lambda x: 1 if 'google' in x['processed_text'] else 0, axis=1)
# Out:
# Pandas Apply:   0%|          | 0/452977 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/452977 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/452977 [00:00<?, ?it/s]

# %% [markdown]
# We drop all the columns that we are not going to use in our analysis

# %%
df_with_countries.drop(['level_0', 'index', 'location', 'country', 'Country', 'processed_text', 'text', 'hashtags'], inplace=True, axis=1)
df_with_countries.rename(columns={'country_new': 'country'}, inplace=True)

# %% [markdown]
# ### Cloud Vendors popularity by Market Region - number of tweets

# %% [markdown]
# Number of tweets about each cloud vendor per market region

# %%
noam_region = df_with_countries.loc[df_with_countries['Region']=='NOAM']
print('Number of tweets about Azure in North America Region: ', noam_region['is_azure'].sum())
print('Number of tweets about AWS in North America Region: ', noam_region['is_aws'].sum())
print('Number of tweets about Google Cloud in North America Region: ', noam_region['is_gcp'].sum())
# Out:
# Number of tweets about Azure in North America Region:  9961
# Number of tweets about AWS in North America Region:  5197
# Number of tweets about Google Cloud in North America Region:  2381

# %%
apac_region = df_with_countries.loc[df_with_countries['Region']=='APAC']
print('Number of tweets about Azure in Asia Pacific Region: ', apac_region['is_azure'].sum())
print('Number of tweets about AWS in Asia Pacific Region: ', apac_region['is_aws'].sum())
print('Number of tweets about Google Cloud in Asia Pacific Region: ', apac_region['is_gcp'].sum())
# Out:
# Number of tweets about Azure in Asia Pacific Region:  7247
# Number of tweets about AWS in Asia Pacific Region:  8812
# Number of tweets about Google Cloud in Asia Pacific Region:  3460

# %%
emea_region = df_with_countries.loc[df_with_countries['Region']=='EMEA']
print('Number of tweets about Azure in EMEA Region: ', emea_region['is_azure'].sum())
print('Number of tweets about AWS in EMEA Region: ', emea_region['is_aws'].sum())
print('Number of tweets about Google Cloud in EMEA Region: ', emea_region['is_gcp'].sum())
# Out:
# Number of tweets about Azure in EMEA Region:  7423
# Number of tweets about AWS in EMEA Region:  5963
# Number of tweets about Google Cloud in EMEA Region:  2538

# %%
latam_region = df_with_countries.loc[df_with_countries['Region']=='LATAM']
print('Number of tweets about Azure in Latin America Region: ', latam_region['is_azure'].sum())
print('Number of tweets about AWS in Latin America Region: ', latam_region['is_aws'].sum())
print('Number of tweets about Google Cloud in Latin America Region: ', latam_region['is_gcp'].sum())
# Out:
# Number of tweets about Azure in Latin America Region:  3404
# Number of tweets about AWS in Latin America Region:  2576
# Number of tweets about Google Cloud in Latin America Region:  322

# %% [markdown]
# Frequency of tweets about a particular cloud vendor over all tweets about cloud vendors

# %%
noam_region = df_with_countries.loc[df_with_countries['Region']=='NOAM']

count_of_tweets = (noam_region['is_azure'].sum() + noam_region['is_aws'].sum() + noam_region['is_gcp'].sum())

print('Ratio of tweets about Azure in North America Region: ', round(noam_region['is_azure'].sum() / count_of_tweets * 100, 2))
print('Ratio of tweets about AWS in North America Region: ', round(noam_region['is_aws'].sum() / count_of_tweets * 100, 2))
print('Ratio of tweets about Google Cloud in North America Region: ', round(noam_region['is_gcp'].sum() / count_of_tweets * 100, 2))
# Out:
# Ratio of tweets about Azure in North America Region:  56.79
# Ratio of tweets about AWS in North America Region:  29.63
# Ratio of tweets about Google Cloud in North America Region:  13.58

# %%
apac_region = df_with_countries.loc[df_with_countries['Region']=='APAC']

count_of_tweets = (apac_region['is_azure'].sum() + apac_region['is_aws'].sum() + apac_region['is_gcp'].sum())

print('Ratio of tweets about Azure in Asia Pacific Region: ', round(apac_region['is_azure'].sum() / count_of_tweets * 100, 2))
print('Ratio of tweets about AWS in Asia Pacific Region: ', round(apac_region['is_aws'].sum() / count_of_tweets * 100, 2))
print('Ratio of tweets about Google Cloud in Asia Pacific Region: ', round(apac_region['is_gcp'].sum() / count_of_tweets * 100, 2))
# Out:
# Ratio of tweets about Azure in Asia Pacific Region:  37.13
# Ratio of tweets about AWS in Asia Pacific Region:  45.15
# Ratio of tweets about Google Cloud in Asia Pacific Region:  17.73

# %%
emea_region = df_with_countries.loc[df_with_countries['Region']=='EMEA']

count_of_tweets = (emea_region['is_azure'].sum() + emea_region['is_aws'].sum() + emea_region['is_gcp'].sum())

print('Ratio of tweets about Azure in EMEA Region: ', round(emea_region['is_azure'].sum() / count_of_tweets * 100, 2))
print('Ratio of tweets about AWS in EMEA Region: ', round(emea_region['is_aws'].sum() / count_of_tweets * 100, 2))
print('Ratio of tweets about Google Cloud in EMEA Region: ', round(emea_region['is_gcp'].sum() / count_of_tweets * 100, 2))
# Out:
# Ratio of tweets about Azure in EMEA Region:  46.62
# Ratio of tweets about AWS in EMEA Region:  37.45
# Ratio of tweets about Google Cloud in EMEA Region:  15.94

# %%
latam_region = df_with_countries.loc[df_with_countries['Region']=='LATAM']

count_of_tweets = (latam_region['is_azure'].sum() + latam_region['is_aws'].sum() + latam_region['is_gcp'].sum())

print('Ratio of tweets about Azure in Latin America Region: ', round(latam_region['is_azure'].sum() / count_of_tweets * 100, 2))
print('Ratio of tweets about AWS in Latin America Region: ', round(latam_region['is_aws'].sum() / count_of_tweets * 100, 2))
print('Ratio of tweets about Google Cloud in Latin America Region: ', round(latam_region['is_gcp'].sum() / count_of_tweets * 100, 2))
# Out:
# Ratio of tweets about Azure in Latin America Region:  54.01
# Ratio of tweets about AWS in Latin America Region:  40.88
# Ratio of tweets about Google Cloud in Latin America Region:  5.11

# %% [markdown]
# ### Cloud Vendors popularity by Market Region - tweet visibility

# %% [markdown]
# Although number of tweets is a good indicator of each cloud vendor's popularity, there are some tweets that are much more visible than others. A tweet's visibility can be calculated using 3 key drivers: 1. The number of people following the user making the tweet, 2. The number of times that a tweet has been retweeted, 3. The number of people that have liked the tweet. The higher the number in each category, the higher will be the visibility of the tweet as well. Moreover, the weight that each of the 3 key drivers provide to a tweet's visibility is not the same, since a tweet with 100 likes will have received a much higher visibility than a tweet made by a tweetor with 100 followers, since in order to receive 100 likes it means that the tweet has been viewed by much more than 100 people. Furthermore, a tweet with 100 retweets will have received a much higher visibility than a tweet with 100 likes, since a user is more prone to like a tweet than retweet it to his network. Although subjective we are going to assign a visibility weight of 0.6 per retweet, a weight of 0.3 per like and finally a weight of 0.1 per number of followers.

# %%
def reach_score(x, y, z):
    return 0.6 * x + 0.3 * y + 0.1 * z

# %%
df_with_countries['reach'] = df_with_countries.swifter.apply(lambda x: reach_score(x['retweetcount'], x['favorite_count'], x['followers']), axis=1)

# %%
noam_region = df_with_countries.loc[df_with_countries['Region']=='NOAM']

reach_of_tweets = (noam_region.loc[noam_region['is_azure']==1, 'reach'].sum() + noam_region.loc[noam_region['is_aws']==1, 'reach'].sum() + noam_region.loc[noam_region['is_gcp']==1, 'reach'].sum())

print('Reach of tweets about Azure in North America Region: ', round(noam_region.loc[noam_region['is_azure']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
print('Reach of tweets about AWS in North America Region: ', round(noam_region.loc[noam_region['is_aws']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
print('Reach of tweets about Google Cloud in North America Region: ', round(noam_region.loc[noam_region['is_gcp']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
# Out:
# Reach of tweets about Azure in North America Region:  15.86
# Reach of tweets about AWS in North America Region:  71.42
# Reach of tweets about Google Cloud in North America Region:  12.72

# %%
apac_region = df_with_countries.loc[df_with_countries['Region']=='APAC']

reach_of_tweets = (apac_region.loc[apac_region['is_azure']==1, 'reach'].sum() + apac_region.loc[apac_region['is_aws']==1, 'reach'].sum() + apac_region.loc[apac_region['is_gcp']==1, 'reach'].sum())

print('Reach of tweets about Azure in Asia Pacific Region: ', round(apac_region.loc[apac_region['is_azure']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
print('Reach of tweets about AWS in Asia Pacific Region: ', round(apac_region.loc[apac_region['is_aws']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
print('Reach of tweets about Google Cloud in Asia Pacific Region: ', round(apac_region.loc[apac_region['is_gcp']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
# Out:
# Reach of tweets about Azure in Asia Pacific Region:  33.63
# Reach of tweets about AWS in Asia Pacific Region:  40.79
# Reach of tweets about Google Cloud in Asia Pacific Region:  25.58

# %%
emea_region = df_with_countries.loc[df_with_countries['Region']=='EMEA']

reach_of_tweets = (emea_region.loc[emea_region['is_azure']==1, 'reach'].sum() + emea_region.loc[emea_region['is_aws']==1, 'reach'].sum() + emea_region.loc[emea_region['is_gcp']==1, 'reach'].sum())

print('Reach of tweets about Azure in EMEA Region: ', round(emea_region.loc[emea_region['is_azure']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
print('Reach of tweets about AWS in EMEA Region: ', round(emea_region.loc[emea_region['is_aws']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
print('Reach of tweets about Google Cloud in EMEA Region: ', round(emea_region.loc[emea_region['is_gcp']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
# Out:
# Reach of tweets about Azure in EMEA Region:  35.74
# Reach of tweets about AWS in EMEA Region:  38.02
# Reach of tweets about Google Cloud in EMEA Region:  26.24

# %%
latam_region = df_with_countries.loc[df_with_countries['Region']=='LATAM']

reach_of_tweets = (latam_region.loc[latam_region['is_azure']==1, 'reach'].sum() + latam_region.loc[latam_region['is_aws']==1, 'reach'].sum() + latam_region.loc[latam_region['is_gcp']==1, 'reach'].sum())

print('Reach of tweets about Azure in Latin America Region: ', round(latam_region.loc[latam_region['is_azure']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
print('Reach of tweets about AWS in Latin America Region: ', round(latam_region.loc[latam_region['is_aws']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
print('Reach of tweets about Google Cloud in Latin America Region: ', round(latam_region.loc[latam_region['is_gcp']==1, 'reach'].sum() / reach_of_tweets * 100, 2))
# Out:
# Reach of tweets about Azure in Latin America Region:  55.27
# Reach of tweets about AWS in Latin America Region:  37.84
# Reach of tweets about Google Cloud in Latin America Region:  6.89

# %%
noam_region = df_with_countries.loc[(df_with_countries['Region']=='NOAM') & ((df_with_countries['is_aws']==1) | (df_with_countries['is_azure']==1) | (df_with_countries['is_gcp']==1))]

noam_region_sorted = noam_region.sort_values(by=['reach'], ascending=False)[:200]

print('Out of 200 tweets with highest reach, ', noam_region_sorted['is_aws'].sum(), ' are about AWS')
print('Out of 200 tweets with highest reach, ', noam_region_sorted['is_azure'].sum(), ' are about Azure')
print('Out of 200 tweets with highest reach, ', noam_region_sorted['is_gcp'].sum(), ' are about GCP')
# Out:
# Out of 200 tweets with highest reach,  143  are about AWS
# Out of 200 tweets with highest reach,  23  are about Azure
# Out of 200 tweets with highest reach,  42  are about GCP

# %% [markdown]
# We observe that tweets by AWS have a much greater visibility than its competitors although when assessing the number of tweets per se it was behind Azure.

# %% [markdown]
# Moreover, if we deep dive in the specific account that drives the AWS visibility we see that it was created at 2009-08-18. This account is the official account of AWS at tweeter and it has such a high visibility since it is being followed by 2M people

# %%
df_with_countries.loc[df_with_countries['usercreatedts']=='2009-08-18 19:52:16.000000'][:1]
# Out:
#           hashed_userid  following  followers  totaltweets  \
# 89  3284594507786650753        975    2014973        36321
#
#                  usercreatedts              tweetid  \
# 89  2009-08-18 19:52:16.000000  1518228625895706624
#
#                 tweetcreatedts  retweetcount  favorite_count  \
# 89  2022-04-24 14:01:26.000000            39             339
#
#     original_tweet_id  tweetcreatedts_new tweetcreatedts_date  \
# 89                  0 2022-04-24 14:01:26          2022-04-24
#
#                      country  \
# 89  United States of America
#
#                                            clean_text Region  is_aws  \
# 89  skill frontrunner worthy new deepracer arcade ...   NOAM       1
#
#     is_azure  is_gcp     reach
# 89         0       0  201622.4

# %% [markdown]
# Breakdown of the top 200 tweets with the highest visibility by Cloud Vendor

# %%
noam_region_sorted.loc[noam_region_sorted['is_aws']==1, 'usercreatedts'].value_counts()
# Out:
# 2009-08-18 19:52:16.000000    68
# 2006-12-07 17:03:09.000000    42
# 2018-02-27 20:10:14.000000     7
# 2012-03-23 16:35:17.000000     6
# 2009-04-25 12:45:16.000000     4
# 2007-12-14 16:06:10.000000     3
# 2008-05-27 20:11:54.000000     2
# 2017-01-10 19:27:47.000000     2
# 2009-01-14 17:13:48.000000     1
# 2008-01-23 22:11:25.000000     1
# 2007-04-27 18:43:50.000000     1
# 2009-04-06 16:10:33.000000     1
# 2008-06-09 23:05:05.000000     1
# 2011-10-19 13:01:42.000000     1
# 2008-07-30 15:55:46.000000     1
# 2008-05-08 21:46:41.000000     1
# 2008-12-29 21:44:27.000000     1
# Name: usercreatedts, dtype: int64

# %%
noam_region_sorted.loc[noam_region_sorted['is_azure']==1, 'usercreatedts'].value_counts()
# Out:
# 2009-04-25 12:45:16.000000    8
# 2012-03-23 16:35:17.000000    8
# 2008-05-27 20:11:54.000000    2
# 2008-04-03 12:33:18.000000    1
# 2009-02-27 18:02:56.000000    1
# 2007-05-08 16:28:38.000000    1
# 2009-01-14 17:13:48.000000    1
# 2007-04-27 18:43:50.000000    1
# Name: usercreatedts, dtype: int64

# %%
noam_region_sorted.loc[noam_region_sorted['is_gcp']==1, 'usercreatedts'].value_counts()
# Out:
# 2012-03-23 16:35:17.000000    17
# 2009-04-25 12:45:16.000000    16
# 2007-04-14 22:48:21.000000     3
# 2009-06-25 20:55:34.000000     2
# 2012-08-16 23:16:47.000000     2
# 2009-01-02 23:15:02.000000     1
# 2015-09-24 11:47:59.000000     1
# Name: usercreatedts, dtype: int64

# %% [markdown]
# ### Topic Modeling

# %% [markdown]
# Finally, we are going to find out the main topics that users are tweeting about when it comes to Cloud Vendors in the North America region

# %%
#Get tweets about AWS
noam_region_aws_cloud = df_with_countries.loc[(df_with_countries['Region']=='NOAM') & (df_with_countries['is_aws']==1)]

# %%
noam_region_aws_cloud.shape #We have 5197 tweets about AWS
# Out:
# (5197, 19)

# %%
noam_region_aws_cloud_train = noam_region_aws_cloud

# %% [markdown]
# Build a corpus dictionary comprised of 100000 words, filtering out words that appear less than 15 times as well as those with a frequency greater than 50%

# %%
from gensim import corpora, models
import gensim
corpus = []
for i in range(noam_region_aws_cloud_train.shape[0]):
    try:    
        corpus.append(noam_region_aws_cloud_train['clean_text'].iloc[i].split())
    except Exception as e:
        print(e)
        print(noam_region_aws_cloud_train['clean_text'].iloc[i], i)
        continue
    
dct = corpora.Dictionary(corpus)

# %%
dct.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dct.doc2bow(doc) for doc in corpus]

# %%
len(bow_corpus)
# Out:
# 5197

# %% [markdown]
# Tf-Idf or Term Frequency over Inverse document frequency is a metric assigning weight to the various words af the tweet acccording to their importance in a particular tweet. The whole idea behind tf-idf is that if a word that in general does not appear too often in all of the tweets, appears in a particular tweet then it should be important for the particular tweet

# %%
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %% [markdown]
# We use Latent Dirichlet Analysis to generate the various topics. We can see the various topics that are getting generated alongside the words that mainly drive each topic

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=4, id2word=dct, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.010*"service" + 0.009*"cloud" + 0.009*"access" + 0.009*"aws" + 0.009*"today" + 0.009*"want" + 0.009*"available" + 0.008*"inbox" + 0.008*"chat" + 0.008*"social"
# Topic: 1 Word: 0.012*"cloud" + 0.012*"aws" + 0.012*"service" + 0.009*"learn" + 0.009*"amazon" + 0.008*"hacking" + 0.007*"free" + 0.007*"support" + 0.006*"instance" + 0.006*"data"
# Topic: 2 Word: 0.011*"rt" + 0.010*"follow" + 0.010*"aws" + 0.008*"new" + 0.008*"cloud" + 0.006*"service" + 0.006*"build" + 0.006*"built" + 0.005*"data" + 0.005*"help"
# Topic: 3 Word: 0.011*"aws" + 0.008*"security" + 0.007*"data" + 0.007*"cloud" + 0.007*"learn" + 0.006*"learning" + 0.006*"work" + 0.006*"week" + 0.006*"technology" + 0.006*"trying"

# %% [markdown]
# For a better visualization of the various topics that LDA has proposed we are going to take the first 200 tweets and print them in their respective topic

# %%
bow_corpus_test = bow_corpus[:200]

# %%
new_df = pd.merge(noam_region_aws_cloud_train, df[['text', 'tweetid']], how='left', on ='tweetid')

# %%
topics = []
score = []
sentence = []
counter = 0 
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 0:
        counter += 1
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# ☀️ Don't miss our on getting free access to our platform - No credit card required!
# 🎯 Hurry up, just a few days left! Refresh your tech skills and take your career to the next level.
# 👉 https://t.co/NgLLyMdvUN
#
# #AWS #Azure #GCP #AWSCertified #AzureCertified https://t.co/YmaviWFIgG
#
#  ------------------
#
#
# Today's Most popular #Cloud Headlines #Openstack #AWS https://t.co/331xhP1D0S
#
#  ------------------
#
#
# Are your #MachineLearning skills frontrunner worthy? 🏁🏎 ☁️
#
# With the new #AWS DeepRacer Arcade, created in collaboration with @F1, you can test your driving skills against the clock. Find an AWS Summit near you, and go for a spin. https://t.co/0na0wRf6lN #Developer #F1 https://t.co/t7aga9LIIF
#
#  ------------------
#
#
# Hiring a full-time Senior Python Developer in Nashville, TN. #python #pythondeveloper #django #aws https://t.co/CtFb6rfbKO
#
#  ------------------
#
#
# awscloud: Are your #MachineLearning skills frontrunner worthy? 🏁🏎 ☁️
#
# With the new #AWS DeepRacer Arcade, created in collaboration with @F1, you can test your driving skills against the clock. Find an AWS Summit near you, and go for a spin. … https://t.co/CXefORoEPM
#
#  ------------------
#
#
# See how customers can use Druva to centrally manage, monitor, and secure backups across multi-account AWS environments and achieve an enhanced, organization-level view of data protection across their #AWS services.   https://t.co/ELuziU6Exu
# #AWSMarketplace #AWSControlTower https://t.co/TQ1qqcVbtb
#
#  ------------------
#
#
# If you want to access your Boyfriend/Girlfriend Chats for any social media
# Inbox I'm available 24/7 for all hacking services
# #hacked #Hackingtime #snapchat #Twitter #instagram #AWS #5G #9News
#
#  ------------------
#
#
# The SenseDeep DynamoDB Single Table Designer is the new way to create your #SingleTableDesign models. Then use the SenseDeep data browser which understands your app entities and fields.
#
# https://t.co/90hVMQOI7g
#
# #aws #dynamodb #129
#
#  ------------------
#
#
# See the SenseDeep Log Viewer in action. This is the fastest and easiest way to view your CloudWatch logs.
#
# Unified views for one or more log groups / streams with real live tail.
#
# https://t.co/c0X9tOxAbd
#
# #sensedeep #aws #cloudwatch #111
#
#  ------------------
#
#
# Amazon GuardDuty gives users the ability to monitor one or multiple AWS accounts for unusual and unexpected behavior.
# -
# https://t.co/xqgqC3cQRn
# .
# #avmconsulting #AWS #guardduty #VPC #flowlogs #cloudtrailevent #DNSlogs #amazon
#
#  ------------------
#
#
# 😎 Senior Frontend Engineer
# 👨‍💻 TestGorilla company.
# 👇 Apply:
# https://t.co/tBvy7M0ruf
#
# #cloud #kubernetes #angular #devops #startup #html #aws #frontend #javascript #docker #azure
#
#  ------------------
#
#
# Today's Most popular #Cloud Headlines #Openstack #AWS https://t.co/YkTB2728jA
#
#  ------------------
#
#
# How do you evaluate the right software development partner for your company?
# #hire #software #business #outsourcing #staff #team #cloud #IT #digital #project #devops #aws #digitaltransformation #sap #microsoft #softwaredevelopment #bigdata #salesforce
# https://t.co/mOHvYpk8eS
#
#  ------------------
#
#
# The @Braves have the day off, but we'll be back and ready to take on the Cubs Tuesday! ⚾
# •••
# #ForTheA #hometeam #worldserieschampions #braves #atlantabraves #bravesbaseball #truistpark #batteryatl #appbarry #atlanta #makeitappen #supportlocal #applocal #developers #aws https://t.co/KNsvEqt1kl
#
#  ------------------
#
#
# If you want to access your Boyfriend/Girlfriend Chats for any social media
# Inbox I'm available 24/7 for all hacking services
# #hacked #Hackingtime #snapchat #Twitter #instagram #AWS #5G #9News
#
#  ------------------
#
#
# AWS Solution Architects are in demand from the biggest companies today. @awscloud certifications will help you to alleviate your career path. Get certified today! https://t.co/p15NKVwT5b  #amazon #aws @amazon https://t.co/PrDvxXvZed
#
#  ------------------
#
#
# The top 8 #AWS courses that you can take on @coursera right now. Perfect for #cloud and #IT professionals. #cloudcomputing #AmazonWebServices #cloudmanagement #cloudinfrastructure #cloudsolutions #cloudsecurity #cloudplatform https://t.co/6E6Hz5CvpG
#
#  ------------------
#
#
# AWS’ Amplify Studio is now generally available
#
# https://t.co/JwRUjovLaK
#
# #NoCodeJournal #NoCode #LowCode #visualdevelopmentaltool #amplifystudio #amazonwebservices
#
#  ------------------
#
#
# For #AWSPartners - LAST CHANCE to register for AnalytiCON 2022! Learn from #AWS experts how to build out your data &amp; analytics practice while aligning to key market opportunities: https://t.co/h4iA1BEKUU 📊 https://t.co/43NTSCRs95
#
#  ------------------
#
#
# Optimizing cost with long-term pricing options for #AWSSnowball https://t.co/9SpqEjByx3 @AWS_Storage #AWS #Cloud #CloudComputing #Edge #EdgeComputing https://t.co/AH7a5SzUgg
#
#  ------------------
#
#
# I am happy to say that today I completed all my requirements #hereataws for Field Readiness!!!! #cloudjourney #aws #awscloud
#
#  ------------------
#
#
# We are an #AWS Premier Consulting Partner! 🏅
# We want to share with you the great news of this new milestone achieved, one of the biggest corporate goals of the company.
#
# https://t.co/w6B6fL0dve
#
#  ------------------
#
#
# “We now have a set of trusted #AWSPartners who can help customers integrate QuickSight’s embedded analytics capabilities to create insightful, data-driven experiences.” ~ Matt Wood, VP of Business Analytics at #AWS
#
# Learn more &amp; meet our launch partners: https://t.co/NTPYbygzwn https://t.co/9gcrkCUFDc
#
#  ------------------
#
#
# Usual prescience and clarity from @benthompson @stratechery #aws #tech #commerce #logistics #Retail https://t.co/8wyv4dbiTy
#
#  ------------------
#
#
# Very soon I will have an open req for my team here at Jamf. I'm going to be looking for #AWS and #serverless experience to help accelerate our efforts.
#
# More to come.
#
#  ------------------
#
#
# Ship Your MVP in Hours with AWS Amplify Studio 👏 https://t.co/282HABoocj #AWS #Startups
#
#  ------------------
#
#
# Advanced Certification in Azure DevOps with Hatigen.
# Enroll Now
# 📱𝐖𝐡𝐚𝐭𝐬𝐚𝐩𝐩 𝐍𝐨𝐰:-+𝟒𝟒 (𝟎) 𝟐𝟎𝟑𝟏𝟓𝟒𝟑𝟑𝟒𝟓
# 🌐𝐖𝐞𝐛𝐬𝐢𝐭𝐞:- 𝐰𝐰𝐰.𝐇𝐚𝐭𝐢𝐠𝐞𝐧.𝐜𝐨𝐦
# 📧𝐄𝐦𝐚𝐢𝐥:- 𝐢𝐧𝐟𝐨@𝐡𝐚𝐭𝐢𝐠𝐞𝐧.𝐜𝐨𝐦
#
# #azure #cloud #aws #cloudcomputing #devops #techjob https://t.co/whQI1UmAiH
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/uFE0UrDMOF
#
#  ------------------
#
#
# Platform as a Service (PaaS) - Advantages &amp; How it is Used
#
# Read more: https://t.co/JaGFk1sQYg
#
# #omron #technology #productmarketing #development #computing #google #database #environment #cloud #aws #azure #programming #language #marketing https://t.co/Y5BK8DrRUw
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/Zvyf72LGzD
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/mo7RKX5MNV
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/AoNFHg2vnH
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/LCh7Knl8bB
#
#  ------------------
#
#
# Today's Most popular #Cloud Headlines #Openstack #AWS https://t.co/OMJyjpiBd8
#
#  ------------------
#
#
# “#CDR delivery and storage was a huge concern for us. CloudTern designed a cost-effective #CloudStorage solution that facilitated seamless movement and management of data across the infrastructure. “
# https://t.co/GdENcYoVVP #Telecom #CDR #AWS #CloudSolutions https://t.co/9SPbGlWXuv
#
#  ------------------
#
#
# 🤝 We are partnering with @ClearScale, a leading #cloud systems integrator, to support enterprises and governments with a holistic mainframe migration journey to @awscloud. Learn more: https://t.co/iJHCeClE0n
#
# #mainframemigration #clearscale #astadia #aws https://t.co/91rAb85AOU
#
#  ------------------
#
#
# @PocketProgram @scrumtuous He rocked fear factor. I just with an episode asked contestants to invalidate a tertiary data cache. Now that invokes fear in me. #programming #development #devops #javascript #golang #rustlang #aws
#
#  ------------------
#
#
# [100% Off] Intermediate Python Immersive Training | Boost your career
#
# https://t.co/4FaKLa0ZVu
#
# #coursetreat #100DaysOfCode #Python #Machinelearning #DataScience #IOT #Webdevelopment #Javascript #ReactJs #Coding #BigData #womenintech #WomenWhoCode #TensorFlow #Programming #AWS
#
#  ------------------
#
#
# We've partnered with @AstadiaInc to migrate and modernize legacy mainframes on #AWS. Together, we minimize the time spent in the #mainframe cloud migration transition phase and maximize the long-term success of modernization: https://t.co/9CVOaqKBld https://t.co/oEjOlqexpG
#
#  ------------------
#
#
# Looking to consolidate tools in a single #cloudsecurity platform for #AWS, #Azure and #Google Cloud? Read this buyer's guide to select the Cloud Native Application Protection Platform (CNAPP) that works best for your business. #CISOs #infosec #cloud https://t.co/2dEpLZnZxb
#
#  ------------------
#
#
# Excited to be in London for the #AWS Summit! Fun fact: I attended the very first ever Summit in London, way back in the day. Amazing to see how the business has grown here in the UK and Europe.
#
# https://t.co/XzNMlwez1G
#
#  ------------------
#
#
# Learn how nClouds uses #AmazonEKS Blueprints to build modern #CloudOps on EKS that accelerate #Kubernetes #ApplicationModernization at scale. #AWScloud #containers #DevOps @AWS_Partners Learn more: https://t.co/wOiRLXWW7v https://t.co/676nXr6UqC
#
#  ------------------
#
#
# Click the link below to see why companies like @Venmo are utilizing AWS serverless offerings.
# https://t.co/dqHo1U21xe
# To learn more about AWS, reach out to a STAND 8 #TechnologySolutions representative and start your #AWS journey today!
# #WeSTAND8 #WirelessTelecom #TalentSolutions https://t.co/lSJhC8cn9t
#
#  ------------------
#
#
# Our team has been architecting Cloud-Native Apps for 6 yrs!
#
# (My first product we launched was built in #containers &amp; architected in #AWS for Massive scale to 10's of thousands of enterprise users!)
#
# DM us for a quick Intro :)
#
# #Hybridcloud #Kubernetes #Docker #Migrations
#
#  ------------------
#
#
# Our team has been architecting Cloud-Native Apps for 6 yrs w/ DevSecOps!
#
# (The first product we launched was built in #containers &amp; architected in #AWS for massive scale to 10's of thousands of *enterprise* users!)
#
# DM us for a quick Intro :)
#
# #Hybridcloud #Kubernetes #Docker
#
#  ------------------
#
#
# New #AWS Wavelength Zone in Toronto – The First in Canada - https://t.co/lspuOBvSg3
#
# "Tiny Mile [  https://t.co/2bf2Efy05f  ] can now use Bell’s public Multi-access Edge Computing (MEC) solution, delivered through AWS Wavelength..." https://t.co/ZLCHqKi1zo
#
#  ------------------
#
#
# We had an amazing time at the Amazon Web Services (AWS) NE Sales Summit in New York City, last week! We got to meet so many of our sales and co-marketing partners in person, make new connections, and network with lots of great people.
#
# #AdvancedAWSPartner #AWS #AWSPartners https://t.co/I222zGef4K
#
#  ------------------
#
#
# New #AWS Wavelength Zone in Toronto – The First in Canada - https://t.co/lspuOBvSg3
#
# "Tiny Mile [  https://t.co/2bf2Efy05f  ] can now use Bell’s public Multi-access Edge Computing (MEC) solution, delivered through AWS Wavelength..." https://t.co/ZLCHqKi1zo
#
#  ------------------
#
#
# Audible is looking for a Director, Software Development
# https://t.co/muxT0ckY2x Forest Hills, NY, United States
# ( AWS )
# #careers #AWS
#
#  ------------------
#
#
# How long before Twitter is kicked off #AWS.   @JeffBezos has already fired the first shot. I hope @elonmusk is prepared.
#
#  ------------------
#
#
# Azure may have finally toppled AWS in the global cloud battle: #artificialintelligence #iot copy: @motorcycletwitt https://t.co/8jPSIKvnNM https://t.co/WNYP9vb1Vn
#
#  ------------------
#
#
# How long does it take to scale to hundreds-of-thousands of transactions? Try a fraction of a second! ☁️⚡️
#
# With #AWS Aurora Serverless v2, that scale comes in fine-grained increments for just the right amount of database resources your application needs.
# https://t.co/OKjx5canI3 https://t.co/x0OCQZgyf3
#
#  ------------------
#
#
# If you want to access your Boyfriend/Girlfriend Chats for any social media
# Inbox I'm available 24/7 for all hacking services
# #hacked #Hackingtime #snapchat #Twitter #instagram #AWS #5G #9News
#
#  ------------------
#
#
# W/ +34% market share worldwide, @AWS is the obvious choice for orgs looking for the benefits a public #cloud delivers.
#
# But how can you navigate the #datamanagement challenges this migration brings? https://t.co/83IAuUiiSi
#
# #dataprotection #datasecurity #Cohesity @AWS_Partners https://t.co/rqXi54HBRs
#
#  ------------------
#
#
# Autonomous flight ✈️ is just around the corner! In the latest This is My Prototype, join @InmarsatGlobal &amp; @a_techsyn who, together with the #AWS prototyping team, are leading autonomous flight with the cloud ☁️  https://t.co/lSP3OzF46p
#
#  ------------------
#
#
# Learn how nClouds uses #AmazonEKS Blueprints to build modern #CloudOps on EKS that accelerate #Kubernetes #ApplicationModernization at scale. #AWScloud #containers #DevOps @AWS_Partners Learn more: https://t.co/wOiRLXWW7v https://t.co/676nXr6UqC
#
#  ------------------
#
#
# #NewJob: Systems Integrator/Engineer
#
# Location: Chantilly, VA
#
# Clearance: US Citizen
#
# Apply: https://t.co/LLzWuBJTAt
#
# #clearancejobs #ITJobs #EngineeringJobs #CloudComputing #Linux #AWS #JobAlert #TechisHiring
#
#  ------------------
#
#
# 57

# %%
topics = []
score = []
sentence = []
counter = 0
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 1:
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        counter += 1
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# #AWS announces EKS Blueprints,  a collection of Infrastructure as Code (IaC) modules that configure &amp; deploy consistent, batteries-included EKS clusters. With support for Terraform &amp; CDK, partner products &amp; self managed add-ons, its a cool way to build https://t.co/yut1iU8yj4
#
#  ------------------
#
#
# #AWS &amp; @Splunk are celebrating 10 years of strategic collaboration! If you want better visibility &amp; control while delivering apps faster, AWS + Splunk are here to help: https://t.co/6mtXmKyljK https://t.co/TISmryilcT
#
#  ------------------
#
#
# Secure and affordable cloud-native #backup for #AWS #EC2 instances. Backup 10 EC2 instances for free. Download &amp; Get started now! https://t.co/DHfhlbIRmb
# #AWSbackup #EC2instances #dataprotection https://t.co/HS0j03tCD3
#
#  ------------------
#
#
# This certification is essential in laying the groundwork for establishing centralized governance and building event-driven security architectures that will help federal agencies like us to move towards Zero Trust cybersecurity principles mandated by the White House
# #infosec #aws https://t.co/auMHVPITXW
#
#  ------------------
#
#
# .NET Enterprise Developer Day EMEA is tomorrow! Learn how to efficiently migrate &amp; modernize your #dotnet applications on #AWS from the experts. Register now for this free one-day virtual conference on April 26th at the link below.
#
# https://t.co/y2uiphLob0
#
#  #dotNETonAWS
#
#  ------------------
#
#
# Aufsite delivers custom cloud solutions for your business. Cloud computing has several advantages for businesses. Contact us now to learn more!
# ☎️ (732) 234-1020
# 📤 sales@aufsite.com
# 🌐 https://t.co/DXUZsvRXPz
# #cloudcomputing #cloud #cloudservices #aws #azure #microsoft https://t.co/BUca0RTyiv
#
#  ------------------
#
#
# AWS Amplify adds visual development tool. Learn more:
#
# https://t.co/hvfF4D5oTq
#
# #AmazonWebServices #DevelopmentTools #WebDevelopment #MobileDevelopment #CloudComputing #SoftwareDevelopment @pjkrill
#
#  ------------------
#
#
# #Azure #aws #tableau #aiforbusiness #automl #analytics Hello Network - Testing out the new Linkedin Smart Links - Give this set of Aible Content Links a look and let me know how it is working -
#
# Thanks - David https://t.co/7hodFd4f8S
#
#  ------------------
#
#
# Want to take your cloud infra to the next level but don’t know where to start?
# Join us with @cloudopsummit for a live panel discussion on Continuous #Cloud Optimization coming up April 27th!
# https://t.co/4om9dou2Hf
# #cloudcomputing #devops #cloudops #aws #k8s #terraform https://t.co/Zh6Zg6uUaN
#
#  ------------------
#
#
# ICYMI: In this interview presented by @PureStorage, @CalvinHP interviews Rajiv Thakkar about @Portwx BaaS version of PX-Backup on #AWS and how #Kubernetes has simplified the deployment aspect of launching applications in the cloud. #Sponsored # https://t.co/IEQVokBcAl https://t.co/femJ2GJmfw
#
#  ------------------
#
#
# Digital Twins on AWS: Driving value with L1 Descriptive Digital Twins https://t.co/i68Lyrjl9M via @awscloud #DigitalTwin #AWS #Amazon
#
#  ------------------
#
#
# CAST AI proved to be one of the best ROI cloud cost initiatives for Branch:
# ✅ Several millions of $ saved
# ✅ Reliability SLAs maintained
# ✅ Real-time cost issue tracking enabled
#
# Read the full case study:
# https://t.co/4CD4oSVBoj
#
# #AWS #cloudnative
#
#  ------------------
#
#
# Learn all tricks, that you need to know about Terraform State.
# #Terraform #Cloud #CloudComputing #AWSSummit #aws #DevOps
# https://t.co/dL1rvz1fP0
#
#  ------------------
#
#
# Migrating to the #cloud is the best place to start when planning a digital #transformation. Watch this video to learn how @Ensono can help you on your #AWS migration journey: https://t.co/PjXgiIz9LA #MakeBetterHappen #DoGreatThings
#
#  ------------------
#
#
# M&amp;A deal number 412 of 2022 (so far). CloudHesive buys #AWS customer service dashboard provider Dextr. #MergersAndAcquisitions #CloudServices #CloudMSP https://t.co/xt91OGsnpM
#
#  ------------------
#
#
# Are you as excited about #DigitalTwin technology as we are? Read about the integration between Element Unify and #AWS IoT TwinMaker. Learn how we work together to help industrials use data to drive business outcomes.
# https://t.co/SF9smw5LEE
#
# #iiot #industrialtransformation https://t.co/ZZY1HrlKLy
#
#  ------------------
#
#
# Here is an exciting opportunity at Salesforce. If you are like me and excited about the AWS and Salesforce partnership and how the two can work together, take a look at this opportunity:  #salesforce #aws #opportunity #workforcedevelopment https://t.co/GILrNcmQPA
#
#  ------------------
#
#
# New in #AWS: Amazon DevOps Guru now provides Proactive Insights to flag issues early on AWS Serverless Applications https://t.co/4ORiCH5Upp
#
#  ------------------
#
#
# Learn how to define dependencies between resources you describe in your template with this #AWS #CloudFormation Workshop lab: https://t.co/4NSDz4nxP3 https://t.co/55v2Wsxkcm
#
#  ------------------
#
#
# In Part 3 of their blog series, Solutions Architects Jagadeesh Chitikesi and Cristobal Espinosa use a .NET Quick Start and AWS CodePipeline to build a complete CI/CD pipeline for a serverless .NET application.
#
# https://t.co/4P7N9OKOfO
#
# #dotnet #AWS #dotNETonAWS
#
#  ------------------
#
#
# Here are the best AWS Elastic Beanstalk alternatives for 2022 👀
#
# https://t.co/IF5GK4TmMQ
#
# #aws #gcp #cloud #beanstalk
#
#  ------------------
#
#
# #MicrosoftAzure is upping the game on Amazon AWS, becoming the preferred choice of Cloud for IT leaders. Become part of the 80% of organizations with Team Venti's help https://t.co/zo9s5a7oUI https://t.co/O2YVOFHsid
#
#  ------------------
#
#
# Join us for the ANZ Partner Summit on 5/17 &amp; learn how to accelerate your engagement with #AWS.
#
# Hear the inspiring story of how @anchorsystems uses the cloud ☁️ to deliver great things for customers: https://t.co/CXyRtnB5p0 https://t.co/0pD0Oo92Iy
#
#  ------------------
#
#
# Amazon Connect, the same tech powering Amazon’s award-winning customer service, is a fully managed cloud contact center service enabled by #MachineLearning to forecast demand, respond to real-time changes &amp; hit service level targets for businesses. 🎯 https://t.co/sCtpJqJDzF #AWS https://t.co/E8nvRcN8EJ
#
#  ------------------
#
#
# SGK has reduced IT infrastructure costs by 83 percent and deployment times by 96 percent.
# SGK created a process to quickly deploy MVPs using a #microservices architecture for increasing the company agility and innovate faster
#
# #serverless #cloud #aws https://t.co/PcYxjlcGuF https://t.co/9W0hJ9xBNN
#
#  ------------------
#
#
# Amazon Connect, the same tech powering Amazon’s award-winning customer service, is a fully managed cloud contact center service enabled by #MachineLearning to forecast demand, respond to real-time changes &amp; hit service level targets for businesses. 🎯 https://t.co/sCtpJqJDzF #AWS https://t.co/E8nvRcN8EJ
#
#  ------------------
#
#
# Amazon Connect, the same tech powering Amazon’s award-winning customer service, is a fully managed cloud contact center service enabled by #MachineLearning to forecast demand, respond to real-time changes &amp; hit service level targets for businesses. 🎯 https://t.co/sCtpJqJDzF #AWS https://t.co/E8nvRcN8EJ
#
#  ------------------
#
#
# Secure Cloud connectivity AND voice control with the WFI32-IOT development board. https://t.co/PxV3iULSB4 #lowpower #wifi #wi-fi #cloud #cloudconnectivity #aws #azure #github #iot https://t.co/3LewZbnm0w
#
#  ------------------
#
#
# What is #amazonwebservices #EKS #Blueprints ?
# Learn more at:
# 1/ video - https://t.co/vnKZ30dnPK
# 2/ repo - https://t.co/kbh8uwcT2P
# 3/ Getting Started - https://t.co/UVN7tCefBH
# 4/ blog - https://t.co/1wkhfcxytq
#
# #kubernetes #awscloud #awscertified #awscommu…https://t.co/9y2xHKH28s
#
#  ------------------
#
#
# Advanced Certification in Azure DevOps with Hatigen.
# Enroll Now
# 📱𝐖𝐡𝐚𝐭𝐬𝐚𝐩𝐩 𝐍𝐨𝐰:-+𝟒𝟒 (𝟎) 𝟐𝟎𝟑𝟏𝟓𝟒𝟑𝟑𝟒𝟓
# 🌐𝐖𝐞𝐛𝐬𝐢𝐭𝐞:- 𝐰𝐰𝐰.𝐇𝐚𝐭𝐢𝐠𝐞𝐧.𝐜𝐨𝐦
# 📧𝐄𝐦𝐚𝐢𝐥:- 𝐢𝐧𝐟𝐨@𝐡𝐚𝐭𝐢𝐠𝐞𝐧.𝐜𝐨𝐦
#
# #azure #cloud #aws #cloudcomputing #devops #techjob https://t.co/whQI1UmAiH
#
#  ------------------
#
#
# Next stop #AWS Summit London 🚀 Learn how to automate, simplify &amp; optimize your cloud infrastructure. Find Spot at Booth #S19! 👋
#
# @awscloud #awssummit https://t.co/snfRwB4TVe
#
#  ------------------
#
#
# 🚨 Free DevOps Training 🚨 I propose 4 free sessions of training of 30 minutes to learn to build a complete CI/CD pipeline with Docker, GitHub Actions, AWS, Qovery, and Terraform.
#
# #cloud #gitops #devops #sre #aws #azure #gcp #training #CloudComputing https://t.co/ESiVaLtVKE
#
#  ------------------
#
#
# Cloud computing lower your costs is perhaps the most touted of the cloud's many benefits, and it’s easy to see how with these 5 steps.
#
# #Cloud #Aws #CloudMigration #Agile #Digital #Cloudcomputing
#
# https://t.co/W08RTUaqGv https://t.co/7dkBQlfQf4
#
#  ------------------
#
#
# Learn How to Deploy 12 Apps to AWS, Azure, &amp; Google Cloud - Via @freeCodeCamp
#
# Read more: https://t.co/MxuAmxp60T
#
# #Cloud #CloudComputing #Serverless #CloudNative #Developer #Programming #LearnProgramming #AWS #Microsoft #Azure #Google #GoogleCloud #Tutorial #freeCodeCamp https://t.co/qdqgq7Awj5
#
#  ------------------
#
#
# Cloud Titans Seek to Slash Carbon Impact: AWS, Meta, Google and Microsoft join 70 firms in iMasons Climate Accord to step up #datacenter carbon tracking.  @InfraMason #cloud #climate #sustainability https://t.co/B48ccyk5Qp
#
#  ------------------
#
#
# Our 2022 Cloud MSP Vendor Map positions the top managed cloud service providers for #AWS, #Azure, and #GoogleCloud in an easy-to-understand Venn diagram.
# https://t.co/cUNKL3ZqyR
# #cloud #cloudcomputing #cloudmanagement
#
#  ------------------
#
#
# Why are more and more companies switching to #cloud-native development? Find out the answer at the #AWSSummit in Madrid on May 5 and stop by Booth S11 to see the power of @OutSystems on @awscloud. 🚀 https://t.co/oSOA3ZHzHc https://t.co/c2CaffmBTH
#
#  ------------------
#
#
# [100% Off] The Python Developer Essentials 2022 Immersive Bootcamp
#
# https://t.co/dzi4j8lemV
#
# #coursetreat #100DaysOfCode #Python #Machinelearning #DataScience #IOT #Webdevelopment #Javascript #ReactJs #Coding #BigData #womenintech #WomenWhoCode #TensorFlow #Programming #AWS
#
#  ------------------
#
#
# Both #AWS and #Cloudera offer advanced #cognitiveanalytics that allow manufacturers to build innovative solutions to improve driver’s experience and operational efficiency.
#
# Explore more here: https://t.co/Ss6zBsvHLB
#
# #datascience #machinelearning #python #artificialintelligence
#
#  ------------------
#
#
# Want to take your cloud infra to the next level but don’t know where to start?
# Join us with @cloudopsummit for a live panel discussion on Continuous #Cloud Optimization tomorrow!
# https://t.co/oGNmSoYWHP
# #cloudcomputing #devops #cloudops #aws #k8s #terraform https://t.co/kOvGKIMJwm
#
#  ------------------
#
#
# Looking forward to presenting in the AWS booth (W3500) at NAB today at noon. Stop by to learn more about https://t.co/GRxcVMwJC7 Archive-Migration-as-a-Service (AMaaS) managed archive migration services.
#
# #aws #nabshow #nab2022 #…https://t.co/KTjCZPjS00 https://t.co/MClGqKvmfF
#
#  ------------------
#
#
# Good news for our neighbors to the north—today's the launch of the new Wavelength Zone in Toronto. 🇨🇦🤳🏼📱
#
# It’s the first public MEC offering in Canada on the @Bell_Business 5G Network. Get ready to develop &amp; deploy ultra-low-latency apps. https://t.co/3pmCX30a13 #AWS #Developer https://t.co/YfPbhqHK6m
#
#  ------------------
#
#
# This article covers everything you need to know about #cloud-based #productdevelopment.
#
# https://t.co/AL8yaArwH1
#
# #cloudcomputing #digitalproduct #aws #azure #development #software
# CC: @Shi4Tech @antgrasso @enricomolinari @ChuckDBrooks @MikeQuindazzi @TamaraMcCleary @sallyeaves https://t.co/azjWgUKbAu
#
#  ------------------
#
#
# This article covers everything you need to know about #cloud-based #productdevelopment.
#
# https://t.co/AL8yaArwH1
#
# #cloudcomputing #digitalproduct #aws #azure #development #software
# CC: @Shi4Tech @antgrasso @enricomolinari @ChuckDBrooks @MikeQuindazzi @TamaraMcCleary @sallyeaves https://t.co/azjWgUKbAu
#
#  ------------------
#
#
# This article covers everything you need to know about #cloud-based #productdevelopment.
#
# https://t.co/AL8yaArwH1
#
# #cloudcomputing #digitalproduct #aws #azure #development #software
# CC: @Shi4Tech @antgrasso @enricomolinari @ChuckDBrooks @MikeQuindazzi @TamaraMcCleary @sallyeaves https://t.co/azjWgUKbAu
#
#  ------------------
#
#
# Can your .NET code keep a secret? In this video, Engineering Manager @nickchapsas explains how to store secrets correctly in .NET applications using AWS Secrets Manager.
#
# https://t.co/rd6nLONo4b
#
# #dotnet #AWS #dotNETonAWS
#
#  ------------------
#
#
# We are pleased to announce that in all #AWS Regions that support Amazon #Cognito, you can now integrate Amazon Cognito with Amazon Simple Email Service (Amazon #SES) and Amazon Simple Notification Service (Amazon #SNS) in the same Region.
#
# #DevOps https://t.co/llZuHR6ta4
#
#  ------------------
#
#
# Good news for our neighbors to the north—today's the launch of the new Wavelength Zone in Toronto. 🇨🇦🤳🏼📱
#
# It’s the first public MEC offering in Canada on the @Bell_Business 5G Network. Get ready to develop &amp; deploy ultra-low-latency apps. https://t.co/3pmCX30a13 #AWS #Developer https://t.co/YfPbhqHK6m
#
#  ------------------
#
#
# This article covers everything you need to know about #cloud-based #productdevelopment.
#
# https://t.co/AL8yaArwH1
#
# #cloudcomputing #digitalproduct #aws #azure #development #software
# CC: @Shi4Tech @antgrasso @enricomolinari @ChuckDBrooks @MikeQuindazzi @TamaraMcCleary @sallyeaves https://t.co/azjWgUKbAu
#
#  ------------------
#
#
# API (GraphQL) - Connect to machine learning services - AWS Amplify Docs https://t.co/O3GhvUHYoq #ai #ml #dl
#
#  ------------------
#
#
# Good news for our neighbors to the north—today's the launch of the new Wavelength Zone in Toronto. 🇨🇦🤳🏼📱
#
# It’s the first public MEC offering in Canada on the @Bell_Business 5G Network. Get ready to develop &amp; deploy ultra-low-latency apps. https://t.co/3pmCX30a13 #AWS #Developer https://t.co/YfPbhqHK6m
#
#  ------------------
#
#
# In Part 3 of their blog series, Solutions Architects Jagadeesh Chitikesi and Cristobal Espinosa use a .NET Quick Start and AWS CodePipeline to build a complete CI/CD pipeline for a serverless .NET application.
#
# https://t.co/4P7N9OKOfO
#
# #dotnet #AWS #dotNETonAWS
#
#  ------------------
#
#
# #VMware Cloud on #AWS #GovCloud (US) is an integrated cloud offering jointly developed by Amazon Web Services and VMware. It provides a seamless hybrid cloud by extending the organization’s on-premises vSphere environment to the AWS Cloud. Learn more. https://t.co/m31pAltEp8 https://t.co/9gXCbwSfqB
#
#  ------------------
#
#
# Azure may have finally toppled AWS in the global cloud battle: #artificialintelligence #iot copy: @motorcycletwitt https://t.co/8jPSIKvnNM https://t.co/WNYP9vb1Vn
#
#  ------------------
#
#
# Amazon Connect, the same tech powering Amazon’s award-winning customer service, is a fully managed cloud contact center service enabled by #MachineLearning to forecast demand, respond to real-time changes &amp; hit service level targets for businesses. 🎯 https://t.co/sCtpJqJDzF #AWS https://t.co/E8nvRcN8EJ
#
#  ------------------
#
#
# The @Amazon Web Services (@awscloud) Summit London is back!
#
# Join Toluna and @Coralogix for a session on ensuring full visibility during #AWS cloud migration. Register here: https://t.co/ORs3TOI09D
#
# #AWSSummit #AWSLondon #cloudmigration #marketresearch #mrx https://t.co/Xti80Gsk0g
#
#  ------------------
#
#
# The @Amazon Web Services (@awscloud) Summit London is back!
#
# Join Toluna and @Coralogix for a session on ensuring full visibility during #AWS cloud migration. Register here: https://t.co/pmF7KYQ1Mz
#
# #AWSSummit #AWSLondon #cloudmigration #marketresearch #mrx | @TolunaCorporate https://t.co/DWnsjSmvkR
#
#  ------------------
#
#
# Join @chira001, @rg_olver, @nvermande, @crmilsted, and more at @AWS_UKI Summit London 2022 tomorrow at Booth S23 where we are giving away an Apple Watch Series 7 to one lucky winner! #kubernetes #devops #aws
#
# Learn more:
#
# #AWSSummit #AWS_Partner #Cloud https://t.co/n1dUDz2vdm
#
#  ------------------
#
#
# Bolster your cloud security awareness by registering now! ☁️🛡
#
# Lock in 2 days of learning at #AWS #reInforce, where you’ll hear the latest from industry-leading experts about compliance, identity, privacy &amp; more. 👩‍💻👨‍💻💡🔐
#
# Register now 👉 https://t.co/ciWGiQQYSr
# #CloudSecurity https://t.co/6hPS1s7xH9
#
#  ------------------
#
#
# Judge dismisses most claims in Sony gender discrimination lawsuit: #AI #IoT #BigData CC: @worldtrendsinfo https://t.co/NQCvlJm1YQ https://t.co/eE3FDXz2oQ
#
#  ------------------
#
#
# Bolster your cloud security awareness by registering now! ☁️🛡
#
# Lock in 2 days of learning at #AWS #reInforce, where you’ll hear the latest from industry-leading experts about compliance, identity, privacy &amp; more. 👩‍💻👨‍💻💡🔐
#
# Register now 👉 https://t.co/ciWGiQQYSr
# #CloudSecurity https://t.co/6hPS1s7xH9
#
#  ------------------
#
#
# 61

# %%
topics = []
score = []
sentence = []
counter = 0
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 2:
        counter += 1
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# Senior Architect - Permanent/Remote anywhere in Canada (Vancity based) - Golang, SaaS/PaaS/IaaS, DevSecOps, scale and build new features for visionary product - kbarr@teemagroup.com #softwaredesign #Golang #softwarearchitect #remotejobs #backendengineer #Azure #AWS #gcpcloud
#
#  ------------------
#
#
# See a request in a forest of logs.
#
# Quickly and easily combine multiple log groups into a unified view and filter by request ID to see a single request across multiple AWS lambdas and services.
#
# https://t.co/aqdmMHbrEO
#
# #serverless #aws #lambda #148
#
#  ------------------
#
#
# Senior Architect - Permanent/Remote anywhere in Canada (Vancity based) - Golang, SaaS/PaaS/IaaS, DevSecOps, scale and build new features for visionary product - kbarr@teemagroup.com #softwaredesign #Golang #softwarearchitect #remotejobs #backendengineer #Azure #AWS #gcpcloud
#
#  ------------------
#
#
# I will be at the #NABshow. Would love to connect, share notes/trends on the world of #streaming and the latest with @cloudfront #AWS.
#
#  ------------------
#
#
# Build a File Upload System on AWS with React and a Serverless API
# #react #aws #serverless
# https://t.co/RhhaNZ68eb
#
#  ------------------
#
#
# More delays to DoD cloud contract; #AWS, #Azure, #Google, #Oracle in the running
#
# Read more about the contract in our latest article: https://t.co/wl7qXFBNbm
#
# #cloud @awscloud @GoogleCloudTech @Oracle @Azure  #managedhosting https://t.co/7mCnJwV96M
#
#  ------------------
#
#
# Check out our solution brief, where we walk you through how to detect @awscloud misconfigurations and suspicious activity in real-time with detection-as-code and normalized logs in a security data lake.
#
# Learn more here👉  https://t.co/r8IHdFXcY1
#
# #AWS #datalake https://t.co/WWvfY4b5xY
#
#  ------------------
#
#
# Learn how to automatically rename remote worker agents based on the employee's HR profile through the use of AWS Lambda and the NetBeez API! https://t.co/Ty0pR2WU4d #api #aws #awslambda
#
#  ------------------
#
#
# @GoldmanSachs and #AmazonWebServices (#AWS) collaborate to create new data management and analytics solutions for financial services organizations. Read more...
#
# https://t.co/vesvAv93VY
#
# #aws #analytics #financialservices #amazon #datamanagement #research
#
#  ------------------
#
#
# Red Lion Hotels increased network speeds, accelerated load times, and decreased cost, making a better #travel experience for their guests. Click below to find out how they worked with 2nd Watch to accomplish this feat. #cloudmigration #AWS #redlionhotels https://t.co/Gn2faOBhX4 https://t.co/WJck3YUIXj
#
#  ------------------
#
#
# Make #CloudComputing fit your schedule. ☁️⏱💻
#
# Watch @SwamiSivasubram's #AWSSummit SF Keynote as he discusses exciting innovations that make #AWS the best place to run your applications &amp; make better, faster data decisions.
#
# View on demand 👀 https://t.co/LhPBtU3lD4 #Developer https://t.co/5BDuwq2R1C
#
#  ------------------
#
#
# awscloud: Make #CloudComputing fit your schedule. ☁️⏱💻
#
# Watch @SwamiSivasubram's #AWSSummit SF Keynote as he discusses exciting innovations that make #AWS the best place to run your applications &amp; make better, faster data decisions.
#
# View on demand… https://t.co/kR8XXreHZD
#
#  ------------------
#
#
# I've had so much fun at the #AWSSummit in San Francisco last week. I had to make a video about it! 🥳
#
# Check out my ramblings about my experience, and get a sneak peek at some future videos coming out! ❤️
#
# https://t.co/O9LobS3WH2
#
# #aws
#
#  ------------------
#
#
# #ISV’s get ahead of what’s coming! Join us and #AWS to hear how to modernize your application for faster performance, increased reliability, and cost-effectiveness to enhance urbanism and the #smartcity experience. #applicationmigration #modernization https://t.co/u4lbykqE3Z https://t.co/11cv48cSle
#
#  ------------------
#
#
# It takes two. 👯‍♀️ 📈🏢
#
# With #AWS #IoT TwinMaker, you can build digital twins of real-world systems to create a holistic view of your business with less time &amp; effort. Twinning is winning!
#
# 👉 https://t.co/bXsDGcTp1X #AWS #CloudComputing #Developer https://t.co/qWYpTNikO6
#
#  ------------------
#
#
# @MissionCloud wins managed AWS customer for ML capabilities
#
# Read more in our latest article, analysis by @phils88888 : https://t.co/8jUPLMSy5p
#
# #AWS @awscloud #machinelearning #cloud #MSP #managedservices https://t.co/Z6EwG3zg4z
#
#  ------------------
#
#
# awscloud: It takes two. 👯‍♀️ 📈🏢
#
# With #AWS #IoT TwinMaker, you can build digital twins of real-world systems to create a holistic view of your business with less time &amp; effort. Twinning is winning!
#
# 👉 https://t.co/hKHwbEesn7 #AWS #CloudComputing #Deve… https://t.co/IgHgBnzoR8
#
#  ------------------
#
#
# See a request in a forest of logs.
#
# Quickly and easily combine multiple log groups into a unified view and filter by request ID to see a single request across multiple AWS lambdas and services.
#
# https://t.co/aqdmMHbrEO
#
# #serverless #aws #lambda #149
#
#  ------------------
#
#
# Here are the best AWS Elastic Beanstalk alternatives for 2022 👀
#
# https://t.co/IF5GK4TmMQ
#
# #aws #gcp #cloud #beanstalk
#
#  ------------------
#
#
# Hey there NerdHerders! Learn how to hire an AWS Developer in 2022 through this video, based on the blog written by Forrest Brown, Content Manager here at NerdRabbit. Read the full article here ➡️ https://t.co/BvC6CRCqTa
# #NerdRabbit #aws #cloudmigration #costsaving #awscertified https://t.co/tpDNDLJOwt
#
#  ------------------
#
#
# Senior Architect - Permanent/Remote anywhere in Canada (Vancity based) - Golang, SaaS/PaaS/IaaS, DevSecOps, scale and build new features for visionary product - kbarr@teemagroup.com #softwaredesign #Golang #softwarearchitect #remotejobs #backendengineer #Azure #AWS #gcpcloud
#
#  ------------------
#
#
# Here are 5 ways for Microsoft CSPs sales teams to drive up their monthly revenue figures through better customer experiences: https://t.co/wuhRpfZXW8
#
# #microsoft #devops #Azure #devops #cloud #programming #cloudcomputing #aws #linux
#
#  ------------------
#
#
# On the other hand, if you choose teams that for instance create SaaS products, you'll soon realize why your fundamentals matter and why the interviews also (in some ways) make sense. At large tech companies, where you can jump teams, all these skills become highly relevant. #AWS
#
#  ------------------
#
#
# Check out my mentor, Dean of Engineering, Dr. Ayanna Howard 👑 @robotsmarts, discussing how she is making AI, robotics, and engineering look more like the people they serve. #AWS
#
#  https://t.co/bDenn8BKP1
#
#  ------------------
#
#
# Optimize AI/ML workloads for sustainability: Part 1, identify business goals, validate ML use, and process data #aws #sustainability #cloud  https://t.co/PFO6HvB1Wo
#
#  ------------------
#
#
# Hi All,
#
# She is my known contact and good in technical. She is now located in Bangalore. If you and your circle looking for any resources do forward.
#
# #job #aws #kubernetes #docker #share #comment #like #freshers #jobopportunities #network #linux #recrui…https://t.co/R6ZyLEy86v
#
#  ------------------
#
#
# FBI warns of cyber attacks on agriculture, stay prepared with the right defense.
# #team #cybersecurity #informationtechnology #Texas #Austin #cloudsecurity #Azure #Aws #supplychaincrisis #Ransomware #edrecovery #Dallas #Houston #SanAntonio #cloudsecurity
#
# https://t.co/vrYi7yuefN
#
#  ------------------
#
#
# Google Pixel unleashed a game-changing virtual experience where you can create, play, share &amp; celebrate your 2022 NBA Playoffs skills! 🏀 https://t.co/Q7JRuphsa5
# •••
# #appbarry #makeitappen #atlanta #softwaredevelopment #appdevelopment #aws #NBA #google #pixel #googlepixelarena https://t.co/5BzoI9nqsj
#
#  ------------------
#
#
# [video] @Starbucks builds seamless customer experiences on #AWS https://t.co/gzFVwfifmV @awscloud #Cloud #CloudComputing #Innovation #CX #CustomerExperience #DigitalTransformation https://t.co/QoBpJ6YBfG
#
#  ------------------
#
#
# I once created an #aws Lambda that sent me 16,000 emails. I was sure nobody would ever create a worse piece of code. Yesterday, AkuDreams held a Dutch Auction for their #NFT drop, their poorly written smart contract caused the minting funds to be locked - $34M Gone Forever 😬😬
#
#  ------------------
#
#
# [100% Off] How to Create a Marketing Video for Your Business or Product
#
# https://t.co/ForjfdCn2E
#
# #coursetreat #100DaysOfCode #Python #Machinelearning #DataScience #IOT #Webdevelopment #Javascript #ReactJs #Coding #BigData #womenintech #WomenWhoCode #TensorFlow #Programming #AWS
#
#  ------------------
#
#
# I'm putting together a little #AWS Networking Fundamentals CloudFormation video. We're going to cover how to build out networks with some automation via CloudFormation scripts🔥
#
# Subscribe so you don't miss out🤝
# https://t.co/0ARhl8urX2 https://t.co/bhWkDku9eF
#
#  ------------------
#
#
# #AWS compliance is a continuous process, meaning you have to stay on it at all times. Here are some of the best ways to achieve #compliance for the various regulatory standards you may face: https://t.co/BptGdsOJRI https://t.co/L59Ksl2ghj
#
#  ------------------
#
#
# Optimize AI/ML workloads for sustainability: Part 1, identify business goals, validate ML use, and process data #aws #sustainability #cloud  https://t.co/PFO6HvB1Wo
#
#  ------------------
#
#
# Free Virtual Hands-On Workshop: Boost your serverless application availability with AIOps on #AWS . Register today at https://t.co/H7uRwVhlPj
#
# Featuring Amazon DevOps Guru, Lambda, API Gateway, and DynamoDB. https://t.co/AvUACw096R
#
#  ------------------
#
#
# 101 global #Twitter influencers to follow for 2022.
#
# Thank you so much @getengati
#
# Congratulations to all the #influencers
#
# Thanks: @nvidia @amazon @AWS @Twitter @Azure @Dataprius @Microsoft
#
# #ElonMusk #ElonMuskTwitter #IoT #CloudComputing #AI #Cloud
#
# https://t.co/Uzb4UAnSL1 https://t.co/M3iL4ydJJ3
#
#  ------------------
#
#
# New AWS Wavelength Zone in Toronto – The First in Canada https://t.co/d36ohE1osu #AWS https://t.co/Qt5gtC1RdZ
#
#  ------------------
#
#
# HIRING: Manager, Product Security / REMOTE https://t.co/9cRtmLdyFV #InfoSec #InfoSecJobs #Cybersecurity #security #jobsearch #techjobs #hiringnow #RemoteJob #AWS #DevOps #SaaS
#
#  ------------------
#
#
# Just got off a call with @mchancloud from #AWS Identity. Michael, thank you for letting me vent a bit about IAM and Organizations APIs and user experience. Thank you for advising me on a step forward for the #CNCF's infrastructure needs and being #CustomerObsessed.
#
#  ------------------
#
#
# 39

# %%
topics = []
score = []
sentence = []
counter = 0
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 3:
        counter += 1
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# AWS CMO Rachel Thornton on the future of customer-obsessed marketing in 2022 https://t.co/AYxZxuAJNz via @VentureBeat  #AWS #B2B
#
#  ------------------
#
#
# #amazonwebservices has a many beautiful #pins and #stickers ! Strongly suggest you attend their #Summits ! See more at https://t.co/V8eLfEJmGw
#
# e.g. #awssummit2022  #London April 27, 2022, then AWS Summit #Madrid May 04 - May 05, 2022, then #Korea, #Stock…https://t.co/UV6hulu91N
#
#  ------------------
#
#
# @TammyCloudLover Oh trust me that’s never happening. I’m in the lab currently #aws
#
#  ------------------
#
#
# 💭 #AWS #Aurora Serverless V2 now has public access (V1 only allowed access from within a VPC). Now you can have serverless &amp; fully-managed benefits (cost savings + no fear of db size limits... i think) while doing something like creating a ton of dbs per #git branch
#
# #database https://t.co/8WoXs90gO2
#
#  ------------------
#
#
# It’s test time #aws as soon as I’m 100% I’m getting to that bag
#
#  ------------------
#
#
# #Seattle #AWS looking forward for 4 days of learning at the quarterly boot camp. https://t.co/oVWUwzKUvn
#
#  ------------------
#
#
# By understanding the adversary, defenders can better address security controls &amp; gaps that may allow an attacker to gain a foothold. Read how an attacker can use #Log4j shell TTPs to exploit Log4j in an #AWS cloud env't https://t.co/3hhc4mVX7F
#
#  ------------------
#
#
# NorthBay helps organizations understand where, when and how best to leverage the power of AI/ML to enhance data-driven decision making, increase productivity, and solve old problems in new ways. Learn how:  https://t.co/uoEFLhAYrF
# #northbay #ai #ml #cloud #aws https://t.co/lKsG7FB3P1
#
#  ------------------
#
#
# Coming to the #awssummit in London and feeling like you have been threading water at work and home lately? Check our workshop that we developed from the lessons we learned while helping over 150,000 Amazonians learn emotional intelligence. #AWS #mentalhealth https://t.co/AelGbSDoZS
#
#  ------------------
#
#
# Happy Monday!
#
# In Level 4/6 of https://t.co/bvZgt6FtyE, we explore how leaked AWS keys in addition to publicly accessible and unencrypted ec2 snapshots can be used to gain access to an AWS environment.
#
# #aws #awscommunitybuilder #cloudsecurity #cloud
# 👉🏾https://t.co/7kSRZZC1gW
#
#  ------------------
#
#
# The old ways of securing data on #AWS don't work at #cloud-scale.
#
# Get a fresh perspective on modern #DataSecurity in this conversation between Open Raven CEO Dave Cole and @goteleport CEO @kontsevoy.
#
# 🖱 https://t.co/kSEsn8ZjGE https://t.co/6OpiOPfuMf
#
#  ------------------
#
#
# Check out how easy it is to run your SQL Server on AWS in this hands-on, step-by-step lab in an #AWS environment. Register today! https://t.co/onzJjKyZdq
# #AWSCloud #CloudComputing #Stratus10 https://t.co/x588SUBy5D
#
#  ------------------
#
#
# Join our webinar where we discuss how to optimize how your teams use cloud infrastructure with tools such as #Terraform, #AWS #CloudFormation, and #Azure Resource Manager.
#
# https://t.co/yzVp9KpVu4 https://t.co/noGfqTgkvZ
#
#  ------------------
#
#
# Get complete data protection for your #AWS #EC2 instances at an affordable cost. Start your 30 days free trial now! https://t.co/DHfhlbIRmb
# #AWSbackup #EC2instances #dataprotection https://t.co/77acnhHoPk
#
#  ------------------
#
#
# The "hotpatch" released by #AWS in response to the #Log4Shell vulnerabilities could be leveraged for container escape and privilege escalation, allowing an attacker to seize control of the underlying host. Read more🔗https://t.co/SqgdNx2O36
# #Cybersecurity #Pentest https://t.co/e3MmgE3wrs
#
#  ------------------
#
#
# #AWS Week in Review - April 25, 2022 - https://t.co/S2IBMuKMNb
#
#  ------------------
#
#
# Buckle up for the most exciting @AWS security ride! 🚀
#
# @NorthSec_io  and @we45 are bringing 'Purple Team #AWS (Virtual training)'.
#
# This 2 Day training given by @abhaybhargav  is an extensive deep-dive into Attack, Detect, and Defense implementations within AWS.
#
# Register now:
#
#  ------------------
#
#
# @AWS @NorthSec_io @abhaybhargav 2 /
#
# Who Should Attend this Purple team AWS training by @NorthSec_io:
#
# 👉 Cloud Professionals - #AWS
# 👉 #Pentesters
# 👉 #CloudSecurity Practitioners
# 👉 Red-Teamers
# 👉 #DevOps professionals
# 👉 #DevSecOps Professionals
# 👉 #AppSec Professionals
#
#  ------------------
#
#
# Learn how to test #Terraform compliance using #OpenPolicyAgent. OPA provides policy-based control of #CloudNative environments on #AWS. Using OPA, you can apply compliance policies to Terraform changes before deployment. @AWS_Partners View tutorial video https://t.co/IgauLF4mkX https://t.co/CeCdhCd4LV
#
#  ------------------
#
#
# GIVEAWAY! Our #Catalyst apps close 4/29 for early stage women founders. We’re celebrating this EPIC opp with the help of @AWS by giving 3 lucky winners 10k #AWS credits EACH. To enter, retweet this post &amp; follow us here! #GrahamAndWalker
#
# https://t.co/CoY8nMeFtW https://t.co/t5p7s4ruQY
#
#  ------------------
#
#
# Next week, I will be celebrating 4 months w/ @awscloud @AWSIdentity. This continues to be one of the most rewarding experiences of my career. So how is it so far? Check out my post on😀
# https://t.co/RiMdNkGldh
#
# #aws #amazon #leadership #career #amazonian #awscloud
#
#  ------------------
#
#
# AWS Week in Review – April 25, 2022 https://t.co/Qjm26gln5h #AWS https://t.co/kDGn1fbxOd
#
#  ------------------
#
#
# We cannot slander people and try to use the powers to strengthen ourselves. The audience of life waits to see the truth present itself and shame the lie.
# #awsreinvent  #AWS   @ShieldVoC https://t.co/hapRS18l37
#
#  ------------------
#
#
# Author AWS Glue jobs with PyCharm using AWS Glue interactive sessions https://t.co/p24e8mU7qn #AWS #ETL #Python
#
#  ------------------
#
#
# Cool - #AWS Powers Scuderia Ferrari - https://t.co/wzhrhf4o4i
#
# 🏎️Car Design
# 🏁Fan Engagement
# 📱Better Consumer Interactions https://t.co/vRHPincDAQ
#
#  ------------------
#
#
# Cool - #AWS Powers Scuderia Ferrari - https://t.co/wzhrhf4o4i
#
# 🏎️Car Design
# 🏁Fan Engagement
# 📱Better Consumer Interactions https://t.co/vRHPincDAQ
#
#  ------------------
#
#
# Cool - #AWS Powers Scuderia Ferrari - https://t.co/wzhrhf4o4i
#
# 🏎️Car Design
# 🏁Fan Engagement
# 📱Better Consumer Interactions https://t.co/vRHPincDAQ
#
#  ------------------
#
#
# Let’s Architect! Architecting for Blockchain #aws #cloud #architecting #awsblog   https://t.co/A2J2IJCPkk
#
#  ------------------
#
#
# HIRING: Threat Hunter / Munich, Germany https://t.co/Ntn0ICCraW #InfoSec #InfoSecJobs #Cybersecurity #security #jobsearch #techjobs #hiringnow #Munich #Germany #AWS #Azure #Cloud #DNS #Firewall #Python #SIEM #SaaS
#
#  ------------------
#
#
# Financial technology companies make our lives easier and faster, but it also creates more vulnerabilities. Here’s what our Expert Mr Aseem Rastogi recommends for Fintech companies to protect and store sensitive financial data.
# #cloud #cloudsecurity #aws #gcp #azure #kubernetes https://t.co/iiGnOkaoaP
#
#  ------------------
#
#
# Best open-source app framework for Machine Learning and Data Science 👇
#
# https://t.co/7P80YvGbIJ
#
# #opensource #DEVCommunity #javascript #MachineLearning #Flutter #Python #AWS #DevOps #KubeCon #Kubernetes #CloudComputing #Java #AI #React #Reactjs #angularjs #Web3 #Docker https://t.co/3PtCyaFIte
#
#  ------------------
#
#
# @BaheerNoori2 @scrumtuous I share my Spotify password with friends so THEY can listen to @joerogan as well. And he sometimes has guests that talk #code, #development, computer #programming and software in general. #devops #javascript #aws #rustlang #100DaysOfCode
#
#  ------------------
#
#
# SADA CEO Tony Safoian: How Google Cloud Is Besting AWS: https://t.co/bhk77Po9iR
#
# @SADA's @safoian talks to @CRN about the company’s new $2.5 billion @googlecloud partnership, besting #cloud competitor AWS and its push to become a more global channel partner.
#
# @gcloudpartners https://t.co/eZt7McGsZc
#
#  ------------------
#
#
# Let’s Architect! Architecting for Blockchain #aws #cloud #architecting #awsblog   https://t.co/A2J2IJCPkk
#
#  ------------------
#
#
# GIVEAWAY! Our #Catalyst apps close 4/29 for early stage women founders. We’re celebrating this EPIC opp with the help of @AWS by giving 3 lucky winners 10k #AWS credits EACH. To enter, retweet this post &amp; follow us here! #GrahamAndWalker
#
# https://t.co/CoY8nMeFtW https://t.co/t5p7s4ruQY
#
#  ------------------
#
#
# #AWS Big Data Blog: Amazon Redshift Continues its Price-Performance Leadership - https://t.co/xmUUUmcvpt
#
# "As we started to look deeper into how Amazon Redshift ran these kinds of workloads, we discovered several opportunities to optimize performance..." https://t.co/tH0g5F84cG
#
#  ------------------
#
#
# AWS Lambda Retry mechanism can cause a headache. 🤕
#
# In this post, guest author @enricop89 analyzes the AWS Lambda Retry Policy and the different techniques, as well as the best practices to handle errors.
#
# #ServerlessFramework #Serverless #AWS #Lambda
# https://t.co/Bh30dhJKnT
#
#  ------------------
#
#
# We help companies build, automate, and manage their business operations in the #AWS cloud infrastructure.
# Get a Quote Now: https://t.co/EC38voomiV
# #purelogics #digital #outsourcing #mobileappdevelopment #uiuxdesign #webdev #productdesign #cloudservices #awsservices #tech #agency https://t.co/LZgNEE1tmY
#
#  ------------------
#
#
# 📢 We’ll be at the #AWSSummit in Stockholm on May 11! Come meet our team at Booth S5 to learn more about #lowcode and #cloud-native development with @OutSystems on @awscloud. https://t.co/xKdkFfl2vG https://t.co/DpGgluqYyS
#
#  ------------------
#
#
# @awscloud releases IoT TwinMaker into GA; edge scenarios
#
# Read more about the new tool in our article: https://t.co/QjojfEcMEq
#
# #AWS #edge #cloud #Amazon #amazonwebservices https://t.co/Qpkatm8qQq
#
#  ------------------
#
#
# #blockchain Real estate meets #crypto: Startups offer token-based investments - NBC News https://t.co/di6lSi7wNO
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes
#
#  ------------------
#
#
# Keynote rehearsals in full swing at the #AWS Summit London. #thatdbegreat https://t.co/rWc3OkI5OL
#
#  ------------------
#
#
# #AWS Big Data Blog: Amazon Redshift Continues its Price-Performance Leadership - https://t.co/xmUUUmcvpt
#
# "As we started to look deeper into how Amazon Redshift ran these kinds of workloads, we discovered several opportunities to optimize performance..." https://t.co/tH0g5F84cG
#
#  ------------------
#
#
# Learn how nClouds helped a leading bath &amp; spa products company gain improved visibility into #AWScosts &amp; enhance #CostOptimization with #AWSConsolidatedBilling. #DevOps #WellArchitected @AWS_Partners Read case study https://t.co/zMV1rJGAbm https://t.co/ynGYENMKdR
#
#  ------------------
#
#
# Don't miss our LIVE DEMO happening this week! Register today to join us to learn about @awscloud Amazon Connect: https://t.co/0wUzAvSaZ4
#
# #AWS #AWSpartner #amazonconnect #webinar #livedemo #InterVision #contactcenter
#
#  ------------------
#
#
# Super informative blog from #AWS Chief Evangelist Jeff Barr on the new Cloud #NGFW for AWS https://t.co/SFOwYcuj46 via @awscloud
#
#  ------------------
#
#
# 46

# %% [markdown]
# We perform the same analysis for Azure

# %%
noam_region_azure_cloud = df_with_countries.loc[(df_with_countries['Region']=='NOAM') & (df_with_countries['is_azure']==1)]

# %%
noam_region_azure_cloud.shape
# Out:
# (9961, 19)

# %%
noam_region_azure_cloud_train = noam_region_azure_cloud

# %%
corpus = []
for i in range(noam_region_azure_cloud_train.shape[0]):
    try:    
        corpus.append(noam_region_azure_cloud_train['clean_text'].iloc[i].split())
    except Exception as e:
        print(e)
        print(noam_region_azure_cloud_train['clean_text'].iloc[i], i)
        continue
    
dct = corpora.Dictionary(corpus)

# %%
dct.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dct.doc2bow(doc) for doc in corpus]

# %%
len(bow_corpus)
# Out:
# 9961

# %%
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=4, id2word=dct, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.015*"azure" + 0.010*"learn" + 0.010*"data" + 0.008*"team" + 0.007*"update" + 0.007*"service" + 0.007*"rt" + 0.007*"new" + 0.007*"got" + 0.006*"say"
# Topic: 1 Word: 0.012*"troll" + 0.011*"azure" + 0.010*"learn" + 0.009*"one" + 0.008*"hear" + 0.008*"microsoft" + 0.008*"business" + 0.007*"would" + 0.007*"service" + 0.007*"never"
# Topic: 2 Word: 0.013*"access" + 0.012*"like" + 0.010*"gifted" + 0.009*"run" + 0.009*"see" + 0.008*"get" + 0.008*"look" + 0.008*"vms" + 0.007*"azure" + 0.007*"includes"
# Topic: 3 Word: 0.029*"troll" + 0.024*"verified" + 0.011*"cloud" + 0.009*"help" + 0.009*"one" + 0.008*"love" + 0.008*"azure" + 0.008*"today" + 0.006*"need" + 0.006*"fact"

# %%
bow_corpus_test = bow_corpus[:200]

# %%
new_df = pd.merge(noam_region_azure_cloud, df[['text', 'tweetid']], how='left', on ='tweetid')

# %%
topics = []
score = []
sentence = []
counter = 0 
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 0:
        counter += 1
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# Passed my Azure Fundamentals exam this past Wednesday. Excited to go down this path. #cloudengineer #microsoftazure #azure https://t.co/LCzfSthMVX
#
#  ------------------
#
#
# AlpsLogic IT Solutions has experience &amp; expertise in a broad range of Microsoft technologies and languages 👍 #USA #Canada #hustle #business #entrepreneur #motivation #remote #nomad #angular #Azure #SharePoint #Dotnet #MVC #Microsoft #Technologies https://t.co/Uhx1OM0aE8
#
#  ------------------
#
#
# How Companies Are Leveraging Microsoft #Azure’s #IoT Hub. (IoT For All) #Cloud #IoT #IoTPL #IoTCL  #IoTPractioner #IoTCommunity @IoTcommunity @IoTchannel https://t.co/diIKatGIRU https://t.co/NbbXVD8QqD
#
#  ------------------
#
#
# This week's Azure Infrastructure Update is up! (from IRONMAN Texas lol).
#
# https://t.co/6gjN6dgV04
#
# #azure
#
#  ------------------
#
#
# Introduction to CosmosDB Security and Using #Azure #CosmosDB REST API with POSTMAN https://t.co/xJasWpUi8P
#
#  ------------------
#
#
# How to draw a #spatial polygon and query #Azure #CosmosDB to see if there is any data under the given polygon https://t.co/wE4K3iMRWi
#
#  ------------------
#
#
# New—Azure Managed Grafana integrates  dashboards with Azure services and security.  about the preview release: AbzlUNqUR8 #Azure ..
#
# 🪔 Buy Azure Fundamentals AZ-900 Practice Exam https://t.co/crNOlhHytu https://t.co/3Rv7qk0CLU
#
#  ------------------
#
#
# Why is it crucial to pick a right partition key in #Azure #CosmosDB https://t.co/A2PjO21WMV
#
#  ------------------
#
#
# Introduction to Role Based Access Control in #Azure #CosmosDB https://t.co/SV0QgH9jHw
#
#  ------------------
#
#
# How to retrieve data from #Azure #CosmosDB Analytical Storage with #AzureSynapse and SQL Pool https://t.co/ojpPaU6CkK
#
#  ------------------
#
#
# Start Building Your Career Path with MS-500 Microsoft 365 Security Administration Exam. Achieve your Career path with us: https://t.co/f3NA9Ef6Jf
# .
# .
# .
# .
# .
# .
# #microsoftcertification #microsoft #training #coding #bestinstitute #azure #bigdata #certification #machinelearning https://t.co/VGqdMoVdEq
#
#  ------------------
#
#
# #Azure #aws #tableau #aiforbusiness #automl #analytics Hello Network - Testing out the new Linkedin Smart Links - Give this set of Aible Content Links a look and let me know how it is working -
#
# Thanks - David https://t.co/7hodFd4f8S
#
#  ------------------
#
#
# Watch this video and click 👍 if you'd like to maximize the quality of the customer experiences you deliver. Contact us to discuss how Eagle Tech Corp can help you do it with #Azure from @Microsoft. #cloudsolutions https://t.co/Gywf85UdO5
#
#  ------------------
#
#
# Microsoft announces new collaboration with Red Button for attack simulation testing
# https://t.co/YTaXM9ovbZ
# #Azure #Microsoft #Cloud #Security #AttackSimulation https://t.co/y5iE4NqrxX
#
#  ------------------
#
#
# Join our webinar where we discuss how to optimize how your teams use cloud infrastructure with tools such as #Terraform, #AWS #CloudFormation, and #Azure Resource Manager.
#
# https://t.co/yzVp9KpVu4 https://t.co/noGfqTgkvZ
#
#  ------------------
#
#
# Reading: Bring your own IP addresses (BYOIP) to #Azure with Custom IP Prefix - https://t.co/D53VXvfi7v
#
#  ------------------
#
#
# FEITIAN BioPass FIDO Series is a hardware-based FIDO2/U2F strong authenticator with Fingerprint verification. Suitable for two-factor, multi-factor and passwordless authentication, especially for Microsoft Azure AD and Hybrid AD passwordless logon. #Citrix #Azure #Office365 https://t.co/OgDSr0KWmH
#
#  ------------------
#
#
# As a Microsoft partner, we are thrilled to be part of the virtual Azure Marketplace App Fair on Wed, April 27 at 2pm EDT! Join us to learn how to view and manage which #Azure resources are monitored by Datadog directly inside the Azure portal: https://t.co/d7g8cL9E8F
#
#  ------------------
#
#
# Enhance your classroom experience with Azure Lab Services—April 2022 update https://t.co/MKSWtF9r4E #Azure
#
#  ------------------
#
#
# #Azure blog has a new post "Enhance your classroom experience with Azure Lab Services—April 2022 update" https://t.co/wzt8Qk9aH7
#
#  ------------------
#
#
# Join our Global CTO for Office 365 Security with Azure MFA, PIM and AIP! May 4-6, 2022
#
# #Microsoft365 #virtualmarathon2022 #onboarding #AUTOMATION #microsoft #azure #office365 https://t.co/wDXsoXauyE
#
#  ------------------
#
#
# PSA on whats new with @Azure fam! Enhance your classroom experience with Azure Lab Services—April 2022 update by Fawad Khan here -&gt; https://t.co/uOtlaACRNu #Azure https://t.co/UoU6Ahid9R
#
#  ------------------
#
#
# Datto is hitting the road this spring and coming to NYC on the 28th for a unique event. Here you'll meet, network, share, and learn best practices on how to protect your clients data in #SaaS applications and Microsoft #Azure. Join us in NYC next week: https://t.co/0T6PDH3Qpe https://t.co/aXSbvzuCJQ
#
#  ------------------
#
#
# JSON does not have datetime data types. Here is my article about storing datetime and retrieving data by date and time without a datatime data type in #Azure #CosmosDB https://t.co/khxEvnwGMM
#
#  ------------------
#
#
# Hello 👋 @_CloudFamily @CloudSkills_FM @AzureCrazy
# Join my @GlobalAzure sessions - What is new in #Azure Bicep 💪 language? ⁉🤔
# &gt;&gt; Check out a #cloudmarathoner session 👉 https://t.co/aite4cT47c #microsoftazure @BicepLang #devops  #globalazure2022 @AzureDevOps https://t.co/lXb0HAOL6a
#
#  ------------------
#
#
# Here are 5 ways for Microsoft CSPs sales teams to drive up their monthly revenue figures through better customer experiences: https://t.co/wuhRpfZXW8
#
# #microsoft #devops #Azure #devops #cloud #programming #cloudcomputing #aws #linux
#
#  ------------------
#
#
# @KIIARA you didn't compare to any of my facets 💎
# #Python #AI #IoT #IIoT #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @MonkeyMouse666  The People Mom Warned Us Of
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @clown__nation  How Pizza Gate Stalks Kids
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @p_man_74  User Has 100+ Porn sites
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @ShehinImran9  User Only Posts Porn
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA You Just Ended your career
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA  8 retweets 8 likes
# #Python #IoT #IIoT #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad #MachineLearning
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure https://t.co/VEGf3mhihm
#
#  ------------------
#
#
# Join me this Thursday for the Azure Networking Crash Course.
#
# https://t.co/EBM1lV3dUz
#
# #azure #networking https://t.co/j02PzdlACX
#
#  ------------------
#
#
# In this tutorial you will learn how to create a SQL Database in Azure. This lab will walk you through the steps to deploy SQL server and to create a SQL database. #Azure #fundamentals #tutorials
# https://t.co/m1DW6iH7J4
#
#  ------------------
#
#
# Enhance your classroom experience with Azure Lab Services—April 2022 update- https://t.co/lIs5FbKifi #azure #strategy
#
#  ------------------
#
#
# Generally available: Java 17 and Tomcat 10.0 on #Azure App Service from The Azure Updates Team https://t.co/8jdvtgkpia #AzureAppService
#
#  ------------------
#
#
# Only a day left! Join me and Eric tomorrow 27th April, Wednesday at 5 PM EST online at the Toronto User Group to learn about Optimizing Azure Environments! #mvpbuzz #microsoftazure #azurecloud #microsoftmvp  https://t.co/RJHiLCTLy8
#
#  ------------------
#
#
# ⏳ 2 days to go! Join us and Kudzai Manditereza as we discuss an end-to-end solution to send OPCUA data to the #Azure cloud using a full-featured #MQTT broker.
# ➡️ Register now: https://t.co/L8LEKfdj5Z
# #SmartFactory #SmartManufacturing #SmartIndustry #ConnectedFactories #IIoT https://t.co/h4PEhqe7OI
#
#  ------------------
#
#
# Ultimate #Guide To #Azure Costs For 2022
#
# https://t.co/wCIV8HZuUr
#
# Check out this article written by the #AgileSEO team and published on https://t.co/7Z9NHdpZ7C https://t.co/hR4fn5rFAG
#
#  ------------------
#
#
# Alert when a user is added directly to an Azure AD role, bypassing PIM https://t.co/8I3n0WDPCM
#
# #MicrosoftSentinel #Azure #Cybersecurity #MicrosoftSecurity #Security #KQL
#
#  ------------------
#
#
# #microsoft #azure has a weekly "Learn Live: Azure #Hybrid Cloud Study Hall" so we all can learn more about Azure stack and how to configure, deploy, manage your hybrid cloud resources using services and hybrid cloud technologies, a…https://t.co/eXKHQiQO7d https://t.co/5UhTu5ckBI
#
#  ------------------
#
#
# #microsoft #azure has a weekly "Learn Live: Azure #Hybrid Cloud Study Hall" so we all can learn more about Azure stack and how to configure, deploy, manage your hybrid cloud resources using services and hybrid cloud technologies, a…https://t.co/eXKHQiQO7d https://t.co/5UhTu5ckBI
#
#  ------------------
#
#
# Read a case study about how @Apprisia_USA  migrates existing #SAP servers to #Azure technology to enhance service reliability, resiliency, and robust security. https://t.co/hPQSWSMzef #casestudy #successstory #SAPMigrations https://t.co/yRJVJON9rd
#
#  ------------------
#
#
# Speakers Announcement for “𝐆𝐥𝐨𝐛𝐚𝐥 𝐀𝐳𝐮𝐫𝐞 𝟐𝟎𝟐𝟐" @ Chennai !!
#
# The event will take place on May 07, 2022, Saturday at Chennai, India.
#
# To join with us, kindly get registered with the URL: https://t.co/2LdZRV9Ah0
#
# #IndiaMVP #mvpbuzz #GlobalAzure #Azure @karthik3030 https://t.co/bpRaLOK8Zj
#
#  ------------------
#
#
# Create #Azure SQL Server and DTU based SQL Database with TDE State Enabled using #PowerShell script from Shrushti Shah https://t.co/sxUGI0ofN2
#
#  ------------------
#
#
# Public preview: #Azure Monitoring Agent supports custom and IIS logs from The Azure Updates Team https://t.co/18hpn7ZWjh #AzureMonitor
#
#  ------------------
#
#
# Become a Insider Risk Management Ninja from Patrick David https://t.co/eEdB2VJYCk #Azure
#
#  ------------------
#
#
# Public preview: Metrics and alerts support in #Azure Container Apps from The Azure Updates Team https://t.co/h7m9k15jpz
#
#  ------------------
#
#
# Managed Identities With #Azure Container Apps from https://t.co/FzgwzTRjnQ Thorsten Hans https://t.co/ATEeFFrcDY
#
#  ------------------
#
#
# Make #Azure AD Identity Governance work for you from Sue Bohn https://t.co/nJjfhxKj4O #AzureAD
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/uFE0UrDMOF
#
#  ------------------
#
#
# ICYMI: (9/6/2020): "Dependency Injection with Azure Functions." RTs and feedback are always appreciated! https://t.co/wzpFKxgR1k  #Azure #DependencyInjection #Functions
#
#  ------------------
#
#
# Get Microsoft #Azure innovation, #cloud benefits, and flexible cloud billing across your data estate leveraging #AzureArc. Sign up and stay connected! We’ll help you find the right option for your data workloads. https://t.co/nmIrbxHhjg
#
#  ------------------
#
#
# Published yesterday. Covers how you can keep your Azure Synapse secrets secret in Azure DevOps.
#
# Same example can be applied to Azure SQL Database #Azure #AzureDevOps #AzureSynapse #SQLServer
#
# https://t.co/AAoFNzgiiv
#
#  ------------------
#
#
# I have daily conversations with IT administrators who manage #Azure Tenants but often do not have the proper security knowledge.
#
# One of my recommendations is the @CISecurity "Securing Microsoft Azure" Guide, with step-by-step instructions for hardening:
#
# https://t.co/vGZ3TJ7WOD https://t.co/mxUWqAXiCn
#
#  ------------------
#
#
# Learn How to Deploy 12 Apps to AWS, Azure, &amp; Google Cloud - Via @freeCodeCamp
#
# Read more: https://t.co/MxuAmxp60T
#
# #Cloud #CloudComputing #Serverless #CloudNative #Developer #Programming #LearnProgramming #AWS #Microsoft #Azure #Google #GoogleCloud #Tutorial #freeCodeCamp https://t.co/qdqgq7Awj5
#
#  ------------------
#
#
# Enhance your classroom experience with Azure Lab Services—April 2022 update https://t.co/IXVs2T13Hg #Microsoft #Azure https://t.co/QL11BTPn4S
#
#  ------------------
#
#
# #TalentTuesday  #MultiPlan is looking for an experienced Oracle Database Administrator and an SQL Server Database Administrator (w/ #Azure) to work in our Irving, TX office (hybrid schedule).  Visit our #Careers page to apply &gt; https://t.co/XdeQs8361C https://t.co/OE5URyu8hJ
#
#  ------------------
#
#
# New video looking at Azure NetApp Files capabilities.
#
# https://t.co/ehAfmQ3ecc
#
# #azure #cloud #microsoft #cloudcomputing #microsoftazure #azurecloud #youtubevideo #learning #azureadministrator #azurearchitect #microsoftcloud
#
#  ------------------
#
#
# #SmartTech Don't Fight The In-housing Trend: A Warning To Agencies - The Drum https://t.co/F2Q3D7dwxp
#
# #IoT #IIoT #programming #cloudcomputing #developer #linux #coding #azure #software #it #javascript #machinelearning #Programming #coding #python #java
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/Zvyf72LGzD
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/mo7RKX5MNV
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/AoNFHg2vnH
#
#  ------------------
#
#
# #Linux How To Monitor CPU and RAM in Linux - BollyInside https://t.co/lmzYv4MhsV
#
# #devops #programming #cloudcomputing #cloud #aws #developer #linux #technology #python #coding #azure #software #iot #cybersecurity #it #javascript #kubernetes #java #css https://t.co/LCh7Knl8bB
#
#  ------------------
#
#
# I have daily conversations with IT administrators who manage #Azure Tenants but often do not have the proper security knowledge.
#
# One of my recommendations is the @CISecurity "Securing Microsoft Azure" Guide, with step-by-step instructions for hardening:
#
# https://t.co/vGZ3TJ7WOD https://t.co/mxUWqAXiCn
#
#  ------------------
#
#
# Follow IncWorx Consulting on #LinkedIn to see the latest insights, guides and how-to articles for all your Microsoft technologies!  https://t.co/sbGUGLY5nB
#
# #microsoft365 #office365 #sharepoint #powerapps #powerbi #powerautomate #powerplatform #microsoftteams #sqlserver #azure https://t.co/TfWmzoE1Ub
#
#  ------------------
#
#
# Managed Identities With #Azure Container Apps from https://t.co/FzgwzTRjnQ Thorsten Hans https://t.co/ATEeFFrcDY
#
#  ------------------
#
#
# Generally available: Java 17 and Tomcat 10.0 on #Azure App Service from The Azure Updates Team https://t.co/8jdvtgkpia #AzureAppService
#
#  ------------------
#
#
# Generally available: Java 17 and Tomcat 10.0 on #Azure App Service from The Azure Updates Team https://t.co/8jdvtgkpia #AzureAppService
#
#  ------------------
#
#
# Public preview: Metrics and alerts support in #Azure Container Apps from The Azure Updates Team https://t.co/h7m9k15jpz
#
#  ------------------
#
#
# Become a Insider Risk Management Ninja from Patrick David https://t.co/eEdB2VJYCk #Azure
#
#  ------------------
#
#
# Public preview: #Azure Monitoring Agent supports custom and IIS logs from The Azure Updates Team https://t.co/18hpn7ZWjh #AzureMonitor
#
#  ------------------
#
#
# Create #Azure SQL Server and DTU based SQL Database with TDE State Enabled using #PowerShell script from Shrushti Shah https://t.co/sxUGI0ofN2
#
#  ------------------
#
#
# #Azure AD RBAC: Dynamic administrative units now in public preview for users &amp; devices from Alex Simons https://t.co/9QSacJt2mp #AzureAD
#
#  ------------------
#
#
# Generally available: DNS reservations to prevent subdomain takeover in Cloud Services deployments from The Azure Updates Team https://t.co/GH3NArIjpi #Azure
#
#  ------------------
#
#
# A Simple Network Connection Test Tool for #Azure Spring Cloud from Hanli Ren https://t.co/qbOUVcKhOw
#
#  ------------------
#
#
# Public preview: App Service - Configure networking in #Azure Portal during app creation from The Azure Updates Team https://t.co/5GardEsIwO #AzurePortal
#
#  ------------------
#
#
# Modern data lake architectures power digital transformation.  They deliver flexibility, scale and security. In this Artis Minute, we focus on the Silver zone of a 3-zone data lake architecture.  #Azure #datalake https://t.co/UlcOyhjNTW
#
#  ------------------
#
#
# Giving you peace of mind. 🧘 Henson Group actively maintains and monitors your servers with managed services for Azure, M365, and Security Applications.
#
# Need an extension for your IT Team? Visit https://t.co/oP1dlbuaSP
#
# #HensonGroup #Microsoft #MicrosoftPartners #CloudSecurity https://t.co/z8pOoEMqqG
#
#  ------------------
#
#
# Some awesome new features in @AzureCosmosDB MongoDB API. Larger document sizes (16MB), unique index improvements, support for $expr: https://t.co/0Vv6V7jBsn #Azure
#
#  ------------------
#
#
# Hello 👋 @_CloudFamily @CloudSkills_FM @AzureCrazy
# Join my @GlobalAzure sessions - What is new in #Azure Bicep 💪 language? ⁉🤔
# &gt;&gt; Check out a #cloudmarathoner session 👉 https://t.co/aite4cT47c #microsoftazure @BicepLang #devops  #globalazure2022 @AzureDevOps https://t.co/lXb0HAOL6a
#
#  ------------------
#
#
# Issues you may meet when upgrading #Azure function app to V4 from Xinyu Shan https://t.co/L2dXOvXmj2 #AzureFunctions
#
#  ------------------
#
#
# Efficient work is all about simplicity and control, which is why #Microsoft enabled #VMware enterprises to use their infrastructure as an extension of the #Azure #cloud, easing work processes between Azure and the vCenter control plane.  https://t.co/Ou1rpjB7yR
#
#  ------------------
#
#
# Reading: Amplify your database development experience with #Azure Data Studio - https://t.co/OjFG4GJTzX #AzureData
#
#  ------------------
#
#
# Many teams ask common questions about how to structure deployable application components and how the deployment fits in with other elements in the DevOps pipeline.
#
# Webinar Registration https://t.co/mUbWWcZPiB
#
# #octopusdeploy #azuredevops #devops https://t.co/lcFoqJRK5K
#
#  ------------------
#
#
# Released 1st ver of Azure Blob Storage developer guide for JS. So much more to go. Docs https://t.co/m3G4404uJd with code https://t.co/j7GfZncQLe What would you like to see? #azure #javascript #blob https://t.co/ydQCaKu4jd
#
#  ------------------
#
#
# 87

# %%
topics = []
score = []
sentence = []
counter = 0
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 1:
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        counter += 1
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# What's the best system for managing and monitoring #data? Comment if you think you know.     For 💡 insight, watch this video showing @Microsoft #Azure tools and processes i that tackle malicious #security threats in real-time. https://t.co/CcbxZ24E5E
#
#  ------------------
#
#
# Did you know there are 2 different connectivity modes in #Azure #CosmosDB? https://t.co/elOEQ7kbJr
#
#  ------------------
#
#
# Time is of the essence when it comes to protecting your clients’ critical Azure workloads, with hourly RPO out of the box, you can ensure complete protection. Learn more about Datto Continuity for Microsoft #Azure: https://t.co/PQAdHOelyv https://t.co/kOMGfRHr33
#
#  ------------------
#
#
# Aufsite delivers custom cloud solutions for your business. Cloud computing has several advantages for businesses. Contact us now to learn more!
# ☎️ (732) 234-1020
# 📤 sales@aufsite.com
# 🌐 https://t.co/DXUZsvRXPz
# #cloudcomputing #cloud #cloudservices #aws #azure #microsoft https://t.co/BUca0RTyiv
#
#  ------------------
#
#
# More delays to DoD cloud contract; #AWS, #Azure, #Google, #Oracle in the running
#
# Read more about the contract in our latest article: https://t.co/wl7qXFBNbm
#
# #cloud @awscloud @GoogleCloudTech @Oracle @Azure  #managedhosting https://t.co/7mCnJwV96M
#
#  ------------------
#
#
# Whether you use #Amazon Kendra, #Azure OpenSearch Service, #Elasticsearch, #Microsoft Search or #SharePoint Online, we can connect your search engine to over 90 enterprise systems. https://t.co/n75FPaj205 #EnterpriseSearch #YourChoice
#
#  ------------------
#
#
# Watch "Architecting multitenant solutions on #Azure" on @azurefriday with @jdwns and @shanselman https://t.co/U6JlSebohy
#
#  ------------------
#
#
# @KIIARA @COKID970SWAG  What Is A Troll' 5 thousand @Jeopardy
# #Python #AI #IoT #IIoT #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure https://t.co/Zgq3yShw7m
#
#  ------------------
#
#
# @KIIARA @sai_ki7  No Fans! Just Media Trolls
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @OptimistCrypto7 @KIIARA  Troll Talk
# #Python #IoT #IIoT #PyTorch #SQL #JavaScript #ReactJS #WordPress #Security #DeFi #mentalhealth
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #ETH
# #MLOps #Flutter #HTML #Azure
# #NFTs #NFT
#
#  ------------------
#
#
# Here's how migrating to #Azure improved the way we verify and record transactions here at Microsoft. #MicroftDigital #MicrosoftAzure https://t.co/EYQvS1rO0F
#
#  ------------------
#
#
# Here's how migrating to #Azure improved the way we verify and record transactions here at Microsoft. #MicroftDigital #MicrosoftAzure https://t.co/EYQvS1rO0F
#
#  ------------------
#
#
# An Icelandic Barn Conversion Transforms an Early Century Relic https://t.co/HpjQ1T1frh #Azure #Cloud https://t.co/uzoXLwWaYO
#
#  ------------------
#
#
# Deploy an application to #Azure Static Web apps using the Visual Studio Code extension. Check out this quickstart guide to get started: https://t.co/LWPGRg2dyQ https://t.co/vakpEfabq9
#
#  ------------------
#
#
# HIRING: Threat Hunter / Munich, Germany https://t.co/Ntn0ICCraW #InfoSec #InfoSecJobs #Cybersecurity #security #jobsearch #techjobs #hiringnow #Munich #Germany #AWS #Azure #Cloud #DNS #Firewall #Python #SIEM #SaaS
#
#  ------------------
#
#
# Xinnovit is hiring: Data Lake Developer
#
# Minimum Qualifications: * Five years of Data Lake Developer experience * Two engagements with two different entities in a Senior Data Lake Developer role Preferred...
#
# https://t.co/9Xh1dMfCLL
# #Remote #azure #Jobs
#
#  ------------------
#
#
# Did you know our brain structure changes every time we learn something new?
#
# #AI &amp; #ML theme is a fun way to learn &amp; win with us ➡️ https://t.co/UMTDKUNhZc
#
# #KonfHub #CloudQuiz #MSFT #Azure https://t.co/Zxc4GPwWkP
#
#  ------------------
#
#
# Advanced Certification in Azure DevOps with Hatigen.
# Enroll Now
# 📱𝐖𝐡𝐚𝐭𝐬𝐚𝐩𝐩 𝐍𝐨𝐰:-+𝟒𝟒 (𝟎) 𝟐𝟎𝟑𝟏𝟓𝟒𝟑𝟑𝟒𝟓
# 🌐𝐖𝐞𝐛𝐬𝐢𝐭𝐞:- 𝐰𝐰𝐰.𝐇𝐚𝐭𝐢𝐠𝐞𝐧.𝐜𝐨𝐦
# 📧𝐄𝐦𝐚𝐢𝐥:- 𝐢𝐧𝐟𝐨@𝐡𝐚𝐭𝐢𝐠𝐞𝐧.𝐜𝐨𝐦
#
# #azure #cloud #aws #cloudcomputing #devops #techjob https://t.co/whQI1UmAiH
#
#  ------------------
#
#
# Retail continues to rank among the top two industries most affected by cyberattacks. Are you making monitoring and threat detection a 2022 priority? Read the @Microsoft blog to learn more.      #MSCloudRetail #Azure https://t.co/fAsrrOu9Co
#
#  ------------------
#
#
# 🚨 Free DevOps Training 🚨 I propose 4 free sessions of training of 30 minutes to learn to build a complete CI/CD pipeline with Docker, GitHub Actions, AWS, Qovery, and Terraform.
#
# #cloud #gitops #devops #sre #aws #azure #gcp #training #CloudComputing https://t.co/ESiVaLtVKE
#
#  ------------------
#
#
# #Azure DevOps – Tips and Tricks – 2 – Pipeline Notifications – Custom notification Subscription. from @PrawinSreeram https://t.co/qyGKoB5zog #AzureDevOps
#
#  ------------------
#
#
# General Availability of Cross-Subscription Restore for Dedicated SQL Pools from stevehow https://t.co/L8Dtr26O0B #Azure
#
#  ------------------
#
#
# Analyze in Excel Workbooks are now saved to OneDrive for Business - https://t.co/Q4EPxcgse0 #azure #powerbi #reports #dashboards
#
#  ------------------
#
#
# Our 2022 Cloud MSP Vendor Map positions the top managed cloud service providers for #AWS, #Azure, and #GoogleCloud in an easy-to-understand Venn diagram.
# https://t.co/cUNKL3ZqyR
# #cloud #cloudcomputing #cloudmanagement
#
#  ------------------
#
#
# General Availability of Cross-Subscription Restore for Dedicated SQL Pools from stevehow https://t.co/L8Dtr26O0B #Azure
#
#  ------------------
#
#
# From automating code-to-cloud workflows to accelerating developer velocity, #GitHub and #Azure combine the best tools to create your next great solution. Follow System Soft to stay connected and learn more about Azure #DevOps with GitHub and #VisualStudio. https://t.co/ieskuw3NFW
#
#  ------------------
#
#
# How to Setup Different Test Environments in #Azure DevOps Test Plans from Panu Oksala https://t.co/M6SOSnEfP3
#
#  ------------------
#
#
# New blog post. Creating an event streaming application using @AzureFunctions, @AzureCosmosDB and Event Hubs. Includes details on using Managed Identities, Bicep and Dependency Injection: https://t.co/pdmLMzoiIG #Azure
#
#  ------------------
#
#
# CoDailychalleng: RT @AlludingAssets: If I Work Unconditionally @KIIARA
# Can You Imagine What My Intensions
# Are? #NFT #IDO #HTML #DAO #AI
# #Security #WordPress #Serverless
# #CSS #IoT #Roblox #flutter #GitHub
# #Azure #javascript #DevOps #Linux #MLOps #building… https://t.co/fMyBiQ4rKs
#
#  ------------------
#
#
# Looking to consolidate tools in a single #cloudsecurity platform for #AWS, #Azure and #Google Cloud? Read this buyer's guide to select the Cloud Native Application Protection Platform (CNAPP) that works best for your business. #CISOs #infosec #cloud https://t.co/2dEpLZnZxb
#
#  ------------------
#
#
# #JAMStack stands for #JavaScript, #API's and #Markup, and is an architectural pattern for building web-based applications. #Azure provides services for hosting applications that deploy the pattern.
#
# https://t.co/PZhQppnq3R
#
#  ------------------
#
#
# CoDailychalleng: RT @AlludingAssets: If I Work Unconditionally @KIIARA
# Can You Imagine What My Intensions
# Are? #NFT #IDO #HTML #DAO #AI
# #Security #WordPress #Serverless
# #CSS #IoT #Roblox #flutter #GitHub
# #Azure #javascript #DevOps #Linux #MLOps #building… https://t.co/fMyBiQ4rKs
#
#  ------------------
#
#
# In this tutorial you will learn how create a Virtual Network in your Azure Lab. I will guide you through setting up a Virtual Network and deploying two Virtual Machines onto your virtual network. #Azure #Tutorials #Labs
# https://t.co/QCPPLvRSRf
#
#  ------------------
#
#
# MSPs. Did you know you can integrate #Azure AD with @Superops_ai? Here's how https://t.co/CeW9VwOItz #ManagedServices
#
#  ------------------
#
#
# This article covers everything you need to know about #cloud-based #productdevelopment.
#
# https://t.co/AL8yaArwH1
#
# #cloudcomputing #digitalproduct #aws #azure #development #software
# CC: @Shi4Tech @antgrasso @enricomolinari @ChuckDBrooks @MikeQuindazzi @TamaraMcCleary @sallyeaves https://t.co/azjWgUKbAu
#
#  ------------------
#
#
# This article covers everything you need to know about #cloud-based #productdevelopment.
#
# https://t.co/AL8yaArwH1
#
# #cloudcomputing #digitalproduct #aws #azure #development #software
# CC: @Shi4Tech @antgrasso @enricomolinari @ChuckDBrooks @MikeQuindazzi @TamaraMcCleary @sallyeaves https://t.co/azjWgUKbAu
#
#  ------------------
#
#
# This article covers everything you need to know about #cloud-based #productdevelopment.
#
# https://t.co/AL8yaArwH1
#
# #cloudcomputing #digitalproduct #aws #azure #development #software
# CC: @Shi4Tech @antgrasso @enricomolinari @ChuckDBrooks @MikeQuindazzi @TamaraMcCleary @sallyeaves https://t.co/azjWgUKbAu
#
#  ------------------
#
#
# New blog post. Creating an event streaming application using @AzureFunctions, @AzureCosmosDB and Event Hubs. Includes details on using Managed Identities, Bicep and Dependency Injection: https://t.co/pdmLMzoiIG #Azure
#
#  ------------------
#
#
# 38

# %%
topics = []
score = []
sentence = []
counter = 0
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 2:
        counter += 1
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# Senior Architect - Permanent/Remote anywhere in Canada (Vancity based) - Golang, SaaS/PaaS/IaaS, DevSecOps, scale and build new features for visionary product - kbarr@teemagroup.com #softwaredesign #Golang #softwarearchitect #remotejobs #backendengineer #Azure #AWS #gcpcloud
#
#  ------------------
#
#
# ☀️ Don't miss our on getting free access to our platform - No credit card required!
# 🎯 Hurry up, just a few days left! Refresh your tech skills and take your career to the next level.
# 👉 https://t.co/NgLLyMdvUN
#
# #AWS #Azure #GCP #AWSCertified #AzureCertified https://t.co/YmaviWFIgG
#
#  ------------------
#
#
# Azure Arc + automation: step-by-step guides, code samples, and more…what are you waiting for?
#
# #azure #automation #hybridcloud #multicloud  #developer #AzureArc https://t.co/UeuaWrzBAr
#
#  ------------------
#
#
# Looking forward to collaborating with like minded people. We are #software solutions provider. 😀 #USA #Canada #hustle #business #entrepreneur #motivation #remote #nomad #angular #Azure #SharePoint #Dotnet #MVC https://t.co/Uf5XfDPMZ6
#
#  ------------------
#
#
# First look at #Azure #CosmosDB Continuous Backup. https://t.co/wf1cmKcbEp
#
#  ------------------
#
#
# Senior Architect - Permanent/Remote anywhere in Canada (Vancity based) - Golang, SaaS/PaaS/IaaS, DevSecOps, scale and build new features for visionary product - kbarr@teemagroup.com #softwaredesign #Golang #softwarearchitect #remotejobs #backendengineer #Azure #AWS #gcpcloud
#
#  ------------------
#
#
# #ArtificialIntelligence functionality in the decision tree #AI #Azure #SaaS #Microsoft #DataSecurity #dataScientist #DataAnalytics #Python #RStats #Reactjs #IIoT #MachineLearning #flutter #javascript #digitalhealth #TensorFlow #BigData #Cloud #coding #100DaysOfCode #fintech https://t.co/dp2R0xhAVd
#
#  ------------------
#
#
# 😎 Senior Frontend Engineer
# 👨‍💻 TestGorilla company.
# 👇 Apply:
# https://t.co/tBvy7M0ruf
#
# #cloud #kubernetes #angular #devops #startup #html #aws #frontend #javascript #docker #azure
#
#  ------------------
#
#
#  I would pay someone to write this essay for me.
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #TensorFlow #JavaScript #ReactJS #Serverless #Linux #Security #NFT #opensource
# #AI #CSS #WordPress #HTML #DevOps #css
#
#  ------------------
#
#
# #Azure community - Where do you guys get materials from other than the actual Microsoft Website?
#
#  ------------------
#
#
# Step by Step creating and executing Stored Procedures in #Azure #CosmosDB https://t.co/cM672Qojwg
#
#  ------------------
#
#
# Looking forward to collaborating with like minded people. We are #software solutions provider. 😀 #USA #Canada #hustle #business #entrepreneur #motivation #remote #nomad #angular #Azure #SharePoint #Dotnet #MVC https://t.co/uNazFJzT9b
#
#  ------------------
#
#
# I would pay someone to write this essay for me.
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #TensorFlow #JavaScript #ReactJS #Serverless #Linux #Security #NFT #opensource
# #AI #CSS #WordPress #HTML #DevOps #css
#
#  ------------------
#
#
# Senior Architect - Permanent/Remote anywhere in Canada (Vancity based) - Golang, SaaS/PaaS/IaaS, DevSecOps, scale and build new features for visionary product - kbarr@teemagroup.com #softwaredesign #Golang #softwarearchitect #remotejobs #backendengineer #Azure #AWS #gcpcloud
#
#  ------------------
#
#
# Watch "Architecting multitenant solutions on #Azure" on @azurefriday with @jdwns and @shanselman https://t.co/U6JlSebohy
#
#  ------------------
#
#
# @KIIARA @COKID970SWAG  What Is A Troll' 5 thousand @Jeopardy
# #Python #AI #IoT #IIoT #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure https://t.co/Zgq3yShw7m
#
#  ------------------
#
#
# @KIIARA @thatweirdkidav  User Has 30+ troll sites
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @FlyingRaccoon66  User Has 20+ troll sites
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA  @KIIARA they all have multiple sites like me, Do You #C Them Working For You Every Day?
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #JavaScript #ReactJS #Serverless #Linux #Security #CSS #WordPress #DevOps #Ad https://t.co/odNH9COubu
#
#  ------------------
#
#
# @KIIARA @purplefloss1  @KIIARA these rats are your problem
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #TensorFlow #JavaScript #ReactJS #Serverless #Linux #Security #NFT #opensource
# #AI #CSS #WordPress #HTML
# #NFT #DevOps #CSS https://t.co/fLovPzrx8N
#
#  ------------------
#
#
# @KIIARA  It's probably brain damage #C
# #Python #IoT #IIoT #PyTorch #SQL #JavaScript #ReactJS #WordPress #Security #DeFi #Ad @KIIARA #AI #fintech #insurtech #finserv #CSS #marketing #TensorFlow #datavis #Infosec #DevOps #ADA #Linux
# #MLOps #Flutter #HTML #Azure
# https://t.co/G8PWbZ1VPS https://t.co/Ue7sdUOdpr
#
#  ------------------
#
#
#  I would pay someone to write this essay for me.
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #TensorFlow #JavaScript #ReactJS #Serverless #Linux #Security #NFT #opensource
# #AI #CSS #WordPress #HTML #DevOps #css
#
#  ------------------
#
#
#  I would pay someone to write this essay for me.
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #TensorFlow #JavaScript #ReactJS #Serverless #Linux #Security #NFT #opensource
# #AI #CSS #WordPress #HTML #DevOps #css
#
#  ------------------
#
#
# On #AzureFriday, @JDwns joins @SHanselman🌮 to discuss how to design, architect, and build #multitenant #SaaS solutions on #Azure. It's all in the #AzureArchitectureCenter https://t.co/F771miePS0 https://t.co/x4WE4Nm6wV
#
#  ------------------
#
#
# Microsoft expands efforts to 23 countries for #cybersecurity #azure #microsoft   https://t.co/dBZtLKxyD0
#
#  ------------------
#
#
# Episode 421 - Project Flash from Cynthia Kreng, Kendall Roden, Cale Teeter, Evan Basalik, Russell Young, and Sujit D'Mello https://t.co/O7GfhTlrkx #Azure
#
#  ------------------
#
#
# What does a #Dynamics365 cloud migration success story look like? To Sanitas Seguros, it looks like an automated data-centric digital platform in the #Azure #cloud. Get the story. Contact High Tech.2.0 for help with your story. https://t.co/CAZn3JLWiv
#
#  ------------------
#
#
# Platform as a Service (PaaS) - Advantages &amp; How it is Used
#
# Read more: https://t.co/JaGFk1sQYg
#
# #omron #technology #productmarketing #development #computing #google #database #environment #cloud #aws #azure #programming #language #marketing https://t.co/Y5BK8DrRUw
#
#  ------------------
#
#
# Financial technology companies make our lives easier and faster, but it also creates more vulnerabilities. Here’s what our Expert Mr Aseem Rastogi recommends for Fintech companies to protect and store sensitive financial data.
# #cloud #cloudsecurity #aws #gcp #azure #kubernetes https://t.co/iiGnOkaoaP
#
#  ------------------
#
#
# FBI warns of cyber attacks on agriculture, stay prepared with the right defense.
# #team #cybersecurity #informationtechnology #Texas #Austin #cloudsecurity #Azure #Aws #supplychaincrisis #Ransomware #edrecovery #Dallas #Houston #SanAntonio #cloudsecurity
#
# https://t.co/vrYi7yuefN
#
#  ------------------
#
#
# Why #Azure Arc is a big deal to Workload Operations Management from Andre Camillo https://t.co/Wi8PnNSEb1 #AzureArc
#
#  ------------------
#
#
# Watch to learn how being @Microsoft ISV Partner has resulted in collaborations with @Azure public multi-access edge compute (MEC). https://t.co/zOUlkVwNCi #5G #cloud https://t.co/Uw3yMMYO6W
#
#  ------------------
#
#
# Episode 421 - Project Flash from Cynthia Kreng, Kendall Roden, Cale Teeter, Evan Basalik, Russell Young, and Sujit D'Mello https://t.co/O7GfhTlrkx #Azure
#
#  ------------------
#
#
# Episode 421 - Project Flash from Cynthia Kreng, Kendall Roden, Cale Teeter, Evan Basalik, Russell Young, and Sujit D'Mello https://t.co/O7GfhTlrkx #Azure
#
#  ------------------
#
#
# Become a Communication Compliance Ninja from Patrick David https://t.co/Dplzfad2Nj #Azure
#
#  ------------------
#
#
# Why #Azure Arc is a big deal to Workload Operations Management from Andre Camillo https://t.co/Wi8PnNSEb1 #AzureArc
#
#  ------------------
#
#
# Use Code: FAWAPRIL for 15% off New Professional plans with an annual sign-up, valid thru April 30th, 2022.
#
# Get started: https://t.co/Fvi18osWXi
#
# #Promo #FileSharing  #Cloud #Azure #ECM #FilesAnywhere
#
#  ------------------
#
#
# @KIIARA @KIIARA what part this of $#*+ don't you get? #trendingkiiara #fintech #insurtech #finserv #WordPress #DevOps #RStats #flutter #JavaScript #TensorFlow #Python #datavis #Security #ModelOps #Infosec #Roblox #IoT #IIoT #Azure #PyTorch #Cython #DotNet #C #CPP #CSharp #ReactJS #HTML https://t.co/Tru7PVibBh
#
#  ------------------
#
#
# [Video] Working with Delta Lake in #Azure Synapse
# https://t.co/f9qLBdYg8t
# #DataScience
#
#  ------------------
#
#
# Why #Azure Arc is a big deal to Workload Operations Management from Andre Camillo https://t.co/Wi8PnNSEb1 #AzureArc
#
#  ------------------
#
#
# Microsoft expands efforts to 23 countries for #cybersecurity #azure #microsoft   https://t.co/dBZtLKxyD0
#
#  ------------------
#
#
# 41

# %%
topics = []
score = []
sentence = []
counter = 0
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 3:
        counter += 1
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# Transforming and Importing to #CosmosDB data by using #Azure CosmosDB Data Migration Tool. https://t.co/qO1bzd6qn0
#
#  ------------------
#
#
# Who else needs help?
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #TensorFlow #JavaScript #ReactJS #Serverless #Linux #Security #NFT #opensource
# #AI #CSS #WordPress #HTML #DevOps
#
#  ------------------
#
#
#  #Water #Cloud #Sky #Weddingdress #Peopleonbeach #Dress #Bride #Blue #Peopleinnature #Azure https://t.co/PCjuXp7oiD
#
#  ------------------
#
#
# Microsoft Azure AZ-305 Exam Preparation Guide with tips and resources is here to help you pass this certification -
# https://t.co/k3TXxfPp8C
# #cloud #certification #technology #tothecloud #microsoft #azure #azurearrchitect #cloudcomputing  https://t.co/k3TXxfPp8C
#
#  ------------------
#
#
# Who else needs help?
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #TensorFlow #JavaScript #ReactJS #Serverless #Linux #Security #NFT #opensource
# #AI #CSS #WordPress #HTML #DevOps
# @writters_pro
#
#  ------------------
#
#
# Assess and Modernize with Microsoft Cloud Azure! 🌥 The Tidal Migrations platform provides the data and recommendations that you need to modernize your applications and adopt cloud-native architectures https://t.co/bMr3kKMsf4 🚀 #microsoftazure #microsoftpartner #azure https://t.co/HLYRO5pYTF
#
#  ------------------
#
#
# Are you tired of typing when using your computer? Try Windows Key + H for dictation.
# The cursor must be in a text area or an app like notepad and you must click the mic icon on the display window. Let your hands rest.
#
# #Dictation #Shortcut #Azure #Mic #NewWeek #WWDC2022 #beta https://t.co/THvdQ3fakx
#
#  ------------------
#
#
# Check out how @Microsoft #Azure helps Mondelez International maximize agility, flexibility and scalability in this story. 👍 this post if you'd like help moving to a modern #cloud solution with Secure Networkers. https://t.co/5BuS5ak26e https://t.co/1Ff06704la
#
#  ------------------
#
#
# Who else needs help?
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #TensorFlow #JavaScript #ReactJS #Serverless #Linux #Security #NFT #opensource
# #AI #CSS #WordPress #HTML #DevOps
#
#  ------------------
#
#
# More #SOFIC22 goodness. Excited to partner with @Esri on the USS Azure. Look out for demos from several amazing partners.
# #Azure #Microsoft https://t.co/jngfleTyKs
#
#  ------------------
#
#
# Master Microsoft development with these Apress books #azure #dotnet #developer #sale #book #books #apress #microsoft #programming https://t.co/xyYOqRFC7p
#
#  ------------------
#
#
# #MicrosoftAzure is upping the game on Amazon AWS, becoming the preferred choice of Cloud for IT leaders. Become part of the 80% of organizations with Team Venti's help https://t.co/zo9s5a7oUI https://t.co/O2YVOFHsid
#
#  ------------------
#
#
# @KIIARA @COKID970SWAG  Verified Porn Trolls
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure https://t.co/4XCCuU3m0v
#
#  ------------------
#
#
# @KIIARA Where They Go
# after cumming on you
# #Python #AI #IoT #IIoT  #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure https://t.co/H8GPynLcxu
#
#  ------------------
#
#
# @handapimp @KIIARA  Verified trolls
# #Python #IoT #IIoT #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @tranenauskajal  Verified Troll
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @LebreLP  If you have minor kids watch this creep
# #Python #AI #IoT #IIoT #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad #Roblox
# #trendingkiiara
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @sadnegrito  What Is A Troll for $.01
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @ilikefavchange  She Has Loyal Trolls
# #Python #AI #IoT #IIoT #opensea #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @iamsommerr  Verified user has 10 troll accounts
# #Python #AI #IoT #IIoT #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @diegolicenciado @KIIARA says the blind  Verified troll
# #Python #IoT #IIoT #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad
# #trendingkiiara #buildinginpublic
# @KIIARA #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #IDO
# #MLOps #Flutter #HTML #Azure
#
#  ------------------
#
#
# @KIIARA @purplefloss1  This Rat Trolls Accounts Below
# #Python #Roblox #IoT #IIoT #Azure #PyTorch #Cython #RStats #DotNet #CPP #Java #BTSV #ADA #CSharp #Flutter #SQL #TensorFlow #3D #JavaScript #ReactJS #Serverless #Linux #Security #NFT #opensource
# #AI #CSS #WordPress #HTML #C
# #NFT #DevOps #CSS #AR https://t.co/v8Kw6CoXOo
#
#  ------------------
#
#
#  My Heart Lives Here
# #Python #IoT #IIoT #PyTorch #JavaScript #ReactJS #WordPress #Security #DeFi #Ad #Eth #NFT
# #trendingkiiara #100DaysOfCode
# @KIIARA #fintech #insurtech #AI #finserv #TensorFlow #datavis #Infosec #DevOps #ADA
# #MLOps #Flutter #HTML #Azure
# https://t.co/WsoNuPf7tc https://t.co/QmKBgIEIw5
#
#  ------------------
#
#
# @TheShadyNews313 @DKRapArtist  Who Invited The Trolls
# #100DaysOfCode #Eminem #NFT
# #Python #IoT #IIoT #PyTorch #Ad #JavaScript #ReactJS #WordPress #Security #DeFi #buildinginpublic #fintech #insurtech #AI #finserv #marketing #TensorFlow #datavis #Infosec #DevOps #ADA #code
# #MLOps #Flutter #HTML #Azure
# #Eth https://t.co/y8EAkj4oEi
#
#  ------------------
#
#
# #BimlFlex Introducing the Delta Vault: #DataVault on #DeltaLake
# @RoelantVos  demo on building a Data Vault on Delta Lake using #azuredatafactory and #azure #mappingdataflows.
# https://t.co/3JUC0uyYSq
#
#  ------------------
#
#
# Did you know you can reduce the average assessment time of an application by over 80%?
# #applicationassessment #ApplicationAssessmentFactory #azure #ModernizeWhileYouMigrate https://t.co/LH1CcpUZOS
#
#  ------------------
#
#
# Did you know you can reduce the average assessment time of an application by over 80%?
# #applicationassessment #ApplicationAssessmentFactory #azure #ModernizeWhileYouMigrate https://t.co/LH1CcpUZOS
#
#  ------------------
#
#
# Secure Cloud connectivity AND voice control with the WFI32-IOT development board. https://t.co/PxV3iULSB4 #lowpower #wifi #wi-fi #cloud #cloudconnectivity #aws #azure #github #iot https://t.co/3LewZbnm0w
#
#  ------------------
#
#
# 👉 $225.00 👈
# Azure FDA 510k AntiAging Wrinkle Reducing Skin Rejuvenating Superintense LED Medical Grade @buy1_best
# #Azure #FDA #510k #AntiAging #Wrinkle #Reducing #Skin #Rejuvenating #fashion #lifestyle
#
# Are you ready to be #pretty?! https://t.co/Fczle1kJUM
#
#  ------------------
#
#
# How can we help your bank offer more than just banking and provide customers real value? See how Royal Bank of Canada does exactly that with @Azure confidential computing, an offering from DATAANALİST BİLİŞİM LTD.ŞTİ..     #Azure https://t.co/JTavzbA4tc
#
#  ------------------
#
#
# INMP441 is an I2S microphone. ESP32 records your voice by the microphone and uploads to Azure to figure out what you said. The mic can turn your ESP32 into a voice-controlled device.
# #Azure #AI #STT #TTS #ESP32 #MQTT https://t.co/CIoXiWt5Ym
#
#  ------------------
#
#
# INMP441 is an I2S microphone. ESP32 records your voice by the microphone and uploads to Azure to figure out what you said. The mic can turn your ESP32 into a voice-controlled device.
# #Azure #AI #STT #TTS #ESP32 #MQTT https://t.co/CIoXiWt5Ym
#
#  ------------------
#
#
# Do you want to control your house with Azure Precept and Speech Studio? Join us on May 4 for the next episode of @aifortytwo with @pete_codes to learn Home Automation with Azure Percept!
#
# Live streaming at https://t.co/6yzvY4GkMh
#
# @EvePardi @agrevlis #Azure #AI #AzurePercept https://t.co/4Q14mrlCmf
#
#  ------------------
#
#
# When You Support @KIIARA know
# These are the creeps she supports running her fandom now!I must quit!
# #Python #IoT #IIoT #PyTorch #CSS #JavaScript #ReactJS #WordPress #Security #DeFi #Ad #fintech #insurtech #AI #finserv #datavis #Infosec #DevOps #Roblox
# #MLOps #Flutter #HTML #Azure https://t.co/f8HAtZJAxG
#
#  ------------------
#
#
# Interested in becoming a DevOps Engineer?
#
# Improve your skills and earn recognition with our certification courses here: https://t.co/YqD4MYMPhC
#
# #Dev #Azure #DevOps https://t.co/blUUKhhHIX
#
#  ------------------
#
#
# Using existing #blockchain oracle solutions always seems to be a compromise. @portusnetwork is the is exactly what everyone is expecting for! #100DaysOfWeb3 #AI #API #dApps #Web3 #Binance #Ethereum #crypto #DeFi #Azure #DevOps #NFT  https://t.co/ucki9ngtSk
#
#  ------------------
#
#
# 36

# %% [markdown]
# Finally we perform topic modelling on Google Cloud

# %%
noam_region_google_cloud = df_with_countries.loc[(df_with_countries['Region']=='NOAM') & (df_with_countries['is_gcp']==1)]

# %%
noam_region_google_cloud.shape
# Out:
# (2381, 19)

# %%
noam_region_google_cloud_train = noam_region_google_cloud

# %%
corpus = []
for i in range(noam_region_google_cloud_train.shape[0]):
    try:    
        corpus.append(noam_region_google_cloud_train['clean_text'].iloc[i].split())
    except Exception as e:
        print(e)
        print(noam_region_google_cloud_train['clean_text'].iloc[i], i)
        continue
    
dct = corpora.Dictionary(corpus)

# %%
dct.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dct.doc2bow(doc) for doc in corpus]

# %%
len(bow_corpus)
# Out:
# 2381

# %%
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=4, id2word=dct, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.016*"ai" + 0.014*"search" + 0.013*"cc" + 0.012*"app" + 0.012*"sentient" + 0.011*"digital" + 0.011*"sale" + 0.011*"get" + 0.010*"apple" + 0.010*"u"
# Topic: 1 Word: 0.028*"cloud" + 0.026*"consciousness" + 0.025*"buy" + 0.019*"account" + 0.019*"ai" + 0.017*"voice" + 0.015*"engineer" + 0.015*"sentient" + 0.015*"created" + 0.013*"number"
# Topic: 2 Word: 0.018*"machine" + 0.016*"intelligence" + 0.015*"artificial" + 0.015*"data" + 0.014*"learning" + 0.014*"cloud" + 0.013*"image" + 0.011*"make" + 0.011*"market" + 0.010*"know"
# Topic: 3 Word: 0.023*"new" + 0.018*"cloud" + 0.012*"ai" + 0.012*"one" + 0.011*"use" + 0.010*"engineer" + 0.010*"language" + 0.010*"platform" + 0.009*"technology" + 0.009*"read"

# %%
new_df = pd.merge(noam_region_google_cloud_train, df[['text', 'tweetid']], how='left', on ='tweetid')

# %%
bow_corpus_test = bow_corpus[:200]

# %%
topics = []
score = []
sentence = []
counter = 0 
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 0:
        counter += 1
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# Tutorial on Creating a Topical Internal Link Graph With Python: https://t.co/WMyN525eB4
# #seo #google #content #contentmarketing #searchengineoptimization #search
# #python #data #DataScience https://t.co/mEUmiXGtof
#
#  ------------------
#
#
# Artificial Intelligence has become an integral part of our life from asking SIRI to turn on the alarm to asking Alexa to control our electronics. Education is one of those sectors where AI can play a huge role in transforming it!
#
# #educhecked #checkedit #ai #education
# @GoogleAI https://t.co/PFwKYfmJLZ
#
#  ------------------
#
#
# 25 Open Source Projects by Google: https://t.co/4iC83pgJXM
#
# PVPC #Arduino #programacion #HOLAMELONMAS #JuackeandoFinetwork05 #TierraAmarga26Abr #Ramen26A #Iot #IfYouWant #Options
#
#  ------------------
#
#
# Struggling to get Google Cloud Digital Leader certified?
#
# Prepare and pass your certification using my practice tests.
#
# Get 40% off on my 5-star rated Google Cloud Digital Leader practice tests course on #udemy
# #GoogleCloud
# #CloudComputing
#
# https://t.co/Gz9k9Szh1h
#
#  ------------------
#
#
# Biggest Google' acquisition
#
# #fintech #insurtech #finserv #marketing #web3 #payments #NFT #ESG #DevOps #RStats #flutter #JavaScript #Python #EMV #API #datavis #ModelOps #NLP #IoT #CyberSecurity #Infosec #Fraud @enricomolinari #banking #AI #regtech #paytech #govtech #mobilepayment https://t.co/PzqR8AtqJw
#
#  ------------------
#
#
# Google reported strong #cloud growth but still losing money on the offering.
#
# Alphabet reports weak earnings and revenue on big YouTube miss.
#
# #cio  https://t.co/sfXqARxRM0
#
#  ------------------
#
#
# ALPHABET INC - CLASS A: We entered a 2022-04-29 put, $2,455.00 strike, with a limit buy. We fully exited in 27 minutes by limit sale for 38% profit.  #googl #msft #aapl #spx #tsla #alphabetinc #google #alphabet #search #internet #microsoft #a https://t.co/LMBlVP0QGS
#
#  ------------------
#
#
# .@Google’s #cloud business was a standout in the quarter, growing 44% and beating estimates as more big enterprises shift their workloads away from their own data centers. @GoogleCloud
# https://t.co/vsvGLtcGzy
#
#  ------------------
#
#
# How to Get Your WordPress Blog Listed in Google News #WordPress #Blogging https://t.co/2DuT34UcmN
#
#  ------------------
#
#
# Schedule Python Scripts with Apache Airflow: https://t.co/w4ZW7Kpilt
#
# Fiverr #FiverrPro #FiverrGigs #Shouvick #php #googleanalyticscourse #FEATURED #COURSES #WordPress #Developer #Code
#
#  ------------------
#
#
# Google Nest security cameras are now on sale #Cameras #camera #security  https://t.co/ffy4LeuqSv
#
#  ------------------
#
#
# Recently, one of our users asked us how to get their #WordPress site listed on Google? 🖥
#
# Since Google is the biggest traffic source for most sites, it’s important that you get your site listed in Google immediately! 🔍
#
# Here's how to easily do that: https://t.co/B98WI2leDF https://t.co/mpziuCTZYk
#
#  ------------------
#
#
# #development #javascript #webdevelopment #freeCodeCamp #100DaysOfCode #javascript30 #Angular #React #PHP #CSS #Nodejs #html #WordPress #css3 #jquery #kayzounleashed #OneDirection2020 I will make a professional  blogspot blogger website or google site https://t.co/WnkrQFGxGV
#
#  ------------------
#
#
# Google and Apple are wrong: Hybrid and remote work won’t keep employees from building ‘social capital’ - Fortune
# #view #site #javascript #search #enable #remotework
# via https://t.co/B1ZUU07MAf
# ☛ https://t.co/CFTf3zA1w1 https://t.co/0dXxLVIbPP
#
#  ------------------
#
#
# Google Cloud sales chief Rob Enslin is leaving for UiPath https://t.co/X0Tfy10CpG #RPA #AI #Automation
#
#  ------------------
#
#
# 3 Different Docstring Formats for Python
# A quick walkaround of Google, NumPy, and Sphinx docstrings
# Photo by wu yi https://t.co/a7fX2Ld0d9 on Unsplash …
# #Programmers
# https://t.co/wUxNFPrW1O
# #programming
#
#  ------------------
#
#
# UiPath appoints Google Cloud sales leader Robert Enslin as co-CEO https://t.co/6q5mbNJjPs via @SiliconANGLE #RPA #AI #Automation
#
#  ------------------
#
#
# Late nights will eventually pay off 🙏 #DataScience #MachineLearning #DataAnalytics #Google https://t.co/5Bg93NonDq
#
#  ------------------
#
#
# Do you SSL? #Google gives you better ranking in addition to the #security benefits.
#
#  ------------------
#
#
# What is the Domain Name?
# Domain name often referred to as “web address”, is the address that people type into a browser address bar to find your website.
#  #seo #microsoft #website #webdevloper #google #internet #stshostanstech https://t.co/H89eOwji6A
#
#  ------------------
#
#
# @Google reports 1Q22 results; more steadiness, logo wins
#
# Read @phils88888  Q1 analysis here: https://t.co/amqj29GVvm
#
# #google #cloud #googlecloud #googlecloudplatform #revenue #infrastructure #digitalinfrastructure @googlecloud  @GoogleCloudTech https://t.co/194xwCLVlr
#
#  ------------------
#
#
# Building End to End Search Engine Chatbot for the website using Amazon Lex, Google Knowledge Graph… #mw https://t.co/0ILtqHZVe3 #programming #cloudcomputing
#
#  ------------------
#
#
# As customer expectations rise and workforce shortages continue, #ContactCenters have no choice but to double down on #AI. @pymnts reports how @Google's upcoming #cloud contact center #AI platform may be the perfect tool to help. #CX
# https://t.co/yk1uiv9Vrs
#
#  ------------------
#
#
# Scraping Data from Google Search Using #Python and Scrapy: https://t.co/dyQhraR8Xx
# ——————
# #WebScraping #abdsc #BigData #DataScience #AI #MachineLearning #DataScientists #TextAnalytics #NLProc #UnstructuredData #DataStrategy #100DaysOfCode
#
#  ------------------
#
#
# Lt. Charles Neill had to sell his home, car, &amp; couldn’t put food on the table for his family.
#
# Why? After he was shot in the head, he lost 75% of his income.
#
# See his story in #TheWoundedBlue on #iTunes #Amazon  #GooglePlay &amp; #Microsoft.
#
# Rent/Purchase: https://t.co/i8kgrwCGCZ https://t.co/wj0FO6u7xC
#
#  ------------------
#
#
# Google Study Shows Transformer Modifications Fail To Transfer Across Implementations and Applications https://t.co/pPkahucyrj #AI #ArtificialIntelligence #MachineLearning
#
#  ------------------
#
#
# #WordPress 6.0 features and improvements - Web Hosting - https://t.co/23snzvBJOM #GoogleAlerts
#
#  ------------------
#
#
# List your website on Google to hold the topmost position on social media.
#
# For Enquiries Contact - +91-8939886868
# https://t.co/QlCAAChGoW
#
# #webdevelopment #webdesign #webdeveloper #html #website #coding #programming #css #javascript #digitalmarketing #developer #websitedesign https://t.co/zUeMwiQPht
#
#  ------------------
#
#
# .@Google Ads implements 3-strike policy rule: https://t.co/zDyy0M8Lx4
#
# Via @sejournal
# Cc @CurieuxExplorer @TanyaSinha_
#
# #DGsaga #coding #programmer #Developer #flutter #javascript #nodejs #HTML5 #Java #100DaysOfCode #Python #devops #programming #RStats #Serverless #advertising
#
#  ------------------
#
#
# Google tweaks Search and News results to direct people to trusted sources: #machinelearning #ai #iot cc @Mikequindazzi https://t.co/m5FwZA85uq https://t.co/HZeKas0mWh
#
#  ------------------
#
#
# Google tweaks Search and News results to direct people to trusted sources: #machinelearning #ai #iot cc @Mikequindazzi https://t.co/m5FwZA85uq https://t.co/HZeKas0mWh
#
#  ------------------
#
#
# Google tweaks Search and News results to direct people to trusted sources: #machinelearning #ai #iot cc @Mikequindazzi https://t.co/m5FwZA85uq https://t.co/HZeKas0mWh
#
#  ------------------
#
#
# Google tweaks Search and News results to direct people to trusted sources: #machinelearning #ai #iot cc @Mikequindazzi https://t.co/m5FwZA85uq https://t.co/HZeKas0mWh
#
#  ------------------
#
#
# Google tweaks Search and News results to direct people to trusted sources: #machinelearning #ai #iot cc @Mikequindazzi https://t.co/m5FwZA85uq https://t.co/HZeKas0mWh
#
#  ------------------
#
#
# Building End to End Search Engine Chatbot for the website using Amazon Lex, Google Knowledge Graph… #mw https://t.co/ncEUF06EJ7 #programming #cloudcomputing via @Towards_AI #TowardAI
#
#  ------------------
#
#
# 30-second Privacy Check for every Google and Facebook user
#
# https://t.co/vw9Mjxjs8K
#
# #GoogleCloud #AWSCloud #Azure #OracleCloud #Microsft365 #GoogleWorkspace #cloud #cloudconsulting #ithelpdesk #googleworkspace #businessemail #officeappssupport #software #programmer https://t.co/rnXyyam1u0
#
#  ------------------
#
#
# Behind the scene working on the backend of these #websites. Utilizing #Microsoft's &amp; #GoogleCloud's technologies.
#
# https://t.co/mKhP0OFrqt
# https://t.co/jrTchLbTh5
#
# #Coding #Backend #Webmaster #Developer #Management #HTML #CSS #JavaScript #WebDevelopment #WebDeveloper #WebDesign https://t.co/9tyH1TWGXX
#
#  ------------------
#
#
# Google's deal with McLaren puts Android and Chrome on its 2022 F1 car, and in the garage: #artificialintelligence #iot CC @mikequindazzi https://t.co/CEfttQOs2H https://t.co/vz7GO0XDiC
#
#  ------------------
#
#
# Government Services Drive Digital Identity Growth - Digital Lifescapes https://t.co/UV6bpCG6NQ via @GoogleNews - #GovTech #security #trends https://t.co/dMGeXVsBK3
#
#  ------------------
#
#
# Running out of RAM for your #DataScience projects? Our dev-rel team explains how to get more processing power without replacing your hardware using @googlecloud, so you can push your analysis to the limits:
# https://t.co/c48jGwUeeF
#
#  ------------------
#
#
# .@Google Ads implements 3-strike policy rule: https://t.co/zDyy0M8Lx4
#
# Via @sejournal
# Cc @CurieuxExplorer @TanyaSinha_
#
# #DGsaga #coding #programmer #Developer #flutter #javascript #nodejs #HTML5 #Java #100DaysOfCode #Python #devops #programming #RStats #Serverless #advertising
#
#  ------------------
#
#
# . @Google's teaching #AI how to see and hear at the same time. (The Next Web)  https://t.co/8r2CLSi1Lf https://t.co/UvW3274da1
#
#  ------------------
#
#
# Think Google Translate is good enough to translate a professional website?   🗺️ Think again... https://t.co/dMarvnYTzP
#
# #googletranslate #machinetranslation #ai
#
#  ------------------
#
#
# 43

# %%
topics = []
score = []
sentence = []
counter = 0
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 1:
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        counter += 1
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# Architecting with Google Cloud #gcp #cloud #architecting #uber  https://t.co/7Y9iRxCIjP
#
#  ------------------
#
#
# Cloud Titans Seek to Slash Carbon Impact: AWS, Meta, Google and Microsoft join 70 firms in iMasons Climate Accord to step up #datacenter carbon tracking.  @InfraMason #cloud #climate #sustainability https://t.co/B48ccyk5Qp
#
#  ------------------
#
#
# Our 2022 Cloud MSP Vendor Map positions the top managed cloud service providers for #AWS, #Azure, and #GoogleCloud in an easy-to-understand Venn diagram.
# https://t.co/cUNKL3ZqyR
# #cloud #cloudcomputing #cloudmanagement
#
#  ------------------
#
#
# Looking to consolidate tools in a single #cloudsecurity platform for #AWS, #Azure and #Google Cloud? Read this buyer's guide to select the Cloud Native Application Protection Platform (CNAPP) that works best for your business. #CISOs #infosec #cloud https://t.co/2dEpLZnZxb
#
#  ------------------
#
#
# Pro tip: Bookmark this @googlecloud link to keep up with the latest and greatest tools, technologies, insights, and offers on GCP.
#
# https://t.co/FZcn8I2TB1
#
# #gcp #hybridcloud
#
#  ------------------
#
#
# Architecting with Google Cloud #gcp #cloud #architecting #uber  https://t.co/7Y9iRxCIjP
#
#  ------------------
#
#
# If you're looking to buy google voice accounts or numbers 😍
# https://t.co/D3kqscN3LA
#
# #MachineLearning #DataScience  #100DaysOfCode #javascript #CyberSecurity #getpvaaccount  #DeepLearning #bitcoinplease #getpvaaccount #tinder #pvaaccount  #googlevoice #gmailaccounts #ONEPIECE https://t.co/YEOYMAlCvp
#
#  ------------------
#
#
# May 9
# @4point0_innov invites you at the P4IE Pre-Conference Workshop @Hiltons_Ottawa @ottawacity #Python #NLP Initiation to #coding solving a case study on #BCorps
# Analysis of #unstructured #data in the #social #sciences
# #GoogleColab
# @IVADO_Qc @polymtl
# ➡️https://t.co/eVh1110nR0
#
#  ------------------
#
#
# #Google #AI Blog: Flexible, Scalable, Differentiable Simulation of Recommender Systems with RecSim NG
# 👉🏽https://t.co/1eM5gDwHTZ
# v/ @GoogleAI
#
# #ArtificialIntelligence #DataScience #ML #MachineLearning #IoT #IIoT #IoTPL #Python #TensorFlow #100DaysOfCode #DEVCommunity #coding #tech https://t.co/orMrwT3EJA
#
#  ------------------
#
#
# The most efficient way to learn about Consciousness is to simply Google "consciousness". #Mind #Consciousness #Philosophy #AI #ArtificialIntelligence #MachineConsciousness
#
#  ------------------
#
#
# Architecting with Google Cloud #gcp #cloud #architecting #uber  https://t.co/7Y9iRxDg9n
#
#  ------------------
#
#
# The most efficient way to learn about Consciousness is to simply Google "consciousness". #Mind #Consciousness #Philosophy #AI #ArtificialIntelligence #MachineConsciousness
#
#  ------------------
#
#
# Architecting with Google Cloud #gcp #cloud #architecting #uber  https://t.co/7Y9iRxCIjP
#
#  ------------------
#
#
# Buy Google Reviews Top-Quality Social Service.
# https://t.co/gxu46gslGr
# ⭐️⭐️⭐️⭐️⭐️
# #MachineLearning  #DataScience #5G #100DaysOfCode #Python #Cybersecurity #usaxoom #BigData #AI #IoT #DeepLearning #ArtificialIntelligence #NLP #robots
# #Industry40 #tech #DEVCommunity #javascript30 https://t.co/XAboZd581P
#
#  ------------------
#
#
# Buy Google Reviews Top-Quality Social Service.
# https://t.co/gxu46gslGr
# ⭐️⭐️⭐️⭐️⭐️
# #MachineLearning  #DataScience #5G #100DaysOfCode #Python #Cybersecurity #usaxoom #BigData #AI #IoT #DeepLearning #ArtificialIntelligence #NLP #robots
# #Industry40 #tech #DEVCommunity #javascript30 https://t.co/XAboZd581P
#
#  ------------------
#
#
# #ai #ml #artificialintelligence #machinelearning #datascience #bigdata #analytics #blockchain #tech #data @kuriharan @mvollmer1 @rwang0 @DunkenKBliths @nigewillson
# GamesBeat Summit: Google for Games on the new global opportunities for mobile game devs https://t.co/drlROzThdp
#
#  ------------------
#
#
# To learn about Consciousness simply Google "consciousness". #Mind #Consciousness #Philosophy #AI #ArtificialIntelligence #MachineConsciousness
#
#  ------------------
#
#
# #Google, #Facebook And #Microsoft Are Working On #AI Ethics—Here’s What Your Company Should Be Doing. (Forbes)  https://t.co/nu9hmvFLP7 https://t.co/Jk9kAgjqsF
#
#  ------------------
#
#
# The Google Play Store is littered with dangerous trojans: #ArtificialIntelligence #IoT #IoE copy @MikeQuindazzi https://t.co/Hm7w7OwZ7I https://t.co/5qTSc0H4ys
#
#  ------------------
#
#
# The Google Play Store is littered with dangerous trojans: #ArtificialIntelligence #IoT #IoE copy @MikeQuindazzi https://t.co/Hm7w7OwZ7I https://t.co/5qTSc0H4ys
#
#  ------------------
#
#
# The Google Play Store is littered with dangerous trojans: #ArtificialIntelligence #IoT #IoE copy @MikeQuindazzi https://t.co/Hm7w7OwZ7I https://t.co/5qTSc0H4ys
#
#  ------------------
#
#
# #ai #ml #artificialintelligence #machinelearning #datascience #bigdata #analytics #blockchain #tech #data @kuriharan @mvollmer1 @rwang0 @DunkenKBliths @nigewillson
# GamesBeat Summit: Google for Games on the new global opportunities for mobile game devs https://t.co/drlROzThdp
#
#  ------------------
#
#
# Hands-on learning lab: Stream Google Cloud data into Splunk Cloud #googlecloud #gcp #cloud https://t.co/S5YYLdwoSi
#
#  ------------------
#
#
# Vendors who offer #managedservices for #cloud platforms can help you operate your cloud solutions. We listed the top MSPs for #AWS, #Azure, and #GoogleCloud in our 2022 Buyer's Guide. #cloudcomputing
# https://t.co/sMznpxjfZS
#
#  ------------------
#
#
# To understand Consciousness simply Google "consciousness". #Mind #Consciousness #Philosophy #AI #ArtificialIntelligence #MachineConsciousness
#
#  ------------------
#
#
# https://t.co/6rWV24S6i1 - it's private, it's secure, it's yours!
#
# Ensuring #DSGVO / #GDPR Conformity!
#
# #Cloud #CloudComputing #AI #IoT #BigData #MachineLearning #DeepLearning #DataScience #VDI #AWS #Azure #GoogleCloud #Zadara #IBM #Oracle #GCP #Serverless #edge  and more... https://t.co/GHztnNXpoV
#
#  ------------------
#
#
# seosmmshop: How do I get Google reviews? https://t.co/FDa56tfly0
# ⭐️⭐️⭐️⭐️⭐️
# #pokemon #90DayFiance #business #Airdrop #blacktechtwitter #Cybersecurity #seosmmshop #infosec #100DaysOfCode #node #nodejs #coding #js #angularjs #reactjs #tech #javascript #html #womenwhocode https://t.co/7Fp8eT6fTm
#
#  ------------------
#
#
# #Google says it blocked 1.2 million apps from being published to the Google Play store because the company detected policy violations, preventing "preventing billions of harmful installations" on Android devices.
#
# Learn more: https://t.co/n8iGb8YTJH #Cybersecurity #Security https://t.co/mpGsA0H3nh
#
#  ------------------
#
#
# Step by Step Guide to Build a Google Trends Scraper Using PyTrends: https://t.co/TQeTEI6PIw
# ————
# #abdsc #DataScience #DataScientists #BigData #AI #BI #MachineLearning #Coding #Python #Rstats #WebScraping #100DaysOfCode https://t.co/FVxnJ7Lhwj
#
#  ------------------
#
#
# The #Google #Data #Cloud evolves &amp; we have #dataexperts at @googlecloud Ground School to help you keep up. ☁️🚀 #SADAGroundSchool
#
# 📆👉https://t.co/7iTvG2E1jD
# Join #GoogleCloud Head of #DataAnalytics @brunoaziza &amp; @SADA Assoc. CTO @brian_suk for an overview of the #DataCloud. 💽 https://t.co/RyTm4C9Mjf
#
#  ------------------
#
#
# #NotGood: The richest guy on the 2021 #Forbes 400 owns the #WashingtonPost. Number two now owns #Twitter. Number three owns #Facebook. Numbers five and six started #Google. Numbers four and nine started #Microsoft. Number 10 owns #Bloomberg. #FreeSpeech? You decide. #Problematic
#
#  ------------------
#
#
# Are you thinking about upskilling in Google Cloud? If so, take a look at their Cloud OnBoard series - free instructor-led training.
#
# @googlecloud #cloud
#
# https://t.co/g6f8whRP22
#
#  ------------------
#
#
# Google Calendar is turning into an appointment booking system: #DeepLearning #IoT #BigData copy: @Mikequindazzi https://t.co/PwejsVqr5h https://t.co/19A6155BjX
#
#  ------------------
#
#
# Google Calendar is turning into an appointment booking system: #DeepLearning #IoT #BigData copy: @Mikequindazzi https://t.co/PwejsVqr5h https://t.co/19A6155BjX
#
#  ------------------
#
#
# Google will now remove your phone number and other info from search results. Here's how to do it. - CBS News https://t.co/8jcPz52MpM #Google #personalinfo #security
#
#  ------------------
#
#
# Google will now remove your phone number and other info from search results. Here's how to do it. https://t.co/r4Dqt5rfUx #Google #personalinfo #security
#
#  ------------------
#
#
# Successfully earned the @aviatrixsys certified Engineer (ACE): Multi-Cloud Network Security Associate global accreditation on @awscloud @GCPcloud @Azure @OracleCloud in a single frame. Learned something really worthy in it.
#
# #aviatrix #100DaysOfCloud #GoogleCloud #AWS #Azure https://t.co/N1X5SjLdpq
#
#  ------------------
#
#
# Google is shutting down the Works with Nest API. (https://t.co/SCiKJJZltj)#youtube #throwback #IOT #SmartHome https://t.co/u2T24Iwydt
#
#  ------------------
#
#
# 10-May-2022: Join @deborah_galea &amp; Greg Irwin from BWG Connect for this interactive webinar on how to better secure your #AWS, #Azure, and #GoogleCloud environments. Network with industry peers and hear about security challenges and practical solutions. https://t.co/pSPit3KBdY
#
#  ------------------
#
#
# Over the past decade, malicious apps have plagued Google Play on a regular basis!👿
# Stay Safe: https://t.co/Vb0UZDv7is
#
# #tech #cybersecurity #100DaysOfCode #womenintech #javascript #Python #nodejs #Pune @BlazedRTs #indiedev #nocode #globalhealth #Flutter #app #TwitchStreamers
#
#  ------------------
#
#
# Over the past decade, malicious apps have plagued Google Play on a regular basis!👿
# Stay Safe: https://t.co/Vb0UZDv7is
#
# #tech #cybersecurity #100DaysOfCode #womenintech #javascript #Python #nodejs #Pune @BlazedRTs #indiedev #nocode #globalhealth #Flutter #app #TwitchStreamers
#
#  ------------------
#
#
# Over the past decade, malicious apps have plagued Google Play on a regular basis!👿
# Stay Safe: https://t.co/Vb0UZDv7is
#
# #tech #cybersecurity #100DaysOfCode #womenintech #javascript #Python #nodejs #Pune @BlazedRTs #indiedev #nocode #globalhealth #Flutter #app #TwitchStreamers
#
#  ------------------
#
#
# Visualizing Cloud Architecture
#
# #CloudComputing #AWS #Azure #GoogleCloud #dataengineering #GCP #DataScience #AI #MachineLearning #ArtificialIntelligence #technology #cybersecurity #Serverless #DigitalTransformation #datalake #datadriven #BigData #API https://t.co/jecC04HobI
#
#  ------------------
#
#
# The best way to understand Consciousness is simply to Google "consciousness". #Mind #Consciousness #Philosophy #AI #ArtificialIntelligence #MachineConsciousness
#
#  ------------------
#
#
# https://t.co/6rWV24S6i1 - it's private, it's secure, it's yours!
#
# Ensuring #DSGVO / #GDPR Conformity!
#
# #Cloud #CloudComputing #AI #IoT #BigData #MachineLearning #DeepLearning #DataScience #VDI #AWS #Azure #GoogleCloud #Zadara #IBM #Oracle #GCP #Serverless #edge  and more... https://t.co/8AXVTq6jN6
#
#  ------------------
#
#
# GHunt - Investigate Google Accounts with emails https://t.co/ibaHI5GINx
#
# #infosec #cybersecurity #redteam #pentest #pentesting  #hacking #hackers #coding #opensource #Linux #windows #gmail #google #osint #emails https://t.co/MlLtxlzAjE
#
#  ------------------
#
#
# #Google, #Facebook, #Apple, and #Amazon MUST have the power to #censor information. It's a matter of national #Security. So say American Intelligence Officials - with ties to profits.
#
# https://t.co/FcRKHAeqB1
#
#  ------------------
#
#
# MobiledgeX acquired by Google Cloud – TelecomTV   #iot #business #data #cloud #artificialintelligence https://t.co/VSrY24sqYH https://t.co/rbxJM5ETG7
#
#  ------------------
#
#
# Science in progress: applying our ALPHA methods to upland mapping!
#
# We are using optical Sentinel-2 satellite &amp; SAR Sentinel-1 imagery and #machinelearning in #GoogleEarthEngine. Various datasets are helping the algorithms “learn” how to identify upland classes.
#
# Stay tuned! https://t.co/7kMfmZEUbu
#
#  ------------------
#
#
# If you're looking to buy google voice accounts or numbers 😍
# https://t.co/D3kqscN3LA
#
# #MachineLearning #doggy  #100DaysOfCode #javascript #CyberSecurity #getpvaaccount  #DeepLearning #bitcoinplease #getpvaaccount #tinder #pvaaccount  #googlevoice #gmailaccounts $AMZN https://t.co/Uofd0riaHU
#
#  ------------------
#
#
# 50

# %%
topics = []
score = []
sentence = []
counter = 0
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 2:
        counter += 1
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# More delays to DoD cloud contract; #AWS, #Azure, #Google, #Oracle in the running
#
# Read more about the contract in our latest article: https://t.co/wl7qXFBNbm
#
# #cloud @awscloud @GoogleCloudTech @Oracle @Azure  #managedhosting https://t.co/7mCnJwV96M
#
#  ------------------
#
#
# Our effective AI and ML delivers pre-built machine learning models and machine learning enabled software that can be applied across multiple industries.
#
# Read more 👉 https://t.co/xb2cY6VDug @Electrifai
#
# #GoogleCloudPlatform #SmartSchedulingtailorProgramming #ResolveMissedCharges
#
#  ------------------
#
#
# Quick reminder: Data and Visualization event tomorrow:  #data #visualization #googlecloudplatform #bigquery #looker https://t.co/llageQDXUG
#
#  ------------------
#
#
# Read about how to prep for any disruption or outages that are sure to happen. Cloud-based and hybrid models (done right) will limit downtime and ensure business continuity.
#
# https://t.co/pHYEAAHglg
# #cloudoutage #GoogleCloud #GCP #disasterrecovery #businesscontinuity
#
#  ------------------
#
#
# 🚀 Are you planning on taking the Google Certified Professional Cloud Architect Exam? Then you need to check out this learning path by @GuyRHummel! 👉 https://t.co/QP3rBwN2nK
#
# #GoogleCloud #GoogleCloudPlatform #GCPcertified #CloudArchitect #GoogleCertified https://t.co/coh2mlrwyx
#
#  ------------------
#
#
# Learn How to Deploy 12 Apps to AWS, Azure, &amp; Google Cloud - Via @freeCodeCamp
#
# Read more: https://t.co/MxuAmxp60T
#
# #Cloud #CloudComputing #Serverless #CloudNative #Developer #Programming #LearnProgramming #AWS #Microsoft #Azure #Google #GoogleCloud #Tutorial #freeCodeCamp https://t.co/qdqgq7Awj5
#
#  ------------------
#
#
# #ai #ml #artificialintelligence #machinelearning #datascience #bigdata #analytics #blockchain #tech #data @Nicochan33 @TrippBraden @Paula_Piccard @haroldsinnott @sallyeaves
# Google Confirms Record-Breaking 14 Serious Chrome Security Exploits Surprise In N… https://t.co/1eZpk9xAQR
#
#  ------------------
#
#
# Platform as a Service (PaaS) - Advantages &amp; How it is Used
#
# Read more: https://t.co/JaGFk1sQYg
#
# #omron #technology #productmarketing #development #computing #google #database #environment #cloud #aws #azure #programming #language #marketing https://t.co/Y5BK8DrRUw
#
#  ------------------
#
#
# How to lose #cloud data, tip 2: overwrite data in Google Workplace, it's not uncommon. But you can avoid this scenario with #SaaSProtection! https://t.co/ffPmAuS3wD https://t.co/MhmjBRX5Yn
#
#  ------------------
#
#
# Google Photos updates its library and sharing tabs to make photos easier to find: #DeepLearning #IoT #BigData ht: @worldtrendsinfo https://t.co/K2Ao1daqwz https://t.co/BPwTPifx90
#
#  ------------------
#
#
# Check the Video: Hello World - Machine Learning Recipes 1 - By Google Developers added to https://t.co/LBpwxU1xQU
#
# #Video #AI #DeepLearning #MachineLearning #Developers #100DaysOfMLCode https://t.co/5DUlj2YkAh
#
#  ------------------
#
#
# Google Photos updates its library and sharing tabs to make photos easier to find: #DeepLearning #IoT #BigData ht: @worldtrendsinfo https://t.co/K2Ao1daqwz https://t.co/BPwTPifx90
#
#  ------------------
#
#
# Spatial K-Nearest-Neighbors (Spatial KNN) Algorithms has so many applications ranging from Google Maps to Geospatial data analytics. Here is a summary:
#
# #gischat #geospatial #DataScience #Database https://t.co/Vjmzj7JVm5
#
#  ------------------
#
#
# Level up your professional career with MS-203 Microsoft 365 Messaging Exam Certification. Download your guide: https://t.co/KS7Vg48rjZ
# .
# .
# .
# .
# .
# .
# .
# #microsoftcertification #microsoft #training #coding #bestinstitute #azure #bigdata #certification #machinelearning #googlecloud https://t.co/pDwrhwKLlg
#
#  ------------------
#
#
# Get a thorough understanding of market sentiments. Analyze comments and videos from any data source including TikTok, Facebook, Twitter, Instagram, Google reviews, &amp; others.
# https://t.co/KcleuCtjE8
# #sociallistening #socialmediamarketing #trendanalysis #AI #TikTok #videoanalytics https://t.co/Er5xA9hNWQ
#
#  ------------------
#
#
# Amazon, Google, Meta Among Targets of EU Law on Disinformation, Harmful Content - CNET: #AI #IoT #BigData HT @MikeQuindazzi https://t.co/AO3tLhraRX https://t.co/higtOR5q4X
#
#  ------------------
#
#
# #ENGINEERING NEWS! Basic #authentication isn’t #secure in today’s complex #cloud environments. @SADA Sr #CloudInfrastructure #Engineer, @mikepietruszka &amp; #CloudSecurity Engineer, Jake Luna, write about @googlecloud's #CloudSQL Auth Proxy. https://t.co/Jm5LLJyFfH #googlecloud #gcp https://t.co/wClJrvx9Hv
#
#  ------------------
#
#
# Google Maps is getting an update. Using Artificial Intelligence, Google will be better tracking business hours to identify high-traffic times around their locations.
#
# #AI #ML #futurism #IntelligenceFactory #digitaltransformation #DX
#
# https://t.co/B15kfEJiKa https://t.co/ZGfPMfvYc3
#
#  ------------------
#
#
# Google Maps is getting an update. Using Artificial Intelligence, Google will be better tracking business hours to identify high-traffic times around their locations.
#
# #AI #ML #futurism #IntelligenceFactory #digitaltransformation #DX
#
# https://t.co/igH50BIHdJ https://t.co/RybdxA9gkw
#
#  ------------------
#
#
# #ENGINEERING NEWS! Basic #authentication isn’t #secure in today’s complex #cloud environments. @SADA Sr #CloudInfrastructure #Engineer, @mikepietruszka &amp; #CloudSecurity Engineer, Jake Luna, write about @googlecloud's #CloudSQL Auth Proxy. https://t.co/J6JpOLEp5O #googlecloud #gcp https://t.co/7vBGR7lqHs
#
#  ------------------
#
#
# Thentia’s recent $10 million Series B1 funding round and rapid expansion in the U.S. were profiled this week in @govtechnews. Read the article: https://t.co/tMoPoaKuqC
#
# #digitaltransformation #govtech #licensing #governmenttechnology #googlecloudplatform #saas #digitalgovernment
#
#  ------------------
#
#
# #ENGINEERING NEWS! Basic #authentication isn’t #secure in today’s complex #cloud environments. @SADA Sr #CloudInfrastructure #Engineer, @mikepietruszka &amp; #CloudSecurity Engineer, Jake Luna, write about @googlecloud's #CloudSQL Auth Proxy. https://t.co/J6JpOLEp5O #googlecloud #gcp https://t.co/7vBGR7lqHs
#
#  ------------------
#
#
# #ENGINEERING NEWS! Basic #authentication isn’t #secure in today’s complex #cloud environments. @SADA Sr #CloudInfrastructure #Engineer, @mikepietruszka &amp; #CloudSecurity Engineer, Jake Luna, write about @googlecloud's #CloudSQL Auth Proxy. https://t.co/J6JpOLEp5O #googlecloud #gcp https://t.co/7vBGR7lqHs
#
#  ------------------
#
#
# Statistics on the global public cloud computing market show that #cloudcomputing will reach 482 billion USD this year. According to Statista, AWS controlled 32 % of the public cloud market in 2021, Microsoft held 21% and Google held 8%.
# #cloud #aws #Microsoft #Google #Statistics https://t.co/fY7Ezg9WHK
#
#  ------------------
#
#
# The top 13 #GoogleCloud courses that you can take on @coursera right now. Perfect for #cloud and #IT professionals. #cloudcomputing #AmazonWebServices #cloudmanagement #cloudinfrastructure #cloudsolutions #cloudsecurity #cloudplatform https://t.co/nYgbe8LoXx
#
#  ------------------
#
#
# 1. Find the right web hosting plan
# 2. Pick a quality theme
# 3. Use Google Analytics
# 4. Install a plugin for SEO
# 5. Don’t use too many plugins
# 6. Compress images
# 7. Modify your permalinks
# 8. Prioritize safety
# 9. Eliminate clutter
# #WORDPRESS #Website #ecommerce #woocommerce #SEO https://t.co/M5a57wITWf
#
#  ------------------
#
#
# . @Google #Cloud is hiring a legion of #Blockchain experts to expand its business. (CNBC) #FinTech https://t.co/4GGl9KonWX https://t.co/Ipek4OVTaj
#
#  ------------------
#
#
# Great interview with Anne Shelle THOMSON BROADCAST NAB show Studio. Thank you for the insights and the great mover and shaker to make the Broadcast Industry and bring NextGen TV to the market. #nabshow #atsc3 #remotelearning #googlecloudplatform https://t.co/ymbFXjGtzE
#
#  ------------------
#
#
# The 3 ‘biggest mistakes’ companies make with return to office, according to Google Workspace
#
# https://t.co/HA2AQsjQJW
#
# #GoogleCloud #AWSCloud #Azure #OracleCloud #Microsft365 #GoogleWorkspace https://t.co/e5hWLArzPx
#
#  ------------------
#
#
# The #RightToRepair debate: Everything you need to know about #Legislation #Apple #Google #Samsung #Microsoft &amp; more. $AAPL $GOOG $MSFT https://t.co/G17LYsCHCQ
#
#  ------------------
#
#
# The #GCP suite of services is always evolving, and #Google periodically introduces, changes or discontinues services based on user demand or competitive pressures.
#
# Check out an update here &gt; &gt; https://t.co/qq0mhm4VhS https://t.co/lZhV9DBlZl
#
#  ------------------
#
#
# Google's New Safety Section Shows What Data Android Apps Collect About Users
#
# Know more: https://t.co/7DZlhRVAFi
#
# #DataSecurity #Privacy #100DaysOfCode #Cloud #Security
# #MachineLearning #Phishing #Ransomware #Cybersecurity
# #CyberAttacks #DataProtection #Malware #Hacked #infosec https://t.co/fwTROi280Q
#
#  ------------------
#
#
# #AmazonWebServices #AWS is one of the foundations of modern #web. #AWShosting  biggest player in #cloud #hosting, 33% of market. Closest competitor #GoogleCloud, 21%. Why #AWS is so popular, you’ll need to know how it works.
#  https://t.co/Q6hOLKRPVk #webdev #webdesign #cyber
#
#  ------------------
#
#
# #Google, #Microsoft aim to make their #cloud environments more secure as #cyberattacks increase
# https://t.co/KHip6Kce1M
#
#  ------------------
#
#
# #Google Cloud Upgrades Speech #AI Models Already Used by @Spotify  Car Thing - https://t.co/6DOOjURsYl https://t.co/VMoVCCVr6Y via @voicebotai
#
#  ------------------
#
#
# https://t.co/WL2IJ33GOQ »How Google could own healthcare« https://t.co/YADHqW0eq4 #BigDataLove #BigData #BusinessIntelligence #ArtificialIntelligence #CognitiveComputing #DataScience #Analysis #Research
#
#  ------------------
#
#
# #ai #ml #artificialintelligence #machinelearning #datascience #bigdata #analytics #blockchain #tech #data @kuriharan @mvollmer1 @rwang0 @DunkenKBliths @nigewillson
# How Google could own healthcare https://t.co/wrVGFC3zjg
#
#  ------------------
#
#
# Perfect Google Professional-Machine-Learning-Engineer Exam [2022]: Magnuson: Nathanael https://t.co/6XyWy664Xs #ai #ml #dl
#
#  ------------------
#
#
# Multisearch could make Google Lens your search sensei: #ai #ml #dl #iot mt: @Mikequindazzi https://t.co/K62hTW5BmD https://t.co/TzqlDMo3Iq
#
#  ------------------
#
#
# Multisearch could make Google Lens your search sensei: #ai #ml #dl #iot mt: @Mikequindazzi https://t.co/K62hTW5BmD https://t.co/TzqlDMo3Iq
#
#  ------------------
#
#
# Learn AI &amp; machine learning - Grow with Google
#    https://t.co/37YLclikU9 #ai #ml #dl
#
#  ------------------
#
#
# My top skill is #IAM - Identity and Access Management, what is your top skills? You can assess it via @cloudacademy !
#
# I love to use #CloudAcademy for learning #MultiCloud including #AWS #Azure #GoogleCloud #AlibabaCloud. Thanks @awscloud for offering the free access! https://t.co/puKptFLWp0
#
#  ------------------
#
#
# Multisearch could make Google Lens your search sensei: #ai #ml #dl #iot mt: @Mikequindazzi https://t.co/K62hTW5BmD https://t.co/TzqlDMo3Iq
#
#  ------------------
#
#
# Use the @UiPath #AI Center to give #robots the skills they need to do things like performing research and compiling #citations. And connect with #machinelearning solutions and platforms—like Google, Microsoft, IBM, ABBYY OCR, and more from @UiPath #RPA https://t.co/cJfJS4TW9j https://t.co/Q6LqiyUe75
#
#  ------------------
#
#
# Make a Success career with Microsoft MS-301 Deploying SharePoint Server Hybrid Exam Certification.
# https://t.co/cZdSxiPsYY
# .
# .
# .
# .
# .
# #microsoftcertification #microsoft #training #coding #bestinstitute #azure #bigdata #certification #machinelearning #googlecloud #cybersecurity https://t.co/XtPs5BiRfY
#
#  ------------------
#
#
# Multisearch could make Google Lens your search sensei: #ai #ml #dl #iot mt: @Mikequindazzi https://t.co/K62hTW5BmD https://t.co/TzqlDMo3Iq
#
#  ------------------
#
#
# Multisearch could make Google Lens your search sensei: #ai #ml #dl #iot mt: @Mikequindazzi https://t.co/K62hTW5BmD https://t.co/TzqlDMo3Iq
#
#  ------------------
#
#
# Shout out to @USATODAY for reaching to comment on this piece “Electronic medical records have been around decades. Their power to help other patients is starting to be unleashed” #ai #tech #maternity #technology #MedTwitter @Apple @google @AtroposHealth https://t.co/33KtYfLlOb
#
#  ------------------
#
#
# Latest #cloud market share figures for #AWS #Azure &amp; #GoogleCloud. Plus next moves for public cloud #MSPs &amp; #MSSPs. https://t.co/aA4c9sFfmV
#
#  ------------------
#
#
# #AI's value to society according to Google's Founder. (World Economic Forum) https://t.co/pwAzD074CL
#
#  ------------------
#
#
# As #Kubernetes becomes integral to #cloud-native #app strategies, the role of women has taken on a more prominent role, especially @Google. To help bring more women into the fold, @ContainIQ shares 7 Resources for women breaking into Kubernetes: https://t.co/wiywZPGHhu
#
#  ------------------
#
#
# Hands-on Machine Learning with Google Cloud Labs https://t.co/LMWuPjAkKV  #machinelearning #datascience #bigdata #AI #learning #elearning #ad
#
#  ------------------
#
#
# 52

# %%
topics = []
score = []
sentence = []
counter = 0
for i in range(len(bow_corpus_test)):
    pred = lda_model_tfidf[bow_corpus_test[i]]    
    maxim = -1
    topic = -1
    for el in pred:        
        if el[1] > maxim:
            maxim = el[1]
            topic = el[0]
    sentence.append(new_df['text'].iloc[i])
    score.append(maxim)
    topics.append(topic)
    if topic == 3:
        counter += 1
        print(new_df['text'].iloc[i], '\n \n ------------------ \n \n')
        #print("Sentence: {}\t \n Score: {}\t \n \n Topic: {}\t \n \n".format(new_df['text'].iloc[i], maxim, topic))
print(counter)
# Out:
# Check it out! Rocky Linux is now on Google Cloud with Enterprise Support. If you are accustomed to CentOS or RHEL, have a look at this great new option. #google #cloud #googlecloudplatform #linux #centos #rhel https://t.co/Wt9QOugLTZ
#
#  ------------------
#
#
# I forgot who said you are NOT really Certified till you post it here at LinkedIn : )
# #googlecloud #googlecloudplatform #googlecloudcertified #datascience #dataanalytics #linkedin https://t.co/NVMIgEvrYA
#
#  ------------------
#
#
# Google Pixel unleashed a game-changing virtual experience where you can create, play, share &amp; celebrate your 2022 NBA Playoffs skills! 🏀 https://t.co/Q7JRuphsa5
# •••
# #appbarry #makeitappen #atlanta #softwaredevelopment #appdevelopment #aws #NBA #google #pixel #googlepixelarena https://t.co/5BzoI9nqsj
#
#  ------------------
#
#
# DoiT is a sponsor of #KubeCon2022! Our cloud experts are excited to help you grow your cloud knowledge at our space in person and virtually in Valencia, Spain May 18th - 20th. Register: https://t.co/7tqyLs0aoA #GCP #googlecloud #containers #multicloud #kubernetes @googlecloud https://t.co/rIPby3YrdA
#
#  ------------------
#
#
# SADA CEO Tony Safoian: How Google Cloud Is Besting AWS: https://t.co/bhk77Po9iR
#
# @SADA's @safoian talks to @CRN about the company’s new $2.5 billion @googlecloud partnership, besting #cloud competitor AWS and its push to become a more global channel partner.
#
# @gcloudpartners https://t.co/eZt7McGsZc
#
#  ------------------
#
#
# Ep62 Intersection of APIs and AppSec - @anton_chuvakin and @_TimPeacock interview Etienne De Burgh of GCloud OCISO about API security
#
# #CloudSecurityPodcast @CloudSecPodcast #GoogleCloud #CloudSecurity #Cloud #Security #Cybersecurity #APIsecurity https://t.co/BKE5LvsZR2
#
#  ------------------
#
#
# Ep62 Intersection of APIs and AppSec - @anton_chuvakin and @_TimPeacock interview Etienne De Burgh of GCloud OCISO about API security
#
# #CloudSecurityPodcast @CloudSecPodcast #GoogleCloud #CloudSecurity #Cloud #Security #Cybersecurity #APIsecurity https://t.co/kyqZhqAm8O
#
#  ------------------
#
#
# Ep62 Intersection of APIs and AppSec - @anton_chuvakin and @_TimPeacock interview Etienne De Burgh of GCloud OCISO about API security
#
# #CloudSecurityPodcast @CloudSecPodcast #GoogleCloud #CloudSecurity #Cloud #Security #Cybersecurity #APIsecurity https://t.co/BKE5LvsZR2
#
#  ------------------
#
#
# #Infographic 👌: How Do Big #Tech Giants Make Their Billions?
#
# 🔗👉 https://t.co/seQmAFNwSR via @VisualCap
#
# 📌 #socialmedia #searchengine #Google #Facebook #Metaverse #GAFAM #ecommerce #Amazon #Metaverse #gaming #data #CloudComputing https://t.co/KFMGsD0Y5p
#
#  ------------------
#
#
# Someone needed a #Cloud created #CIS Sharpening up my #Cloudshell programing language with all the new #Chromium web 3 changes #WebAppTime @googledevs owner of @Nickoftimewebd1 https://t.co/cLEqcTlYu9
#
#  ------------------
#
#
# Last chance to register for tomorrow's live session with @GoogleCloud experts for Optimize your Compute with Tau VMs and Spot. Don't miss this free discussion tomorrow at 9 AM PST. Register now 👉 https://t.co/41fKqRep5H
#
# #GCP #CloudComputing #gcpcloud https://t.co/8ywegkAjxT
#
#  ------------------
#
#
# Google has announced a new commercial CDN offering called “Media CDN”. Listen to this special podcast I did with David Reisfeld from Google for more details on the service. https://t.co/FrXYeu9TPS -----#googlecloud #streamingmedia #nabshow #googlecloudplatform
#
#  ------------------
#
#
# #Math work for virtual students can be tough! Conveying math work to your teacher remotely is made much easier with the #EquatIO extension for #Google Chrome and #Microsoft Edge. Learn more about EquatIO here: https://t.co/1wjVMzEQQR
# #ATTuesday https://t.co/46O7d3rq05
#
#  ------------------
#
#
# Deep Learning Chipset Market Size, Scope And Forecast | Alphabet Inc. (Google Inc.), https://t.co/x1nwZiuvJz Ad... https://t.co/TX36PUUcMX #ai #ml #dl
#
#  ------------------
#
#
# Deep Learning Chipset Market Size, Scope And Forecast | Alphabet Inc. (Google Inc.), https://t.co/x1nwZiuvJz Ad... https://t.co/TX36PUUcMX #ai #ml #dl
#
#  ------------------
#
#
# The Cloud galaxy writhes in chaos and disorder... while tech Twitter debates the correct approach using different providers #AWS, #Azure, #GoogleCloud, #Kubernetes &amp; others, Pulumi is gathering great minds to meet at #PulumiUP to settle the debate. https://t.co/8FNegG4LM2 https://t.co/Yz2Q9RCyEf
#
#  ------------------
#
#
# Excited to be in the office today to continue the work of transforming and revolutionizing the software development industry. #softwaredevelopment #DevSecOps
# #devops #Python #React #javascript #Java #golang #Kubernetes #Azure #GoogleCloud #AWS #automaton #code #cicd #EmergingTech https://t.co/si8Ac9Unz7
#
#  ------------------
#
#
# Google has announced a new commercial CDN offering called “Media CDN”. Listen to this special podcast I did with David Reisfeld from Google for more details on the service. https://t.co/FrXYeu9TPS -----#googlecloud #streamingmedia #nabshow #googlecloudplatform
#
#  ------------------
#
#
# We're excited to announce our new arrangement with @google #cloud to help accelerate the migration and application modernization programs of customers worldwide. Read more here: https://t.co/6QXdokf9vX
#
#  ------------------
#
#
# As customers shift their data infrastructure to cloud data platforms such as Google BigQuery, Snowflake, or Databricks, AtScale is the only provider of a semantic layer and dimensional analysis -- https://t.co/UbFTPd5msA
#
# #data #datascience #bi #ai #semanticlayer #atscale https://t.co/CHUwodf6K1
#
#  ------------------
#
#
# Top story: @CurieuxExplorer: 'Which one do you use most? 🤔
#
# 🎨 thecybersecurityhub
#
# #Google #search #Python #Nodejs #MachineLearning #100daysofmlcode #HTML5 #RStats #Serverless #AI #Flutter #Java #Developer #developers… https://t.co/eg8vY8yuTD, see more https://t.co/jj8n0iJEW3
#
#  ------------------
#
#
# 🏅 Best use of #AI I've seen this week. 😂
# 🤖 Meet MuellerBot; An AI John Mueller To Answer Your Google SEO Questions
# https://t.co/ap9WVt3o0a
#
#  ------------------
#
#
# Last week, we held the Embedded Device Observability Panel with @mbeddedartistry.
#
# You can now watch the recording and listen to panelists from Embedded Artistry, Memfault, and @Google share best practices for using device metrics.
#
# https://t.co/J9H2LS2Saf
#
# #embeddedsystems #iot https://t.co/83Wa1oKDmu
#
#  ------------------
#
#
# Google Ads API v10.1 is now available https://t.co/MKnIla4lVm &gt;&gt; #seo #seonews #searchengineoptimization #sem #smm #divi #wordpress
#
#  ------------------
#
#
# 🚨REMINDER🚨
#
# There's A LOT happening this summer☀️ Don't forget that *early bird registration* ends @ midnight 4/30
#
# June 21-23
# 🌲Mornings- #Google Summer Camp
# ⛺️Afternoons- #Microsoft Summer Camp
#
# June 28-30
# 📚9am-1pm #Librarian Conference
# https://t.co/yQtefJeEL3 #txed #profdev https://t.co/wRlLSOVYPa
#
#  ------------------
#
#
# 🚨REMINDER🚨
#
# There's A LOT happening this summer☀️ Don't forget that *early bird registration* ends @ midnight 4/30
#
# June 21-23
# 🌲Mornings- #Google Summer Camp
# ⛺️Afternoons- #Microsoft Summer Camp
#
# June 28-30
# 📚9am-1pm #Librarian Conference
# https://t.co/yQtefJeEL3 #txed #profdev https://t.co/wRlLSOVYPa
#
#  ------------------
#
#
# 🚨REMINDER🚨
#
# There's A LOT happening this summer☀️ Don't forget that *early bird registration* ends @ midnight 4/30
#
# June 21-23
# 🌲Mornings- #Google Summer Camp
# ⛺️Afternoons- #Microsoft Summer Camp
#
# June 28-30
# 📚9am-1pm #Librarian Conference
# https://t.co/yQtefJeEL3 #txed #profdev https://t.co/wRlLSOVYPa
#
#  ------------------
#
#
# Want to learn about moving to @googlecloud but don't know where to start? 🚚 ☁️
# Enjoy 2️⃣ days of #virtualsessions introducing #GoogleCloud. 🚀 #SADAGroundSchool #GCP
# See live/on-demand sessions Wed., May 18 at 9 a.m. PT / 12 p.m. ET.
# REGISTER TODAY! 📆 👉 https://t.co/WX4wrxUGFh
#
#  ------------------
#
#
# Congratulations, ShelterZoom on your launch of #DocumentGPS, a new standard for #safety, #security, #tracking, #management, and #control of #email attachments in Google #Gmail and #Workspace.
#
# Being able to control the #downloadin…https://t.co/BQiciDGDbq https://t.co/BQYKHSLW0D
#
#  ------------------
#
#
# This #WomenWednesday, we're excited to announce our amazing lineup of panelist sessions with moderators joining us from #AmazonWebServices, #Google, #Microsoft, and #SafeTravelApp. It's not too late to register for our Seattle Accelerate Conference: https://t.co/ISlEs53XdQ https://t.co/TZZ9BRhKPP
#
#  ------------------
#
#
# We just added 300 more risks to our Cloud Risk Encyclopedia! a collection of 1200+ public cloud risks and remediations pulled from the @Orcasec platform for #AWS, #Azure and #GoogleCloud. Read about the latest #cloudsecurity risks and learn best practices. https://t.co/5DBqVfNdAL
#
#  ------------------
#
#
# #Google #sheets and #Microsoft #Excel made easier to use on your phone. Slick #dataviz and #data without paying money or needing a computer. Download free: https://t.co/Wj0lMQkkuf https://t.co/BVYRCxYUDu
#
#  ------------------
#
#
# .@Google Ads API v10.1 is now available: https://t.co/sDktfoAsza
#
# Via @sengineland
# Cc @CurieuxExplorer @TanyaSinha_
#
# #DGsaga #coding #programmer #Developer #flutter #javascript #nodejs #HTML5 #Java #100DaysOfCode #Python #devops #programming #RStats #Serverless #CSS #advertising
#
#  ------------------
#
#
# Amazon Web Services and @Google  Cloud recently rolled out new cloud certifications and training which are designed to drive more channel partners and end users to their cloud-based services.  https://t.co/Guf5bnoHwF  #Cloud #GoogleCloud #AWS
#
#  ------------------
#
#
# Google #Cloud launches content and media distribution platform https://t.co/Qrs0XcEFpi
#
# #CIO
# @sarbjeetjohal @imoyse @avrohomg @DrJDrooghaag @sallyeaves @fklivestolearn @junjudapi @shanebrighton @afigueiredo @rmogha @ShadRaza1 @TylerCohenWood @khurramcyber  @StephaneNappo
#
#  ------------------
#
#
# 300 more risks have been added to our Cloud Risk Encyclopedia, a collection of 1200+ public cloud risks &amp; remediations from the @Orcasec platform for #AWS #Azure #GoogleCloud. Read about the latest #cloudsecurity risks &amp; learn best practices. https://t.co/1pcRnh4NHj
#
#  ------------------
#
#
# New #Research Note Alert: Newly Unveiled @Google #Cloud Consumption Packs are Designed to Accelerate #CloudAdoption. https://t.co/qzA81p45ir
#
# #GoogleCloud https://t.co/TENheQN7Qo
#
#  ------------------
#
#
# what application do you write your copy in? I use google docs a lot but their limitations start bothering me😭 any suggestions? #copywriting #GoogleDocs #microsoft #apple
#
#  ------------------
#
#
# Top story: @CurieuxExplorer: 'Which one do you use most? 🤔
#
# 🎨 thecybersecurityhub
#
# #Google #search #Python #Nodejs #MachineLearning #100daysofmlcode #HTML5 #RStats #Serverless #AI #Flutter #Java #Developer #developers… https://t.co/eg8vY8yuTD, see more https://t.co/jj8n0iJEW3
#
#  ------------------
#
#
# Google Domains: How to Use It and Whether It Beats the Competition https://t.co/1uAHJJf4Vn : #WordPress #WebDesign #WebDevelopment https://t.co/zh8Mb17Xjf
#
#  ------------------
#
#
# .@Amazon #AWS Up 36.5%; @Microsoft #Azure 32%; @GoogleCloud 44% - we've got a new momentum leader and that is @GoogleCloud. @gcloudpartners
# https://t.co/tRyqDyTCEM
#
#  ------------------
#
#
# New Tutorial: Python Programming with Google BigQuery https://t.co/LsmiOOxUTM    Learn how to query and load data into BigQuery.  #Python #GCP
#
#  ------------------
#
#
# Register for "Data Immersion Day - #Canada" today!
# ☁️🇨🇦 https://t.co/bodQoQo9lb
# Imagine what's possible with the power of #dataanalytics in your hands. 💽🤜 #GoogleCloud #GCP
# Participate in an interactive lab session transforming #data w/#BigQuery &amp; #Looker in just a few hours. https://t.co/fAlsPv794h
#
#  ------------------
#
#
# Software Engineer, Computational Photography and Machine Learning - Google Careers https://t.co/PHrZ1r0knT #ai #ml #dl
#
#  ------------------
#
#
# NEW BLOG! Cloud Services in Canada: Comparing AWS, Google Cloud, Azure
# https://t.co/tuNCMLg3VK
#
# #GoogleCloud #GoogleCloudCanada #AWSCloud #AWSCloudCanada #Azure #AzureCanada #OracleCloud https://t.co/FQAdlNe31W
#
#  ------------------
#
#
# Join us for a lively discussion led by @gigastacey, from Stacey on IoT, with @amazon, @csaiot, @digicert, @Google, @SchneiderElec, and @WEMO. These #IoT leaders will be discussing their plans with #Matter and answering your questions. RSVP: https://t.co/dTyYUKg6qb
# #smarthome https://t.co/Rz52C088LJ
#
#  ------------------
#
#
# New #Research Note Alert: Newly Unveiled @Google #Cloud Consumption Packs are Designed to Accelerate #CloudAdoption. https://t.co/qzA81p45ir
#
# #GoogleCloud https://t.co/TENheQN7Qo
#
#  ------------------
#
#
# New #Research Note Alert: Newly Unveiled @Google #Cloud Consumption Packs are Designed to Accelerate #CloudAdoption. https://t.co/qzA81p45ir
#
# #GoogleCloud https://t.co/TENheQN7Qo
#
#  ------------------
#
#
# New #Research Note Alert: Newly Unveiled @Google #Cloud Consumption Packs are Designed to Accelerate #CloudAdoption. https://t.co/qzA81p45ir
#
# #GoogleCloud https://t.co/TENheQN7Qo
#
#  ------------------
#
#
# Newly unveiled @Google Cloud consumption packs are designed to accelerate cloud adoption.  Insights via Principal analyst @ShellyKramer.  https://t.co/lWAJeLohhu
#
# #Cloud #GoogleCloud #CloudAdoption https://t.co/APDnQDyx4h
#
#  ------------------
#
#
# Here are the top 5 largest programs (lines of code) to be ever written in human history.
# #knowledge #facts #techprogram #IT #upskill #programmings #Google #facebook #datascience #Apple #computerscience #development #Itsguru https://t.co/s5dt4oajHj
#
#  ------------------
#
#
# NEWS from @SADA #engineering! OPA Gatekeeper simplifies #policymanagement. #GoogleCloud #GCP #Infrastructure
#
# Read an article by our Sr #CloudInfrastructure #Engineer, Alain Baxter, helping understand how #policies are defined using Rego #policy language. https://t.co/C2VTBzqZNK https://t.co/0Vh39rFVUP
#
#  ------------------
#
#
# . @Google  Cloud’s consumption packs are designed to accelerate the process of cloud transformation for its partners and their clients.
# https://t.co/e4eSfdvoqa #Cloud #GoogleCloud #CloudAdoption
#
#  ------------------
#
#
# If you want to know who the #REAL #OGs of the Google Cloud, #GCP, Google Workspace game are, you need to dig into the archives.
#
# Special shout out to Jeff Ragusa, by the way.
#
# SADA part:
#
# Crisantos Hajibrahim's part:
# https://lnk…https://t.co/hyFBz7FsP3 https://t.co/MGtLEmEV9M
#
#  ------------------
#
#
# New #Research Note Alert: Newly Unveiled @Google #Cloud Consumption Packs are Designed to Accelerate #CloudAdoption. https://t.co/qzA81p45ir
#
# #GoogleCloud https://t.co/TENheQN7Qo
#
#  ------------------
#
#
# 55
